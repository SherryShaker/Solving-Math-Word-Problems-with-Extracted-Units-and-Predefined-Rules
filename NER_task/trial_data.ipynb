# %%
import os
import json
from glob import glob
import numpy as np
import pandas as pd
from collections import namedtuple
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktTrainer
from nltk.tokenize import RegexpTokenizer

# %%
train_docs_dir = 'C:/Users/DELL/Desktop/MeasEval/data/trial'

train_texts = ' '.join([open(txt_file, 'r').read() for txt_file in glob(os.path.join(train_docs_dir,'*.txt'))])
trainer = PunktTrainer()
trainer.INCLUDE_ALL_COLLOCS = True
trainer.train(train_texts)

sentenizer = PunktSentenceTokenizer(trainer.get_params())
tokenizer = RegexpTokenizer(r'\w+|\(|\)|\[|\]|[-–.,]|\S+')

# %%
annotations_dir = 'C:/Users/DELL/Desktop/MeasEval/data/trial/tsv'
docs_dir = 'C:/Users/DELL/Desktop/MeasEval/data/trial/txt'

Sentence = namedtuple('Sentence', ['start', 'end', 'text'])

tsv_files = glob(os.path.join(annotations_dir,'*.tsv')) if annotations_dir is not None else []
txt_files = glob(os.path.join(docs_dir,'*.txt'))

docs = {'docId': [], 'text': []}
for txt_file in txt_files:
    docs['text'].append(open(txt_file, 'r', encoding='UTF-8').read())
    docs['docId'].append(os.path.split(txt_file)[1].split('.')[0])
#     docs['docId'].append(txt_file.split('/')[-1].split('.')[0])

docs = pd.DataFrame(docs)

docs.loc[:, 'texts'] = docs.text.apply(
    lambda x: [
        Sentence(start, end, text) for (start, end), text in zip(
            sentenizer.span_tokenize(x), sentenizer.tokenize(x)
        )
    ]
)

# %%
docs
# Out:
#                       docId  \
# 0    S0012821X12004384-1302
# 1    S0012821X12004384-1405
# 2    S0012821X12004384-1415
# 3    S0012821X12004384-1594
# 4    S0012821X12004384-1599
# ..                      ...
# 60  S0022000014000026-17824
# 61  S0022000014000026-18167
# 62   S0022399913003358-1044
# 63   S0022459611006116-1160
# 64   S0022459611006116-1195
#
#                                                  text  \
# 0   Correspondence analysis (CA) and statistical d...
# 1   Dinoflagellate cysts have been used extensivel...
# 2   Dinoflagellate cyst assemblage 1 (DA1, from 26...
# 3   Alternatively, an increase in regional precipi...
# 4   Our results provide the first evidence that th...
# ..                                                ...
# 60  The figure also demonstrates the capability of...
# 61  As the conclusion of our paper, we now assess ...
# 62  Self-reported hearing difficulty was the stron...
# 63  The ternary magnesium nitride fluorides were p...
# 64  All products were initially characterised by P...
#
#                                                 texts
# 0   [(0, 175, Correspondence analysis (CA) and sta...
# 1   [(0, 302, Dinoflagellate cysts have been used ...
# 2   [(0, 64, Dinoflagellate cyst assemblage 1 (DA1...
# 3   [(0, 195, Alternatively, an increase in region...
# 4   [(0, 129, Our results provide the first eviden...
# ..                                                ...
# 60  [(0, 157, The figure also demonstrates the cap...
# 61  [(0, 242, As the conclusion of our paper, we n...
# 62  [(0, 77, Self-reported hearing difficulty was ...
# 63  [(0, 183, The ternary magnesium nitride fluori...
# 64  [(0, 49, All products were initially character...
#
# [65 rows x 3 columns]

# %%
if annotations_dir is not None:
    annotations = pd.read_csv(tsv_files[0], sep='\t')
    for tsv_file in tsv_files[1:]:
        annotations = annotations.append(pd.read_csv(tsv_file, sep='\t'), ignore_index=True)
    annotations = annotations.replace(np.nan, '{}')
    annotations.loc[:, 'other'] = annotations.other.apply(lambda x: eval(x))
else:
    annotations = pd.DataFrame(columns=['docId', 'annotSet', 'annotType', 'startOffset', 'endOffset', 'annotId', 'text', 'other'])

# %%
annotations
# Out:
#                       docId  annotSet         annotType  startOffset  \
# 0    S0012821X12004384-1302         1          Quantity          553
# 1    S0012821X12004384-1302         1    MeasuredEntity          558
# 2    S0012821X12004384-1302         2          Quantity          588
# 3    S0012821X12004384-1302         2    MeasuredEntity          558
# 4    S0012821X12004384-1302         2         Qualifier          571
# ..                      ...       ...               ...          ...
# 827  S0022459611006116-1195         2  MeasuredProperty          192
# 828  S0022459611006116-1195         2    MeasuredEntity          139
# 829  S0022459611006116-1195         3          Quantity          230
# 830  S0022459611006116-1195         3  MeasuredProperty          217
# 831  S0022459611006116-1195         3    MeasuredEntity          139
#
#      endOffset annotId                                               text  \
# 0          557   T91-1                                               Five
# 1          565  T101-1                                            samples
# 2          637   T12-2  2619.60, 2617.35, 2617.44, 2614.73, and 2614.71 m
# 3          565  T102-2                                            samples
# 4          584  T152-2                                      below the CIE
# ..         ...     ...                                                ...
# 827        201   T32-2                                          step size
# 828        152   T52-2                                      Initial scans
# 829        236   T13-3                                             50 min
# 830        226   T23-3                                          scan time
# 831        152   T53-3                                      Initial scans
#
#                                  other
# 0                {'mods': ['IsCount']}
# 1             {'HasQuantity': 'T91-1'}
# 2    {'mods': ['IsList'], 'unit': 'm'}
# 3             {'HasQuantity': 'T12-2'}
# 4              {'Qualifies': 'T102-2'}
# ..                                 ...
# 827           {'HasQuantity': 'T42-2'}
# 828           {'HasProperty': 'T32-2'}
# 829                    {'unit': 'min'}
# 830           {'HasQuantity': 'T13-3'}
# 831           {'HasProperty': 'T23-3'}
#
# [832 rows x 8 columns]

# %% [markdown]
# ## Q, ME, MP, Qlr tagging

# %%
# annotating tokens in each sentence for each doc

# examples = [exmaple]
# annotated_sent = [annotated_tokens[]]
# example = {
#     'docId': doc.docId,
#     'sentAnnot': annotated_sent
# }

Token = namedtuple('Token', ['start', 'end', 'text'])
AnnotatedToken = namedtuple('AnnotatedToken', ['start', 'end', 'text', 'label'])
only_labels='Quantity+MeasuredProperty+MeasuredEntity+Qualifier'

examples = []
for doc in docs.itertuples():
    doc_annotations = annotations[(annotations.docId == doc.docId) & (annotations.annotType.isin(only_labels.split('+')))]
#     print(doc)
#     print(doc_annotations)
    
    annotated_sent = []
    for sent in doc.texts:
        tokens = [
            Token(sent.start + start, sent.start + end, token)
            for (start, end), token in zip(
                tokenizer.span_tokenize(sent.text),
                tokenizer.tokenize(sent.text)
            )
        ]
        
#         print(sent)
#         for t in tokens:
#             print(t)
            
        # retrieve labels for each sentence
        AnnotatedSpan = namedtuple('AnnotatedSpan', ['start', 'end', 'label'])
        df = doc_annotations[(doc_annotations.startOffset >= sent.start) & (doc_annotations.endOffset <= sent.end)]
        sent_labels = [AnnotatedSpan(r.startOffset, r.endOffset, r.annotType) for r in df.itertuples()]
#         for l in sent_labels:
#             print("sent_labels", l)
            
        annotated_tokens = []
        for token in tokens:
            # initialise the annotation tag for the current token as 'O'
            tag = 'O'
            for sl in sent_labels:
                # check whether the current token is within the range of the current annotated span
                isInCurrRange = set(range(token.start, token.end)).intersection(set(range(sl.start, sl.end)))
                if isInCurrRange:
                    # check whether it's in the beginning (B) of the span
                    if token.start == sl.start:
                        tag = 'B-' + sl.label
                    # otherwise, it's in the internal (I) of the span
                    else:
                        tag = 'I-' + sl.label
            # append the annotated tag for the current token
            annotated_tokens.append(AnnotatedToken(token.start, token.end, token.text, tag))
        
#         for a in annotated_tokens:
#             print('annotated_tokens', a)
        
        if len(annotated_tokens) == len(tokens):
            annotated_sent.append(annotated_tokens)
    
#     for anns in annotated_sent:
#         for annt in anns:
#             print('annotated_tokens', annt)
            
    example = {
        'docId': doc.docId,
        'sentAnnot': annotated_sent
    }
    examples.append(example)

# %%
examples
# Out:
# [{'docId': 'S0012821X12004384-1302',
#   'sentAnnot': [[AnnotatedToken(start=0, end=14, text='Correspondence', label='O'),
#     AnnotatedToken(start=15, end=23, text='analysis', label='O'),
#     AnnotatedToken(start=24, end=25, text='(', label='O'),
#     AnnotatedToken(start=25, end=27, text='CA', label='O'),
#     AnnotatedToken(start=27, end=28, text=')', label='O'),
#     AnnotatedToken(start=29, end=32, text='and', label='O'),
#     AnnotatedToken(start=33, end=44, text='statistical', label='O'),
#     AnnotatedToken(start=45, end=54, text='diversity', label='O'),
#     AnnotatedToken(start=55, end=63, text='analysis', label='O'),
#     AnnotatedToken(start=64, end=68, text='were', label='O'),
#     AnnotatedToken(start=69, end=76, text='carried', label='O'),
#     AnnotatedToken(start=77, end=80, text='out', label='O'),
#     AnnotatedToken(start=81, end=83, text='on', label='O'),
#     AnnotatedToken(start=84, end=87, text='the', label='O'),
#     AnnotatedToken(start=88, end=101, text='palynological', label='O'),
#     AnnotatedToken(start=102, end=109, text='dataset', label='O'),
#     AnnotatedToken(start=110, end=111, text='(', label='O'),
#     AnnotatedToken(start=111, end=116, text='total', label='O'),
#     AnnotatedToken(start=117, end=123, text='counts', label='O'),
#     AnnotatedToken(start=124, end=127, text='per', label='O'),
#     AnnotatedToken(start=128, end=132, text='gram', label='O'),
#     AnnotatedToken(start=132, end=133, text=')', label='O'),
#     AnnotatedToken(start=134, end=136, text='to', label='O'),
#     AnnotatedToken(start=137, end=144, text='confirm', label='O'),
#     AnnotatedToken(start=145, end=155, text='assemblage', label='O'),
#     AnnotatedToken(start=156, end=168, text='designations', label='O'),
#     AnnotatedToken(start=169, end=170, text='(', label='O'),
#     AnnotatedToken(start=170, end=174, text='Figs', label='O'),
#     AnnotatedToken(start=174, end=175, text='.', label='O')],
#    [AnnotatedToken(start=176, end=177, text='4', label='O'),
#     AnnotatedToken(start=178, end=181, text='and', label='O'),
#     AnnotatedToken(start=182, end=183, text='5', label='O'),
#     AnnotatedToken(start=183, end=184, text=')', label='O'),
#     AnnotatedToken(start=184, end=185, text=',', label='O'),
#     AnnotatedToken(start=186, end=188, text='to', label='O'),
#     AnnotatedToken(start=189, end=197, text='identify', label='O'),
#     AnnotatedToken(start=198, end=201, text='any', label='O'),
#     AnnotatedToken(start=202, end=213, text='disturbance', label='O'),
#     AnnotatedToken(start=214, end=216, text='to', label='O'),
#     AnnotatedToken(start=217, end=220, text='the', label='O'),
#     AnnotatedToken(start=221, end=225, text='core', label='O'),
#     AnnotatedToken(start=226, end=231, text='prior', label='O'),
#     AnnotatedToken(start=232, end=234, text='to', label='O'),
#     AnnotatedToken(start=235, end=249, text='interpretation', label='O'),
#     AnnotatedToken(start=249, end=250, text=',', label='O'),
#     AnnotatedToken(start=251, end=254, text='and', label='O'),
#     AnnotatedToken(start=255, end=257, text='to', label='O'),
#     AnnotatedToken(start=258, end=266, text='estimate', label='O'),
#     AnnotatedToken(start=267, end=276, text='diversity', label='O'),
#     AnnotatedToken(start=277, end=278, text='(', label='O'),
#     AnnotatedToken(start=278, end=281, text='Fig', label='O'),
#     AnnotatedToken(start=281, end=282, text='.', label='O')],
#    [AnnotatedToken(start=283, end=284, text='6', label='O'),
#     AnnotatedToken(start=284, end=285, text=')', label='O'),
#     AnnotatedToken(start=285, end=286, text='.', label='O')],
#    [AnnotatedToken(start=287, end=301, text='Dinoflagellate', label='O'),
#     AnnotatedToken(start=302, end=306, text='cyst', label='O'),
#     AnnotatedToken(start=307, end=318, text='assemblages', label='O'),
#     AnnotatedToken(start=319, end=320, text='(', label='O'),
#     AnnotatedToken(start=320, end=323, text='DA1', label='O'),
#     AnnotatedToken(start=323, end=324, text='–', label='O'),
#     AnnotatedToken(start=324, end=327, text='DA5', label='O'),
#     AnnotatedToken(start=327, end=328, text=')', label='O'),
#     AnnotatedToken(start=329, end=332, text='and', label='O'),
#     AnnotatedToken(start=333, end=339, text='pollen', label='O'),
#     AnnotatedToken(start=340, end=351, text='assemblages', label='O'),
#     AnnotatedToken(start=352, end=353, text='(', label='O'),
#     AnnotatedToken(start=353, end=356, text='PA1', label='O'),
#     AnnotatedToken(start=356, end=357, text='–', label='O'),
#     AnnotatedToken(start=357, end=360, text='PA4', label='O'),
#     AnnotatedToken(start=360, end=361, text=')', label='O'),
#     AnnotatedToken(start=362, end=366, text='were', label='O'),
#     AnnotatedToken(start=367, end=374, text='defined', label='O'),
#     AnnotatedToken(start=375, end=377, text='by', label='O'),
#     AnnotatedToken(start=378, end=386, text='visually', label='O'),
#     AnnotatedToken(start=387, end=396, text='comparing', label='O'),
#     AnnotatedToken(start=397, end=404, text='changes', label='O'),
#     AnnotatedToken(start=405, end=407, text='in', label='O'),
#     AnnotatedToken(start=408, end=411, text='the', label='O'),
#     AnnotatedToken(start=412, end=419, text='species', label='O'),
#     AnnotatedToken(start=420, end=429, text='dominance', label='O'),
#     AnnotatedToken(start=430, end=431, text='(', label='O'),
#     AnnotatedToken(start=431, end=435, text='Figs', label='O'),
#     AnnotatedToken(start=435, end=436, text='.', label='O')],
#    [AnnotatedToken(start=437, end=438, text='7', label='O'),
#     AnnotatedToken(start=439, end=442, text='and', label='O'),
#     AnnotatedToken(start=443, end=444, text='8', label='O'),
#     AnnotatedToken(start=444, end=445, text=')', label='O'),
#     AnnotatedToken(start=445, end=446, text=',', label='O'),
#     AnnotatedToken(start=447, end=450, text='and', label='O'),
#     AnnotatedToken(start=451, end=460, text='confirmed', label='O'),
#     AnnotatedToken(start=461, end=463, text='by', label='O'),
#     AnnotatedToken(start=464, end=466, text='CA', label='O'),
#     AnnotatedToken(start=467, end=468, text='(', label='O'),
#     AnnotatedToken(start=468, end=471, text='Fig', label='O'),
#     AnnotatedToken(start=471, end=472, text='.', label='O')],
#    [AnnotatedToken(start=473, end=474, text='4', label='O'),
#     AnnotatedToken(start=474, end=475, text=')', label='O'),
#     AnnotatedToken(start=476, end=481, text='using', label='O'),
#     AnnotatedToken(start=482, end=485, text='the', label='O'),
#     AnnotatedToken(start=486, end=491, text='first', label='O'),
#     AnnotatedToken(start=492, end=497, text='three', label='O'),
#     AnnotatedToken(start=498, end=502, text='axes', label='O'),
#     AnnotatedToken(start=503, end=504, text='(', label='O'),
#     AnnotatedToken(start=504, end=514, text='describing', label='O'),
#     AnnotatedToken(start=515, end=518, text='the', label='O'),
#     AnnotatedToken(start=519, end=526, text='highest', label='O'),
#     AnnotatedToken(start=527, end=538, text='percentages', label='O'),
#     AnnotatedToken(start=539, end=541, text='of', label='O'),
#     AnnotatedToken(start=542, end=550, text='variance', label='O'),
#     AnnotatedToken(start=550, end=551, text=')', label='O'),
#     AnnotatedToken(start=551, end=552, text='.', label='O')],
#    [AnnotatedToken(start=553, end=557, text='Five', label='B-Quantity'),
#     AnnotatedToken(start=558, end=565, text='samples', label='B-MeasuredEntity'),
#     AnnotatedToken(start=566, end=570, text='from', label='O'),
#     AnnotatedToken(start=571, end=576, text='below', label='B-Qualifier'),
#     AnnotatedToken(start=577, end=580, text='the', label='I-Qualifier'),
#     AnnotatedToken(start=581, end=584, text='CIE', label='I-Qualifier'),
#     AnnotatedToken(start=585, end=587, text='at', label='O'),
#     AnnotatedToken(start=588, end=592, text='2619', label='B-Quantity'),
#     AnnotatedToken(start=592, end=593, text='.', label='I-Quantity'),
#     AnnotatedToken(start=593, end=595, text='60', label='I-Quantity'),
#     AnnotatedToken(start=595, end=596, text=',', label='I-Quantity'),
#     AnnotatedToken(start=597, end=601, text='2617', label='I-Quantity'),
#     AnnotatedToken(start=601, end=602, text='.', label='I-Quantity'),
#     AnnotatedToken(start=602, end=604, text='35', label='I-Quantity'),
#     AnnotatedToken(start=604, end=605, text=',', label='I-Quantity'),
#     AnnotatedToken(start=606, end=610, text='2617', label='I-Quantity'),
#     AnnotatedToken(start=610, end=611, text='.', label='I-Quantity'),
#     AnnotatedToken(start=611, end=613, text='44', label='I-Quantity'),
#     AnnotatedToken(start=613, end=614, text=',', label='I-Quantity'),
#     AnnotatedToken(start=615, end=619, text='2614', label='I-Quantity'),
#     AnnotatedToken(start=619, end=620, text='.', label='I-Quantity'),
#     AnnotatedToken(start=620, end=622, text='73', label='I-Quantity'),
#     AnnotatedToken(start=622, end=623, text=',', label='I-Quantity'),
#     AnnotatedToken(start=624, end=627, text='and', label='I-Quantity'),
#     AnnotatedToken(start=628, end=632, text='2614', label='I-Quantity'),
#     AnnotatedToken(start=632, end=633, text='.', label='I-Quantity'),
#     AnnotatedToken(start=633, end=635, text='71', label='I-Quantity'),
#     AnnotatedToken(start=636, end=637, text='m', label='I-Quantity'),
#     AnnotatedToken(start=638, end=639, text='(', label='O'),
#     AnnotatedToken(start=639, end=648, text='indicated', label='O'),
#     AnnotatedToken(start=649, end=651, text='in', label='O'),
#     AnnotatedToken(start=652, end=655, text='Fig', label='O'),
#     AnnotatedToken(start=655, end=656, text='.', label='O')],
#    [AnnotatedToken(start=657, end=658, text='5', label='O'),
#     AnnotatedToken(start=658, end=659, text=')', label='O'),
#     AnnotatedToken(start=660, end=667, text='contain', label='O'),
#     AnnotatedToken(start=668, end=680, text='Apectodinium', label='O'),
#     AnnotatedToken(start=680, end=681, text=',', label='O'),
#     AnnotatedToken(start=682, end=684, text='in', label='O'),
#     AnnotatedToken(start=685, end=693, text='contrast', label='O'),
#     AnnotatedToken(start=694, end=696, text='to', label='O'),
#     AnnotatedToken(start=697, end=700, text='the', label='O'),
#     AnnotatedToken(start=701, end=706, text='other', label='O'),
#     AnnotatedToken(start=707, end=714, text='samples', label='O'),
#     AnnotatedToken(start=715, end=720, text='below', label='O'),
#     AnnotatedToken(start=721, end=724, text='the', label='O'),
#     AnnotatedToken(start=725, end=728, text='CIE', label='O'),
#     AnnotatedToken(start=729, end=730, text='(', label='O'),
#     AnnotatedToken(start=730, end=734, text='Figs', label='O'),
#     AnnotatedToken(start=734, end=735, text='.', label='O')],
#    [AnnotatedToken(start=736, end=737, text='3', label='O'),
#     AnnotatedToken(start=738, end=741, text='and', label='O'),
#     AnnotatedToken(start=742, end=743, text='7', label='O'),
#     AnnotatedToken(start=743, end=744, text=')', label='O'),
#     AnnotatedToken(start=744, end=745, text='.', label='O')],
#    [AnnotatedToken(start=746, end=750, text='Some', label='O'),
#     AnnotatedToken(start=751, end=753, text='of', label='O'),
#     AnnotatedToken(start=754, end=759, text='these', label='O'),
#     AnnotatedToken(start=760, end=767, text='samples', label='B-MeasuredEntity'),
#     AnnotatedToken(start=768, end=769, text='(', label='O'),
#     AnnotatedToken(start=769, end=773, text='2619', label='B-Quantity'),
#     AnnotatedToken(start=773, end=774, text='.', label='I-Quantity'),
#     AnnotatedToken(start=774, end=776, text='60', label='I-Quantity'),
#     AnnotatedToken(start=776, end=777, text=',', label='I-Quantity'),
#     AnnotatedToken(start=778, end=782, text='2614', label='I-Quantity'),
#     AnnotatedToken(start=782, end=783, text='.', label='I-Quantity'),
#     AnnotatedToken(start=783, end=785, text='73', label='I-Quantity'),
#     AnnotatedToken(start=785, end=786, text=',', label='I-Quantity'),
#     AnnotatedToken(start=787, end=790, text='and', label='I-Quantity'),
#     AnnotatedToken(start=791, end=795, text='2614', label='I-Quantity'),
#     AnnotatedToken(start=795, end=796, text='.', label='I-Quantity'),
#     AnnotatedToken(start=796, end=798, text='71', label='I-Quantity'),
#     AnnotatedToken(start=799, end=800, text='m', label='I-Quantity'),
#     AnnotatedToken(start=800, end=801, text=')', label='O'),
#     AnnotatedToken(start=802, end=806, text='also', label='O'),
#     AnnotatedToken(start=807, end=814, text='contain', label='O'),
#     AnnotatedToken(start=815, end=823, text='negative', label='O'),
#     AnnotatedToken(start=824, end=831, text='δ13CTOC', label='O'),
#     AnnotatedToken(start=831, end=832, text=',', label='O'),
#     AnnotatedToken(start=833, end=843, text='indicative', label='O'),
#     AnnotatedToken(start=844, end=846, text='of', label='O'),
#     AnnotatedToken(start=847, end=850, text='the', label='O'),
#     AnnotatedToken(start=851, end=854, text='CIE', label='O'),
#     AnnotatedToken(start=855, end=856, text='(', label='O'),
#     AnnotatedToken(start=856, end=859, text='Fig', label='O'),
#     AnnotatedToken(start=859, end=860, text='.', label='O')],
#    [AnnotatedToken(start=861, end=862, text='3', label='O'),
#     AnnotatedToken(start=862, end=863, text=')', label='O'),
#     AnnotatedToken(start=863, end=864, text='.', label='O')],
#    [AnnotatedToken(start=865, end=867, text='To', label='O'),
#     AnnotatedToken(start=868, end=872, text='test', label='O'),
#     AnnotatedToken(start=873, end=875, text='if', label='O'),
#     AnnotatedToken(start=876, end=886, text='coincident', label='O'),
#     AnnotatedToken(start=887, end=893, text='pollen', label='O'),
#     AnnotatedToken(start=894, end=897, text='and', label='O'),
#     AnnotatedToken(start=898, end=903, text='spore', label='O'),
#     AnnotatedToken(start=904, end=911, text='changes', label='O'),
#     AnnotatedToken(start=912, end=916, text='also', label='O'),
#     AnnotatedToken(start=917, end=922, text='occur', label='O'),
#     AnnotatedToken(start=923, end=925, text='in', label='O'),
#     AnnotatedToken(start=926, end=931, text='these', label='O'),
#     AnnotatedToken(start=932, end=939, text='samples', label='O'),
#     AnnotatedToken(start=939, end=940, text=',', label='O'),
#     AnnotatedToken(start=941, end=943, text='we', label='O'),
#     AnnotatedToken(start=944, end=948, text='used', label='O'),
#     AnnotatedToken(start=949, end=951, text='CA', label='O'),
#     AnnotatedToken(start=952, end=954, text='on', label='O'),
#     AnnotatedToken(start=955, end=958, text='the', label='O'),
#     AnnotatedToken(start=959, end=965, text='pollen', label='O'),
#     AnnotatedToken(start=966, end=969, text='and', label='O'),
#     AnnotatedToken(start=970, end=975, text='spore', label='O'),
#     AnnotatedToken(start=976, end=980, text='data', label='O'),
#     AnnotatedToken(start=981, end=985, text='only', label='O'),
#     AnnotatedToken(start=986, end=987, text='(', label='O'),
#     AnnotatedToken(start=987, end=990, text='Fig', label='O'),
#     AnnotatedToken(start=990, end=991, text='.', label='O')],
#    [AnnotatedToken(start=992, end=994, text='5a', label='O'),
#     AnnotatedToken(start=994, end=995, text=')', label='O'),
#     AnnotatedToken(start=995, end=996, text='.', label='O')],
#    [AnnotatedToken(start=997, end=1000, text='PA1', label='O'),
#     AnnotatedToken(start=1000, end=1001, text='–', label='O'),
#     AnnotatedToken(start=1001, end=1004, text='PA4', label='O'),
#     AnnotatedToken(start=1005, end=1006, text='(', label='O'),
#     AnnotatedToken(start=1006, end=1013, text='symbols', label='O'),
#     AnnotatedToken(start=1013, end=1014, text=')', label='O'),
#     AnnotatedToken(start=1015, end=1019, text='plot', label='O'),
#     AnnotatedToken(start=1020, end=1022, text='in', label='O'),
#     AnnotatedToken(start=1023, end=1031, text='clusters', label='O'),
#     AnnotatedToken(start=1031, end=1032, text=',', label='O'),
#     AnnotatedToken(start=1033, end=1043, text='signifying', label='O'),
#     AnnotatedToken(start=1044, end=1049, text='their', label='O'),
#     AnnotatedToken(start=1050, end=1063, text='palynological', label='O'),
#     AnnotatedToken(start=1064, end=1074, text='similarity', label='O'),
#     AnnotatedToken(start=1074, end=1075, text='.', label='O')],
#    [AnnotatedToken(start=1076, end=1079, text='The', label='O'),
#     AnnotatedToken(start=1080, end=1087, text='species', label='O'),
#     AnnotatedToken(start=1088, end=1092, text='most', label='O'),
#     AnnotatedToken(start=1093, end=1103, text='associated', label='O'),
#     AnnotatedToken(start=1104, end=1108, text='with', label='O'),
#     AnnotatedToken(start=1109, end=1111, text='an', label='O'),
#     AnnotatedToken(start=1112, end=1122, text='assemblage', label='O'),
#     AnnotatedToken(start=1123, end=1126, text='are', label='O'),
#     AnnotatedToken(start=1127, end=1136, text='clustered', label='O'),
#     AnnotatedToken(start=1137, end=1141, text='with', label='O'),
#     AnnotatedToken(start=1142, end=1145, text='the', label='O'),
#     AnnotatedToken(start=1146, end=1153, text='samples', label='O'),
#     AnnotatedToken(start=1154, end=1158, text='from', label='O'),
#     AnnotatedToken(start=1159, end=1163, text='that', label='O'),
#     AnnotatedToken(start=1164, end=1174, text='assemblage', label='O'),
#     AnnotatedToken(start=1174, end=1175, text='.', label='O')],
#    [AnnotatedToken(start=1176, end=1179, text='For', label='O'),
#     AnnotatedToken(start=1180, end=1187, text='example', label='O'),
#     AnnotatedToken(start=1187, end=1188, text=',', label='O'),
#     AnnotatedToken(start=1189, end=1209, text='Inaperturopollenites', label='O'),
#     AnnotatedToken(start=1210, end=1216, text='hiatus', label='O'),
#     AnnotatedToken(start=1217, end=1220, text='and', label='O'),
#     AnnotatedToken(start=1221, end=1230, text='bisaccate', label='O'),
#     AnnotatedToken(start=1231, end=1237, text='pollen', label='O'),
#     AnnotatedToken(start=1238, end=1239, text='(', label='O'),
#     AnnotatedToken(start=1239, end=1245, text='highly', label='O'),
#     AnnotatedToken(start=1246, end=1254, text='abundant', label='O'),
#     AnnotatedToken(start=1255, end=1261, text='before', label='O'),
#     AnnotatedToken(start=1262, end=1265, text='the', label='O'),
#     AnnotatedToken(start=1266, end=1269, text='CIE', label='O'),
#     AnnotatedToken(start=1269, end=1270, text=',', label='O'),
#     AnnotatedToken(start=1271, end=1274, text='Fig', label='O'),
#     AnnotatedToken(start=1274, end=1275, text='.', label='O')],
#    [AnnotatedToken(start=1276, end=1277, text='8', label='O'),
#     AnnotatedToken(start=1277, end=1278, text=')', label='O'),
#     AnnotatedToken(start=1279, end=1282, text='are', label='O'),
#     AnnotatedToken(start=1283, end=1287, text='high', label='O'),
#     AnnotatedToken(start=1288, end=1290, text='on', label='O'),
#     AnnotatedToken(start=1291, end=1295, text='axis', label='O'),
#     AnnotatedToken(start=1296, end=1297, text='1', label='O'),
#     AnnotatedToken(start=1298, end=1303, text='where', label='O'),
#     AnnotatedToken(start=1304, end=1307, text='the', label='O'),
#     AnnotatedToken(start=1308, end=1315, text='earlier', label='O'),
#     AnnotatedToken(start=1316, end=1323, text='samples', label='O'),
#     AnnotatedToken(start=1324, end=1328, text='from', label='O'),
#     AnnotatedToken(start=1329, end=1332, text='PA1', label='O'),
#     AnnotatedToken(start=1333, end=1336, text='and', label='O'),
#     AnnotatedToken(start=1337, end=1340, text='PA2', label='O'),
#     AnnotatedToken(start=1341, end=1346, text='occur', label='O'),
#     AnnotatedToken(start=1346, end=1347, text=',', label='O'),
#     AnnotatedToken(start=1348, end=1351, text='and', label='O'),
#     AnnotatedToken(start=1352, end=1367, text='Caryapollenites', label='O'),
#     AnnotatedToken(start=1368, end=1371, text='spp', label='O'),
#     AnnotatedToken(start=1371, end=1372, text='.', label='O')],
#    [AnnotatedToken(start=1373, end=1376, text='and', label='O'),
#     AnnotatedToken(start=1377, end=1383, text='fungal', label='O'),
#     AnnotatedToken(start=1384, end=1390, text='spores', label='O'),
#     AnnotatedToken(start=1391, end=1392, text='(', label='O'),
#     AnnotatedToken(start=1392, end=1400, text='abundant', label='O'),
#     AnnotatedToken(start=1401, end=1406, text='after', label='O'),
#     AnnotatedToken(start=1407, end=1410, text='the', label='O'),
#     AnnotatedToken(start=1411, end=1414, text='CIE', label='O'),
#     AnnotatedToken(start=1414, end=1415, text=',', label='O'),
#     AnnotatedToken(start=1416, end=1419, text='Fig', label='O'),
#     AnnotatedToken(start=1419, end=1420, text='.', label='O')],
#    [AnnotatedToken(start=1421, end=1422, text='8', label='O'),
#     AnnotatedToken(start=1422, end=1423, text=')', label='O'),
#     AnnotatedToken(start=1424, end=1427, text='are', label='O'),
#     AnnotatedToken(start=1428, end=1431, text='low', label='O'),
#     AnnotatedToken(start=1432, end=1434, text='on', label='O'),
#     AnnotatedToken(start=1435, end=1439, text='axis', label='O'),
#     AnnotatedToken(start=1440, end=1441, text='1', label='O'),
#     AnnotatedToken(start=1442, end=1446, text='near', label='O'),
#     AnnotatedToken(start=1447, end=1450, text='the', label='O'),
#     AnnotatedToken(start=1451, end=1458, text='younger', label='O'),
#     AnnotatedToken(start=1459, end=1466, text='samples', label='O'),
#     AnnotatedToken(start=1467, end=1471, text='from', label='O'),
#     AnnotatedToken(start=1472, end=1475, text='PA4', label='O'),
#     AnnotatedToken(start=1475, end=1476, text='.', label='O')],
#    [AnnotatedToken(start=1477, end=1480, text='The', label='O'),
#     AnnotatedToken(start=1481, end=1484, text='two', label='B-Quantity'),
#     AnnotatedToken(start=1485, end=1492, text='samples', label='B-MeasuredEntity'),
#     AnnotatedToken(start=1493, end=1497, text='2619', label='B-Quantity'),
#     AnnotatedToken(start=1497, end=1498, text='.', label='I-Quantity'),
#     AnnotatedToken(start=1498, end=1500, text='60', label='I-Quantity'),
#     AnnotatedToken(start=1501, end=1504, text='and', label='I-Quantity'),
#     AnnotatedToken(start=1505, end=1509, text='2614', label='I-Quantity'),
#     AnnotatedToken(start=1509, end=1510, text='.', label='I-Quantity'),
#     AnnotatedToken(start=1510, end=1512, text='71', label='I-Quantity'),
#     AnnotatedToken(start=1513, end=1517, text='have', label='O'),
#     AnnotatedToken(start=1518, end=1519, text='a', label='O'),
#     AnnotatedToken(start=1520, end=1525, text='spore', label='O'),
#     AnnotatedToken(start=1526, end=1529, text='and', label='O'),
#     AnnotatedToken(start=1530, end=1536, text='pollen', label='O'),
#     AnnotatedToken(start=1537, end=1550, text='palynological', label='O'),
#     AnnotatedToken(start=1551, end=1560, text='signature', label='O'),
#     AnnotatedToken(start=1561, end=1568, text='similar', label='O'),
#     AnnotatedToken(start=1569, end=1571, text='to', label='O'),
#     AnnotatedToken(start=1572, end=1579, text='samples', label='O'),
#     AnnotatedToken(start=1580, end=1584, text='from', label='O'),
#     AnnotatedToken(start=1585, end=1588, text='PA3', label='O'),
#     AnnotatedToken(start=1588, end=1590, text='/4', label='O'),
#     AnnotatedToken(start=1591, end=1597, text='during', label='O'),
#     AnnotatedToken(start=1598, end=1601, text='the', label='O'),
#     AnnotatedToken(start=1602, end=1605, text='CIE', label='O'),
#     AnnotatedToken(start=1606, end=1607, text='(', label='O'),
#     AnnotatedToken(start=1607, end=1611, text='plot', label='O'),
#     AnnotatedToken(start=1612, end=1617, text='lower', label='O'),
#     AnnotatedToken(start=1618, end=1620, text='on', label='O'),
#     AnnotatedToken(start=1621, end=1625, text='axis', label='O'),
#     AnnotatedToken(start=1626, end=1627, text='1', label='O'),
#     AnnotatedToken(start=1627, end=1628, text=')', label='O'),
#     AnnotatedToken(start=1629, end=1632, text='and', label='O'),
#     AnnotatedToken(start=1633, end=1636, text='are', label='O'),
#     AnnotatedToken(start=1637, end=1643, text='either', label='O'),
#     AnnotatedToken(start=1644, end=1647, text='not', label='O'),
#     AnnotatedToken(start=1648, end=1650, text='in', label='O'),
#     AnnotatedToken(start=1651, end=1654, text='the', label='O'),
#     AnnotatedToken(start=1655, end=1662, text='correct', label='O'),
#     AnnotatedToken(start=1663, end=1671, text='location', label='O'),
#     AnnotatedToken(start=1672, end=1673, text='(', label='O'),
#     AnnotatedToken(start=1673, end=1675, text='it', label='O'),
#     AnnotatedToken(start=1676, end=1682, text='cannot', label='O'),
#     AnnotatedToken(start=1683, end=1685, text='be', label='O'),
#     AnnotatedToken(start=1686, end=1696, text='discounted', label='O'),
#     AnnotatedToken(start=1697, end=1701, text='that', label='O'),
#     AnnotatedToken(start=1702, end=1707, text='these', label='O'),
#     AnnotatedToken(start=1708, end=1715, text='samples', label='O'),
#     AnnotatedToken(start=1716, end=1725, text='represent', label='O'),
#     AnnotatedToken(start=1726, end=1738, text='tectonically', label='O'),
#     AnnotatedToken(start=1739, end=1747, text='emplaced', label='O'),
#     AnnotatedToken(start=1748, end=1755, text='younger', label='O'),
#     AnnotatedToken(start=1756, end=1764, text='material', label='O'),
#     AnnotatedToken(start=1765, end=1766, text='(', label='O'),
#     AnnotatedToken(start=1766, end=1771, text='Payne', label='O'),
#     AnnotatedToken(start=1772, end=1774, text='et', label='O'),
#     AnnotatedToken(start=1775, end=1777, text='al', label='O'),
#     AnnotatedToken(start=1777, end=1778, text='.', label='O'),
#     AnnotatedToken(start=1778, end=1779, text=',', label='O'),
#     AnnotatedToken(start=1780, end=1784, text='2005', label='O'),
#     AnnotatedToken(start=1784, end=1785, text=')', label='O'),
#     AnnotatedToken(start=1785, end=1786, text=',', label='O'),
#     AnnotatedToken(start=1787, end=1789, text='or', label='O'),
#     AnnotatedToken(start=1790, end=1794, text='were', label='O'),
#     AnnotatedToken(start=1795, end=1804, text='misplaced', label='O'),
#     AnnotatedToken(start=1805, end=1811, text='during', label='O'),
#     AnnotatedToken(start=1812, end=1820, text='drilling', label='O'),
#     AnnotatedToken(start=1821, end=1831, text='operations', label='O'),
#     AnnotatedToken(start=1832, end=1836, text='core', label='O'),
#     AnnotatedToken(start=1837, end=1845, text='handling', label='O'),
#     AnnotatedToken(start=1845, end=1846, text=')', label='O'),
#     AnnotatedToken(start=1846, end=1847, text=',', label='O'),
#     AnnotatedToken(start=1848, end=1850, text='or', label='O'),
#     AnnotatedToken(start=1851, end=1860, text='represent', label='O'),
#     AnnotatedToken(start=1861, end=1865, text='very', label='O'),
#     AnnotatedToken(start=1866, end=1871, text='short', label='O'),
#     AnnotatedToken(start=1872, end=1880, text='episodes', label='O'),
#     AnnotatedToken(start=1881, end=1883, text='of', label='O'),
#     AnnotatedToken(start=1884, end=1888, text='both', label='O'),
#     AnnotatedToken(start=1889, end=1895, text='marine', label='O'),
#     AnnotatedToken(start=1896, end=1899, text='and', label='O'),
#     AnnotatedToken(start=1900, end=1911, text='terrestrial', label='O'),
#     AnnotatedToken(start=1912, end=1920, text='ecologic', label='O'),
#     AnnotatedToken(start=1921, end=1927, text='change', label='O'),
#     AnnotatedToken(start=1928, end=1930, text='to', label='O'),
#     AnnotatedToken(start=1931, end=1934, text='CIE', label='O'),
#     AnnotatedToken(start=1934, end=1935, text='-', label='O'),
#     AnnotatedToken(start=1935, end=1939, text='type', label='O'),
#     AnnotatedToken(start=1940, end=1950, text='conditions', label='O'),
#     AnnotatedToken(start=1950, end=1951, text='.', label='O')],
#    [AnnotatedToken(start=1952, end=1955, text='The', label='O'),
#     AnnotatedToken(start=1956, end=1961, text='rapid', label='O'),
#     AnnotatedToken(start=1962, end=1965, text='and', label='O'),
#     AnnotatedToken(start=1966, end=1975, text='transient', label='O'),
#     AnnotatedToken(start=1976, end=1982, text='nature', label='O'),
#     AnnotatedToken(start=1983, end=1985, text='of', label='O'),
#     AnnotatedToken(start=1986, end=1991, text='these', label='O'),
#     AnnotatedToken(start=1992, end=1995, text='two', label='O'),
#     AnnotatedToken(start=1996, end=2002, text='shifts', label='O'),
#     AnnotatedToken(start=2003, end=2010, text='appears', label='O'),
#     AnnotatedToken(start=2011, end=2013, text='to', label='O'),
#     AnnotatedToken(start=2014, end=2021, text='suggest', label='O'),
#     AnnotatedToken(start=2022, end=2026, text='that', label='O'),
#     AnnotatedToken(start=2027, end=2030, text='the', label='O'),
#     AnnotatedToken(start=2031, end=2037, text='latter', label='O'),
#     AnnotatedToken(start=2038, end=2049, text='explanation', label='O'),
#     AnnotatedToken(start=2050, end=2053, text='may', label='O'),
#     AnnotatedToken(start=2054, end=2056, text='be', label='O'),
#     AnnotatedToken(start=2057, end=2065, text='unlikely', label='O'),
#     AnnotatedToken(start=2065, end=2066, text=',', label='O'),
#     AnnotatedToken(start=2067, end=2070, text='and', label='O'),
#     AnnotatedToken(start=2071, end=2073, text='we', label='O'),
#     AnnotatedToken(start=2074, end=2078, text='have', label='O'),
#     AnnotatedToken(start=2079, end=2088, text='therefore', label='O'),
#     AnnotatedToken(start=2089, end=2095, text='shaded', label='O'),
#     AnnotatedToken(start=2096, end=2103, text='samples', label='O'),
#     AnnotatedToken(start=2104, end=2108, text='from', label='O'),
#     AnnotatedToken(start=2109, end=2114, text='these', label='O'),
#     AnnotatedToken(start=2115, end=2118, text='two', label='O'),
#     AnnotatedToken(start=2119, end=2125, text='depths', label='O'),
#     AnnotatedToken(start=2126, end=2128, text='in', label='O'),
#     AnnotatedToken(start=2129, end=2133, text='Figs', label='O'),
#     AnnotatedToken(start=2133, end=2134, text='.', label='O')],
#    [AnnotatedToken(start=2135, end=2136, text='3', label='O'),
#     AnnotatedToken(start=2136, end=2137, text=',', label='O'),
#     AnnotatedToken(start=2138, end=2139, text='6', label='O'),
#     AnnotatedToken(start=2139, end=2140, text='–', label='O'),
#     AnnotatedToken(start=2140, end=2141, text='9', label='O'),
#     AnnotatedToken(start=2141, end=2142, text='.', label='O')]]},
#  {'docId': 'S0012821X12004384-1405',
#   'sentAnnot': [[AnnotatedToken(start=0, end=14, text='Dinoflagellate', label='O'),
#     AnnotatedToken(start=15, end=20, text='cysts', label='O'),
#     AnnotatedToken(start=21, end=25, text='have', label='O'),
#     AnnotatedToken(start=26, end=30, text='been', label='O'),
#     AnnotatedToken(start=31, end=35, text='used', label='O'),
#     AnnotatedToken(start=36, end=47, text='extensively', label='O'),
#     AnnotatedToken(start=48, end=51, text='for', label='O'),
#     AnnotatedToken(start=52, end=66, text='reconstructing', label='O'),
#     AnnotatedToken(start=67, end=84, text='paleoenvironments', label='O'),
#     AnnotatedToken(start=85, end=87, text='in', label='O'),
#     AnnotatedToken(start=88, end=91, text='the', label='O'),
#     AnnotatedToken(start=92, end=101, text='Paleogene', label='O'),
#     AnnotatedToken(start=102, end=103, text='(', label='O'),
#     AnnotatedToken(start=103, end=106, text='see', label='O'),
#     AnnotatedToken(start=107, end=115, text='overview', label='O'),
#     AnnotatedToken(start=116, end=118, text='in', label='O'),
#     AnnotatedToken(start=119, end=125, text='Sluijs', label='O'),
#     AnnotatedToken(start=126, end=128, text='et', label='O'),
#     AnnotatedToken(start=129, end=131, text='al', label='O'),
#     AnnotatedToken(start=131, end=132, text='.', label='O'),
#     AnnotatedToken(start=132, end=133, text=',', label='O'),
#     AnnotatedToken(start=134, end=138, text='2005', label='O'),
#     AnnotatedToken(start=138, end=139, text=')', label='O'),
#     AnnotatedToken(start=139, end=140, text=',', label='O'),
#     AnnotatedToken(start=141, end=143, text='as', label='O'),
#     AnnotatedToken(start=144, end=148, text='they', label='O'),
#     AnnotatedToken(start=149, end=152, text='are', label='O'),
#     AnnotatedToken(start=153, end=165, text='particularly', label='O'),
#     AnnotatedToken(start=166, end=175, text='sensitive', label='O'),
#     AnnotatedToken(start=176, end=178, text='to', label='O'),
#     AnnotatedToken(start=179, end=186, text='changes', label='O'),
#     AnnotatedToken(start=187, end=189, text='in', label='O'),
#     AnnotatedToken(start=190, end=198, text='salinity', label='O'),
#     AnnotatedToken(start=198, end=199, text=',', label='O'),
#     AnnotatedToken(start=200, end=211, text='temperature', label='O'),
#     AnnotatedToken(start=211, end=212, text=',', label='O'),
#     AnnotatedToken(start=213, end=216, text='and', label='O'),
#     AnnotatedToken(start=217, end=225, text='nutrient', label='O'),
#     AnnotatedToken(start=226, end=232, text='levels', label='O'),
#     AnnotatedToken(start=233, end=234, text='(', label='O'),
#     AnnotatedToken(start=234, end=240, text='Powell', label='O'),
#     AnnotatedToken(start=241, end=243, text='et', label='O'),
#     AnnotatedToken(start=244, end=246, text='al', label='O'),
#     AnnotatedToken(start=246, end=247, text='.', label='O'),
#     AnnotatedToken(start=247, end=248, text=',', label='O'),
#     AnnotatedToken(start=249, end=253, text='1992', label='O'),
#     AnnotatedToken(start=253, end=254, text=';', label='O'),
#     AnnotatedToken(start=255, end=260, text='Pross', label='O'),
#     AnnotatedToken(start=261, end=264, text='and', label='O'),
#     AnnotatedToken(start=265, end=274, text='Brinkhuis', label='O'),
#     AnnotatedToken(start=275, end=279, text='2005', label='O'),
#     AnnotatedToken(start=279, end=280, text=';', label='O'),
#     AnnotatedToken(start=281, end=287, text='Sluijs', label='O'),
#     AnnotatedToken(start=288, end=290, text='et', label='O'),
#     AnnotatedToken(start=291, end=293, text='al', label='O'),
#     AnnotatedToken(start=293, end=294, text='.', label='O'),
#     AnnotatedToken(start=294, end=295, text=',', label='O'),
#     AnnotatedToken(start=296, end=300, text='2005', label='O'),
#     AnnotatedToken(start=300, end=301, text=')', label='O'),
#     AnnotatedToken(start=301, end=302, text='.', label='O')],
#    [AnnotatedToken(start=303, end=305, text='We', label='O'),
#     AnnotatedToken(start=306, end=315, text='calculate', label='O'),
#     AnnotatedToken(start=316, end=321, text='“%low', label='O'),
#     AnnotatedToken(start=322, end=330, text='salinity', label='O'),
#     AnnotatedToken(start=331, end=345, text='dinoflagellate', label='O'),
#     AnnotatedToken(start=346, end=351, text='cysts', label='O'),
#     AnnotatedToken(start=351, end=352, text='”', label='O'),
#     AnnotatedToken(start=353, end=354, text='(', label='O'),
#     AnnotatedToken(start=354, end=358, text='Figs', label='O'),
#     AnnotatedToken(start=358, end=359, text='.', label='O')],
#    [AnnotatedToken(start=360, end=361, text='7', label='O'),
#     AnnotatedToken(start=361, end=362, text='–', label='O'),
#     AnnotatedToken(start=362, end=363, text='9', label='O'),
#     AnnotatedToken(start=363, end=364, text=')', label='O'),
#     AnnotatedToken(start=365, end=367, text='by', label='O'),
#     AnnotatedToken(start=368, end=376, text='grouping', label='O'),
#     AnnotatedToken(start=377, end=382, text='cysts', label='O'),
#     AnnotatedToken(start=383, end=385, text='of', label='O'),
#     AnnotatedToken(start=386, end=393, text='similar', label='O'),
#     AnnotatedToken(start=394, end=402, text='inferred', label='O'),
#     AnnotatedToken(start=403, end=411, text='ecologic', label='O'),
#     AnnotatedToken(start=412, end=423, text='preferences', label='O'),
#     AnnotatedToken(start=424, end=425, text='(', label='O'),
#     AnnotatedToken(start=425, end=428, text='see', label='O'),
#     AnnotatedToken(start=429, end=432, text='Fig', label='O'),
#     AnnotatedToken(start=432, end=433, text='.', label='O')],
#    [AnnotatedToken(start=434, end=435, text='7', label='O'),
#     AnnotatedToken(start=435, end=436, text=',', label='O'),
#     AnnotatedToken(start=437, end=440, text='and', label='O'),
#     AnnotatedToken(start=441, end=451, text='discussion', label='O'),
#     AnnotatedToken(start=452, end=454, text='in', label='O'),
#     AnnotatedToken(start=455, end=458, text='the', label='O'),
#     AnnotatedToken(start=459, end=472, text='Supplementary', label='O'),
#     AnnotatedToken(start=473, end=481, text='Material', label='O'),
#     AnnotatedToken(start=481, end=482, text=')', label='O'),
#     AnnotatedToken(start=483, end=485, text='to', label='O'),
#     AnnotatedToken(start=486, end=493, text='provide', label='O'),
#     AnnotatedToken(start=494, end=496, text='an', label='O'),
#     AnnotatedToken(start=497, end=507, text='indication', label='O'),
#     AnnotatedToken(start=508, end=510, text='of', label='O'),
#     AnnotatedToken(start=511, end=524, text='environmental', label='O'),
#     AnnotatedToken(start=525, end=531, text='change', label='O'),
#     AnnotatedToken(start=531, end=532, text=',', label='O'),
#     AnnotatedToken(start=533, end=536, text='and', label='O'),
#     AnnotatedToken(start=537, end=539, text='by', label='O'),
#     AnnotatedToken(start=540, end=549, text='excluding', label='O'),
#     AnnotatedToken(start=550, end=557, text='species', label='O'),
#     AnnotatedToken(start=558, end=560, text='of', label='O'),
#     AnnotatedToken(start=561, end=570, text='uncertain', label='O'),
#     AnnotatedToken(start=571, end=579, text='affinity', label='O'),
#     AnnotatedToken(start=580, end=584, text='such', label='O'),
#     AnnotatedToken(start=585, end=587, text='as', label='O'),
#     AnnotatedToken(start=588, end=600, text='Apectodinium', label='O'),
#     AnnotatedToken(start=600, end=601, text='.', label='O')],
#    [AnnotatedToken(start=602, end=609, text='Samples', label='B-MeasuredEntity'),
#     AnnotatedToken(start=610, end=614, text='with', label='B-Qualifier'),
#     AnnotatedToken(start=615, end=620, text='fewer', label='I-Qualifier'),
#     AnnotatedToken(start=621, end=625, text='than', label='I-Qualifier'),
#     AnnotatedToken(start=626, end=628, text='20', label='I-Qualifier'),
#     AnnotatedToken(start=629, end=638, text='specimens', label='I-Qualifier'),
#     AnnotatedToken(start=639, end=643, text='were', label='I-Qualifier'),
#     AnnotatedToken(start=644, end=648, text='also', label='I-Qualifier'),
#     AnnotatedToken(start=649, end=657, text='excluded', label='I-Qualifier'),
#     AnnotatedToken(start=657, end=658, text='.', label='O')],
#    [AnnotatedToken(start=659, end=666, text='Despite', label='O'),
#     AnnotatedToken(start=667, end=670, text='the', label='O'),
#     AnnotatedToken(start=671, end=682, text='limitations', label='O'),
#     AnnotatedToken(start=683, end=685, text='of', label='O'),
#     AnnotatedToken(start=686, end=690, text='this', label='O'),
#     AnnotatedToken(start=691, end=697, text='method', label='O'),
#     AnnotatedToken(start=697, end=698, text=',', label='O'),
#     AnnotatedToken(start=699, end=702, text='the', label='O'),
#     AnnotatedToken(start=703, end=708, text='large', label='O'),
#     AnnotatedToken(start=709, end=718, text='variation', label='O'),
#     AnnotatedToken(start=719, end=721, text='in', label='O'),
#     AnnotatedToken(start=722, end=725, text='the', label='O'),
#     AnnotatedToken(start=726, end=730, text='%low', label='B-MeasuredProperty'),
#     AnnotatedToken(start=731, end=739, text='salinity', label='I-MeasuredProperty'),
#     AnnotatedToken(start=740, end=754, text='dinoflagellate', label='I-MeasuredProperty'),
#     AnnotatedToken(start=755, end=760, text='cysts', label='I-MeasuredProperty'),
#     AnnotatedToken(start=761, end=762, text='(', label='O'),
#     AnnotatedToken(start=762, end=769, text='ranging', label='O'),
#     AnnotatedToken(start=770, end=774, text='from', label='O'),
#     AnnotatedToken(start=775, end=776, text='0', label='B-Quantity'),
#     AnnotatedToken(start=776, end=777, text='%', label='I-Quantity'),
#     AnnotatedToken(start=778, end=780, text='to', label='I-Quantity'),
#     AnnotatedToken(start=781, end=783, text='80', label='I-Quantity'),
#     AnnotatedToken(start=783, end=785, text='%)', label='I-Quantity'),
#     AnnotatedToken(start=786, end=793, text='clearly', label='O'),
#     AnnotatedToken(start=794, end=803, text='indicates', label='O'),
#     AnnotatedToken(start=804, end=808, text='that', label='O'),
#     AnnotatedToken(start=809, end=820, text='significant', label='O'),
#     AnnotatedToken(start=821, end=834, text='environmental', label='O'),
#     AnnotatedToken(start=835, end=842, text='changes', label='O'),
#     AnnotatedToken(start=843, end=845, text='in', label='O'),
#     AnnotatedToken(start=846, end=853, text='surface', label='O'),
#     AnnotatedToken(start=854, end=859, text='water', label='O'),
#     AnnotatedToken(start=860, end=870, text='conditions', label='O'),
#     AnnotatedToken(start=871, end=879, text='occurred', label='O'),
#     AnnotatedToken(start=880, end=886, text='during', label='O'),
#     AnnotatedToken(start=887, end=890, text='the', label='O'),
#     AnnotatedToken(start=891, end=894, text='CIE', label='O'),
#     AnnotatedToken(start=895, end=900, text='onset', label='O'),
#     AnnotatedToken(start=901, end=903, text='in', label='O'),
#     AnnotatedToken(start=904, end=907, text='the', label='O'),
#     AnnotatedToken(start=908, end=915, text='central', label='O'),
#     AnnotatedToken(start=916, end=921, text='North', label='O'),
#     AnnotatedToken(start=922, end=925, text='Sea', label='O'),
#     AnnotatedToken(start=925, end=926, text=',', label='O'),
#     AnnotatedToken(start=927, end=930, text='and', label='O'),
#     AnnotatedToken(start=931, end=933, text='is', label='O'),
#     AnnotatedToken(start=934, end=943, text='supported', label='O'),
#     AnnotatedToken(start=944, end=946, text='by', label='O'),
#     AnnotatedToken(start=947, end=953, text='coeval', label='O'),
#     AnnotatedToken(start=954, end=961, text='changes', label='O'),
#     AnnotatedToken(start=962, end=964, text='in', label='O'),
#     AnnotatedToken(start=965, end=968, text='the', label='O'),
#     AnnotatedToken(start=969, end=980, text='sedimentary', label='O'),
#     AnnotatedToken(start=981, end=987, text='carbon', label='O'),
#     AnnotatedToken(start=987, end=996, text='/nitrogen', label='O'),
#     AnnotatedToken(start=997, end=998, text='(', label='O'),
#     AnnotatedToken(start=998, end=999, text='C', label='O'),
#     AnnotatedToken(start=999, end=1002, text='/N)', label='O'),
#     AnnotatedToken(start=1003, end=1008, text='ratio', label='O'),
#     AnnotatedToken(start=1009, end=1010, text='(', label='O'),
#     AnnotatedToken(start=1010, end=1013, text='Fig', label='O'),
#     AnnotatedToken(start=1013, end=1014, text='.', label='O')],
#    [AnnotatedToken(start=1015, end=1017, text='10', label='O'),
#     AnnotatedToken(start=1017, end=1018, text=')', label='O'),
#     AnnotatedToken(start=1019, end=1024, text='which', label='O'),
#     AnnotatedToken(start=1025, end=1033, text='reflects', label='O'),
#     AnnotatedToken(start=1034, end=1041, text='changes', label='O'),
#     AnnotatedToken(start=1042, end=1044, text='in', label='O'),
#     AnnotatedToken(start=1045, end=1048, text='the', label='O'),
#     AnnotatedToken(start=1049, end=1059, text='proportion', label='O'),
#     AnnotatedToken(start=1060, end=1062, text='of', label='O'),
#     AnnotatedToken(start=1063, end=1074, text='terrestrial', label='O'),
#     AnnotatedToken(start=1074, end=1081, text='/marine', label='O'),
#     AnnotatedToken(start=1082, end=1089, text='organic', label='O'),
#     AnnotatedToken(start=1090, end=1098, text='material', label='O'),
#     AnnotatedToken(start=1099, end=1108, text='deposited', label='O'),
#     AnnotatedToken(start=1109, end=1111, text='in', label='O'),
#     AnnotatedToken(start=1112, end=1115, text='the', label='O'),
#     AnnotatedToken(start=1116, end=1121, text='North', label='O'),
#     AnnotatedToken(start=1122, end=1125, text='Sea', label='O'),
#     AnnotatedToken(start=1126, end=1131, text='Basin', label='O'),
#     AnnotatedToken(start=1132, end=1135, text='due', label='O'),
#     AnnotatedToken(start=1136, end=1138, text='to', label='O'),
#     AnnotatedToken(start=1139, end=1150, text='terrestrial', label='O'),
#     AnnotatedToken(start=1151, end=1157, text='runoff', label='O'),
#     AnnotatedToken(start=1158, end=1161, text='and', label='O'),
#     AnnotatedToken(start=1162, end=1174, text='productivity', label='O'),
#     AnnotatedToken(start=1175, end=1176, text='(', label='O'),
#     AnnotatedToken(start=1176, end=1179, text='see', label='O'),
#     AnnotatedToken(start=1180, end=1187, text='Section', label='O'),
#     AnnotatedToken(start=1188, end=1189, text='4', label='O'),
#     AnnotatedToken(start=1189, end=1190, text='.', label='O'),
#     AnnotatedToken(start=1190, end=1191, text='4', label='O'),
#     AnnotatedToken(start=1191, end=1192, text=')', label='O'),
#     AnnotatedToken(start=1192, end=1193, text='.', label='O')]]},
#  {'docId': 'S0012821X12004384-1415',
#   'sentAnnot': [[AnnotatedToken(start=0, end=14, text='Dinoflagellate', label='B-MeasuredEntity'),
#     AnnotatedToken(start=15, end=19, text='cyst', label='I-MeasuredEntity'),
#     AnnotatedToken(start=20, end=30, text='assemblage', label='I-MeasuredEntity'),
#     AnnotatedToken(start=31, end=32, text='1', label='I-MeasuredEntity'),
#     AnnotatedToken(start=33, end=34, text='(', label='I-MeasuredEntity'),
#     AnnotatedToken(start=34, end=37, text='DA1', label='I-MeasuredEntity'),
#     AnnotatedToken(start=37, end=38, text=',', label='O'),
#     AnnotatedToken(start=39, end=43, text='from', label='B-Quantity'),
#     AnnotatedToken(start=44, end=48, text='2632', label='I-Quantity'),
#     AnnotatedToken(start=49, end=51, text='to', label='I-Quantity'),
#     AnnotatedToken(start=52, end=56, text='2618', label='I-Quantity'),
#     AnnotatedToken(start=57, end=58, text='m', label='I-Quantity'),
#     AnnotatedToken(start=58, end=59, text=',', label='O'),
#     AnnotatedToken(start=60, end=63, text='Fig', label='O'),
#     AnnotatedToken(start=63, end=64, text='.', label='O')],
#    [AnnotatedToken(start=65, end=67, text='7p', label='O'),
#     AnnotatedToken(start=67, end=68, text=')', label='O'),
#     AnnotatedToken(start=69, end=77, text='contains', label='O'),
#     AnnotatedToken(start=78, end=82, text='high', label='O'),
#     AnnotatedToken(start=83, end=94, text='proportions', label='O'),
#     AnnotatedToken(start=95, end=97, text='of', label='O'),
#     AnnotatedToken(start=98, end=107, text='typically', label='O'),
#     AnnotatedToken(start=108, end=112, text='open', label='O'),
#     AnnotatedToken(start=113, end=119, text='marine', label='O'),
#     AnnotatedToken(start=120, end=123, text='and', label='O'),
#     AnnotatedToken(start=124, end=129, text='hence', label='O'),
#     AnnotatedToken(start=130, end=136, text='normal', label='O'),
#     AnnotatedToken(start=137, end=143, text='marine', label='O'),
#     AnnotatedToken(start=144, end=152, text='salinity', label='O'),
#     AnnotatedToken(start=153, end=163, text='associated', label='O'),
#     AnnotatedToken(start=164, end=177, text='Achomosphaera', label='O'),
#     AnnotatedToken(start=177, end=190, text='/Spiniferites', label='O'),
#     AnnotatedToken(start=191, end=194, text='spp', label='O'),
#     AnnotatedToken(start=194, end=195, text='.', label='O'),
#     AnnotatedToken(start=195, end=196, text=',', label='O'),
#     AnnotatedToken(start=197, end=213, text='undifferentiated', label='O'),
#     AnnotatedToken(start=214, end=221, text='chorate', label='O'),
#     AnnotatedToken(start=222, end=227, text='cysts', label='O'),
#     AnnotatedToken(start=228, end=231, text='and', label='O'),
#     AnnotatedToken(start=232, end=242, text='Areoligera', label='O'),
#     AnnotatedToken(start=242, end=256, text='/Glaphyrocysta', label='O'),
#     AnnotatedToken(start=257, end=260, text='spp', label='O'),
#     AnnotatedToken(start=260, end=261, text='.', label='O')],
#    [AnnotatedToken(start=262, end=265, text='DA1', label='B-MeasuredEntity'),
#     AnnotatedToken(start=266, end=270, text='also', label='O'),
#     AnnotatedToken(start=271, end=279, text='contains', label='O'),
#     AnnotatedToken(start=280, end=282, text='on', label='B-Quantity'),
#     AnnotatedToken(start=283, end=290, text='average', label='I-Quantity'),
#     AnnotatedToken(start=291, end=292, text='5', label='I-Quantity'),
# ...
#     AnnotatedToken(start=1005, end=1008, text='may', label='O'),
#     AnnotatedToken(start=1009, end=1014, text='think', label='O'),
#     AnnotatedToken(start=1015, end=1020, text='their', label='O'),
#     AnnotatedToken(start=1021, end=1029, text='tinnitus', label='O'),
#     AnnotatedToken(start=1030, end=1032, text='is', label='O'),
#     AnnotatedToken(start=1033, end=1043, text='indicative', label='O'),
#     AnnotatedToken(start=1044, end=1046, text='of', label='O'),
#     AnnotatedToken(start=1047, end=1048, text='a', label='O'),
#     AnnotatedToken(start=1049, end=1053, text='more', label='O'),
#     AnnotatedToken(start=1054, end=1061, text='serious', label='O'),
#     AnnotatedToken(start=1062, end=1071, text='condition', label='O'),
#     AnnotatedToken(start=1072, end=1075, text='and', label='O'),
#     AnnotatedToken(start=1076, end=1085, text='therefore', label='O'),
#     AnnotatedToken(start=1086, end=1090, text='find', label='O'),
#     AnnotatedToken(start=1091, end=1094, text='the', label='O'),
#     AnnotatedToken(start=1095, end=1103, text='tinnitus', label='O'),
#     AnnotatedToken(start=1104, end=1108, text='more', label='O'),
#     AnnotatedToken(start=1109, end=1119, text='bothersome', label='O'),
#     AnnotatedToken(start=1119, end=1120, text='.', label='O')],
#    [AnnotatedToken(start=1121, end=1124, text='The', label='O'),
#     AnnotatedToken(start=1125, end=1132, text='finding', label='O'),
#     AnnotatedToken(start=1133, end=1137, text='that', label='O'),
#     AnnotatedToken(start=1138, end=1149, text='personality', label='O'),
#     AnnotatedToken(start=1150, end=1156, text='traits', label='O'),
#     AnnotatedToken(start=1157, end=1161, text='such', label='O'),
#     AnnotatedToken(start=1162, end=1164, text='as', label='O'),
#     AnnotatedToken(start=1165, end=1176, text='neuroticism', label='O'),
#     AnnotatedToken(start=1177, end=1180, text='can', label='O'),
#     AnnotatedToken(start=1181, end=1191, text='contribute', label='O'),
#     AnnotatedToken(start=1192, end=1194, text='to', label='O'),
#     AnnotatedToken(start=1195, end=1203, text='tinnitus', label='O'),
#     AnnotatedToken(start=1204, end=1213, text='awareness', label='O'),
#     AnnotatedToken(start=1214, end=1217, text='and', label='O'),
#     AnnotatedToken(start=1218, end=1226, text='distress', label='O'),
#     AnnotatedToken(start=1227, end=1229, text='is', label='O'),
#     AnnotatedToken(start=1230, end=1239, text='important', label='O'),
#     AnnotatedToken(start=1240, end=1244, text='when', label='O'),
#     AnnotatedToken(start=1245, end=1256, text='considering', label='O'),
#     AnnotatedToken(start=1257, end=1266, text='treatment', label='O'),
#     AnnotatedToken(start=1267, end=1277, text='approaches', label='O'),
#     AnnotatedToken(start=1278, end=1285, text='because', label='O'),
#     AnnotatedToken(start=1286, end=1297, text='personality', label='O'),
#     AnnotatedToken(start=1298, end=1304, text='traits', label='O'),
#     AnnotatedToken(start=1305, end=1308, text='are', label='O'),
#     AnnotatedToken(start=1309, end=1318, text='generally', label='O'),
#     AnnotatedToken(start=1319, end=1325, text='stable', label='O'),
#     AnnotatedToken(start=1326, end=1330, text='over', label='O'),
#     AnnotatedToken(start=1331, end=1335, text='time', label='O'),
#     AnnotatedToken(start=1336, end=1337, text='[', label='O'),
#     AnnotatedToken(start=1337, end=1339, text='41', label='O'),
#     AnnotatedToken(start=1339, end=1340, text=']', label='O'),
#     AnnotatedToken(start=1340, end=1341, text=',', label='O'),
#     AnnotatedToken(start=1342, end=1350, text='although', label='O'),
#     AnnotatedToken(start=1351, end=1354, text='the', label='O'),
#     AnnotatedToken(start=1355, end=1363, text='absolute', label='O'),
#     AnnotatedToken(start=1364, end=1369, text='level', label='O'),
#     AnnotatedToken(start=1370, end=1372, text='of', label='O'),
#     AnnotatedToken(start=1373, end=1384, text='personality', label='O'),
#     AnnotatedToken(start=1385, end=1391, text='traits', label='O'),
#     AnnotatedToken(start=1392, end=1395, text='can', label='O'),
#     AnnotatedToken(start=1396, end=1402, text='change', label='O'),
#     AnnotatedToken(start=1403, end=1404, text='[', label='O'),
#     AnnotatedToken(start=1404, end=1406, text='42', label='O'),
#     AnnotatedToken(start=1406, end=1407, text=']', label='O'),
#     AnnotatedToken(start=1407, end=1408, text='.', label='O')],
#    [AnnotatedToken(start=1409, end=1413, text='Thus', label='O'),
#     AnnotatedToken(start=1414, end=1416, text='it', label='O'),
#     AnnotatedToken(start=1417, end=1419, text='is', label='O'),
#     AnnotatedToken(start=1420, end=1428, text='possible', label='O'),
#     AnnotatedToken(start=1429, end=1433, text='that', label='O'),
#     AnnotatedToken(start=1434, end=1447, text='psychological', label='O'),
#     AnnotatedToken(start=1448, end=1461, text='interventions', label='O'),
#     AnnotatedToken(start=1462, end=1465, text='may', label='O'),
#     AnnotatedToken(start=1466, end=1468, text='be', label='O'),
#     AnnotatedToken(start=1469, end=1479, text='beneficial', label='O'),
#     AnnotatedToken(start=1480, end=1483, text='for', label='O'),
#     AnnotatedToken(start=1484, end=1492, text='tinnitus', label='O'),
#     AnnotatedToken(start=1493, end=1501, text='patients', label='O'),
#     AnnotatedToken(start=1502, end=1510, text='although', label='O'),
#     AnnotatedToken(start=1511, end=1514, text='the', label='O'),
#     AnnotatedToken(start=1515, end=1522, text='effects', label='O'),
#     AnnotatedToken(start=1523, end=1526, text='may', label='O'),
#     AnnotatedToken(start=1527, end=1529, text='be', label='O'),
#     AnnotatedToken(start=1530, end=1537, text='gradual', label='O'),
#     AnnotatedToken(start=1538, end=1539, text='[', label='O'),
#     AnnotatedToken(start=1539, end=1541, text='11', label='O'),
#     AnnotatedToken(start=1541, end=1542, text=']', label='O'),
#     AnnotatedToken(start=1542, end=1543, text='.', label='O')]]},
#  {'docId': 'S0022459611006116-1160',
#   'sentAnnot': [[AnnotatedToken(start=0, end=3, text='The', label='O'),
#     AnnotatedToken(start=4, end=11, text='ternary', label='O'),
#     AnnotatedToken(start=12, end=21, text='magnesium', label='O'),
#     AnnotatedToken(start=22, end=29, text='nitride', label='O'),
#     AnnotatedToken(start=30, end=39, text='fluorides', label='O'),
#     AnnotatedToken(start=40, end=44, text='were', label='O'),
#     AnnotatedToken(start=45, end=53, text='prepared', label='O'),
#     AnnotatedToken(start=54, end=56, text='by', label='O'),
#     AnnotatedToken(start=57, end=60, text='the', label='O'),
#     AnnotatedToken(start=61, end=65, text='high', label='O'),
#     AnnotatedToken(start=66, end=77, text='temperature', label='O'),
#     AnnotatedToken(start=78, end=83, text='solid', label='O'),
#     AnnotatedToken(start=84, end=89, text='state', label='O'),
#     AnnotatedToken(start=90, end=98, text='reaction', label='O'),
#     AnnotatedToken(start=99, end=101, text='of', label='O'),
#     AnnotatedToken(start=102, end=116, text='stoichiometric', label='O'),
#     AnnotatedToken(start=117, end=124, text='amounts', label='O'),
#     AnnotatedToken(start=125, end=127, text='of', label='O'),
#     AnnotatedToken(start=128, end=139, text='synthesised', label='O'),
#     AnnotatedToken(start=140, end=145, text='Mg3N2', label='O'),
#     AnnotatedToken(start=146, end=150, text='with', label='O'),
#     AnnotatedToken(start=151, end=160, text='anhydrous', label='B-MeasuredEntity'),
#     AnnotatedToken(start=161, end=165, text='MgF2', label='I-MeasuredEntity'),
#     AnnotatedToken(start=166, end=167, text='(', label='O'),
#     AnnotatedToken(start=167, end=174, text='Aldrich', label='O'),
#     AnnotatedToken(start=174, end=175, text=',', label='O'),
#     AnnotatedToken(start=176, end=178, text='99', label='B-Quantity'),
#     AnnotatedToken(start=178, end=179, text='.', label='I-Quantity'),
#     AnnotatedToken(start=179, end=180, text='9', label='I-Quantity'),
#     AnnotatedToken(start=180, end=183, text='%).', label='I-Quantity')],
#    [AnnotatedToken(start=184, end=187, text='All', label='O'),
#     AnnotatedToken(start=188, end=201, text='manipulations', label='O'),
#     AnnotatedToken(start=202, end=206, text='were', label='O'),
#     AnnotatedToken(start=207, end=214, text='carried', label='O'),
#     AnnotatedToken(start=215, end=218, text='out', label='O'),
#     AnnotatedToken(start=219, end=224, text='under', label='O'),
#     AnnotatedToken(start=225, end=230, text='inert', label='O'),
#     AnnotatedToken(start=231, end=239, text='nitrogen', label='O'),
#     AnnotatedToken(start=240, end=242, text='or', label='O'),
#     AnnotatedToken(start=243, end=248, text='argon', label='O'),
#     AnnotatedToken(start=249, end=260, text='atmospheres', label='O'),
#     AnnotatedToken(start=260, end=261, text='.', label='O')],
#    [AnnotatedToken(start=262, end=265, text='The', label='O'),
#     AnnotatedToken(start=266, end=277, text='appropriate', label='O'),
#     AnnotatedToken(start=278, end=279, text='1', label='B-Quantity'),
#     AnnotatedToken(start=279, end=281, text=':3', label='I-Quantity'),
#     AnnotatedToken(start=282, end=285, text='and', label='O'),
#     AnnotatedToken(start=286, end=287, text='1', label='B-Quantity'),
#     AnnotatedToken(start=287, end=289, text=':1', label='I-Quantity'),
#     AnnotatedToken(start=290, end=304, text='stoichiometric', label='B-MeasuredEntity'),
#     AnnotatedToken(start=305, end=310, text='molar', label='I-MeasuredEntity'),
#     AnnotatedToken(start=311, end=317, text='ratios', label='B-MeasuredProperty'),
#     AnnotatedToken(start=318, end=322, text='were', label='O'),
#     AnnotatedToken(start=323, end=327, text='used', label='O'),
#     AnnotatedToken(start=328, end=330, text='in', label='O'),
#     AnnotatedToken(start=331, end=334, text='the', label='O'),
#     AnnotatedToken(start=335, end=344, text='synthesis', label='O'),
#     AnnotatedToken(start=345, end=347, text='of', label='O'),
#     AnnotatedToken(start=348, end=354, text='Mg3NF3', label='B-Qualifier'),
#     AnnotatedToken(start=355, end=356, text='(', label='O'),
#     AnnotatedToken(start=356, end=357, text='1', label='O'),
#     AnnotatedToken(start=357, end=358, text=')', label='O'),
#     AnnotatedToken(start=359, end=362, text='and', label='O'),
#     AnnotatedToken(start=363, end=368, text='Mg2NF', label='B-Qualifier'),
#     AnnotatedToken(start=369, end=370, text='(', label='O'),
#     AnnotatedToken(start=370, end=371, text='2', label='O'),
#     AnnotatedToken(start=371, end=372, text=')', label='O'),
#     AnnotatedToken(start=373, end=385, text='respectively', label='O'),
#     AnnotatedToken(start=385, end=386, text=',', label='O'),
#     AnnotatedToken(start=387, end=389, text='as', label='O'),
#     AnnotatedToken(start=390, end=395, text='shown', label='O'),
#     AnnotatedToken(start=396, end=401, text='below', label='O'),
#     AnnotatedToken(start=401, end=444, text=':(1)Mg3N2+3MgF2→2Mg3NF3(2)Mg3N2+MgF2→2Mg2NF', label='O')]]},
#  {'docId': 'S0022459611006116-1195',
#   'sentAnnot': [[AnnotatedToken(start=0, end=3, text='All', label='O'),
#     AnnotatedToken(start=4, end=12, text='products', label='O'),
#     AnnotatedToken(start=13, end=17, text='were', label='O'),
#     AnnotatedToken(start=18, end=27, text='initially', label='O'),
#     AnnotatedToken(start=28, end=41, text='characterised', label='O'),
#     AnnotatedToken(start=42, end=44, text='by', label='O'),
#     AnnotatedToken(start=45, end=48, text='PXD', label='O'),
#     AnnotatedToken(start=48, end=49, text='.', label='O')],
#    [AnnotatedToken(start=50, end=54, text='Data', label='O'),
#     AnnotatedToken(start=55, end=59, text='were', label='O'),
#     AnnotatedToken(start=60, end=69, text='collected', label='O'),
#     AnnotatedToken(start=70, end=75, text='using', label='O'),
#     AnnotatedToken(start=76, end=77, text='a', label='O'),
#     AnnotatedToken(start=78, end=85, text='Philips', label='O'),
#     AnnotatedToken(start=86, end=87, text='X', label='O'),
#     AnnotatedToken(start=87, end=88, text='-', label='O'),
#     AnnotatedToken(start=88, end=92, text='pert', label='O'),
#     AnnotatedToken(start=93, end=107, text='diffractometer', label='O'),
#     AnnotatedToken(start=108, end=117, text='operating', label='O'),
#     AnnotatedToken(start=118, end=122, text='with', label='O'),
#     AnnotatedToken(start=123, end=127, text='CuKα', label='O'),
#     AnnotatedToken(start=128, end=137, text='radiation', label='O'),
#     AnnotatedToken(start=137, end=138, text='.', label='O')],
#    [AnnotatedToken(start=139, end=146, text='Initial', label='B-MeasuredEntity'),
#     AnnotatedToken(start=147, end=152, text='scans', label='I-MeasuredEntity'),
#     AnnotatedToken(start=153, end=157, text='were', label='O'),
#     AnnotatedToken(start=158, end=165, text='carried', label='O'),
#     AnnotatedToken(start=166, end=169, text='out', label='O'),
#     AnnotatedToken(start=170, end=174, text='from', label='O'),
#     AnnotatedToken(start=175, end=176, text='5', label='B-Quantity'),
#     AnnotatedToken(start=176, end=184, text='≤2θ/°≤80', label='I-Quantity'),
#     AnnotatedToken(start=185, end=189, text='with', label='O'),
#     AnnotatedToken(start=190, end=191, text='a', label='O'),
#     AnnotatedToken(start=192, end=196, text='step', label='B-MeasuredProperty'),
#     AnnotatedToken(start=197, end=201, text='size', label='I-MeasuredProperty'),
#     AnnotatedToken(start=202, end=204, text='of', label='O'),
#     AnnotatedToken(start=205, end=206, text='0', label='B-Quantity'),
#     AnnotatedToken(start=206, end=207, text='.', label='I-Quantity'),
#     AnnotatedToken(start=207, end=209, text='02', label='I-Quantity'),
#     AnnotatedToken(start=209, end=210, text='°', label='I-Quantity'),
#     AnnotatedToken(start=211, end=214, text='and', label='O'),
#     AnnotatedToken(start=215, end=216, text='a', label='O'),
#     AnnotatedToken(start=217, end=221, text='scan', label='B-MeasuredProperty'),
#     AnnotatedToken(start=222, end=226, text='time', label='I-MeasuredProperty'),
#     AnnotatedToken(start=227, end=229, text='of', label='O'),
#     AnnotatedToken(start=230, end=232, text='50', label='B-Quantity'),
#     AnnotatedToken(start=233, end=236, text='min', label='I-Quantity'),
#     AnnotatedToken(start=236, end=237, text='.', label='O')],
#    [AnnotatedToken(start=238, end=241, text='Due', label='O'),
#     AnnotatedToken(start=242, end=244, text='to', label='O'),
#     AnnotatedToken(start=245, end=248, text='the', label='O'),
#     AnnotatedToken(start=249, end=252, text='air', label='O'),
#     AnnotatedToken(start=252, end=253, text='-', label='O'),
#     AnnotatedToken(start=253, end=262, text='sensitive', label='O'),
#     AnnotatedToken(start=263, end=269, text='nature', label='O'),
#     AnnotatedToken(start=270, end=272, text='of', label='O'),
#     AnnotatedToken(start=273, end=276, text='the', label='O'),
#     AnnotatedToken(start=277, end=285, text='products', label='O'),
#     AnnotatedToken(start=285, end=286, text=',', label='O'),
#     AnnotatedToken(start=287, end=288, text='a', label='O'),
#     AnnotatedToken(start=289, end=298, text='dedicated', label='O'),
#     AnnotatedToken(start=299, end=302, text='air', label='O'),
#     AnnotatedToken(start=302, end=303, text='-', label='O'),
#     AnnotatedToken(start=303, end=308, text='tight', label='O'),
#     AnnotatedToken(start=309, end=318, text='aluminium', label='O'),
#     AnnotatedToken(start=319, end=325, text='sample', label='O'),
#     AnnotatedToken(start=326, end=332, text='holder', label='O'),
#     AnnotatedToken(start=333, end=337, text='with', label='O'),
#     AnnotatedToken(start=338, end=343, text='Mylar', label='O'),
#     AnnotatedToken(start=344, end=351, text='windows', label='O'),
#     AnnotatedToken(start=352, end=355, text='was', label='O'),
#     AnnotatedToken(start=356, end=364, text='employed', label='O'),
#     AnnotatedToken(start=365, end=366, text='[', label='O'),
#     AnnotatedToken(start=366, end=368, text='24', label='O'),
#     AnnotatedToken(start=368, end=369, text=']', label='O'),
#     AnnotatedToken(start=369, end=370, text='.', label='O')]]}]

# %%
# write the annotated NER training data into a file
f = open("trial.txt", "w", encoding='UTF-8')

for example in examples:
    annotated_sent = example['sentAnnot']
    for sent in annotated_sent:
        for token in sent:
            f.write(token.text + '\t' + token.label + '\n')
        f.write('\n')

f.close()

# %%
# count the number of sentences
num = 0
for example in examples:
    annotated_sent = example['sentAnnot']
    for sent in annotated_sent:
        num += 1
num
# Out:
# 519

# %% [markdown]
# ## unit tagging

# %%
# annotating tokens in each sentence for each doc

# examples = [exmaple]
# annotated_sent = [annotated_tokens[]]
# example = {
#     'docId': doc.docId,
#     'sentAnnot': annotated_sent
# }
import re

Token = namedtuple('Token', ['start', 'end', 'text'])
AnnotatedToken = namedtuple('AnnotatedToken', ['start', 'end', 'text', 'label'])

examples = []
for doc in docs.itertuples():
    doc_annotations = annotations[(annotations.docId == doc.docId) & (annotations.annotType == 'Quantity')]
#     print(doc)
#     print(doc_annotations)
    
    # get rows containing 'unit' in 'other' column
    idx_list = []
    for index, row in doc_annotations.reset_index(drop=True).iterrows():
        if row['other'].get('unit') != None:
            idx_list.append(index)
    doc_annotations = doc_annotations.iloc[idx_list]
#     print(doc_annotations)

#     # add column 'sentIdx' representing the index of a sentence where each quantity of the doc belongs to
#     sent_idx = []
#     for index, row in doc_annotations.iterrows():
#         # check whether the current quantity is within the range of the current sentence span
#         for i in range(len(doc.texts)):
#             sent = doc.texts[i]
#             isInRange = set(range(row.startOffset, row.endOffset)).intersection(set(range(sent.start, sent.end)))
#             if isInRange:
#                 sent_idx.append(i)
#     doc_annotations.loc[:, 'sentIdx'] = sent_idx
    
    # add columns 'unitStart' and 'unitEnd' in doc_annotations to mark the span of units
    unit_start = []
    for index, row in doc_annotations.iterrows():
        if re.compile(row['other'].get('unit')).search(row.text) != None:
            # 'unit' span is within the range of 'quantity' span: append its start offset
            s = re.compile(row['other'].get('unit')).search(row.text).span()[0] + row.startOffset
            unit_start.append(s)
        else:
            # 'unit' span is not within the range of 'quantity' span: ignore it 
            unit_start.append(-1)

            print(row)
            print(doc)
            print(doc_annotations)
    doc_annotations.loc[:, 'unitStart'] = unit_start
        
    # !!!!!!!!!
    unit_end = []
    for index, row in doc_annotations.iterrows():
        if re.compile(row['other'].get('unit')).search(row.text) != None:
            e = re.compile(row['other'].get('unit')).search(row.text).span()[1] + row.startOffset
            unit_end.append(e)
        else:
            unit_end.append(-1)
    doc_annotations.loc[:, 'unitEnd'] = unit_end
    #!!!!!!!!!
    
    # labeling each sentence
    annotated_sent = []
    for sent in doc.texts:
        # get the span of each token within the current sentence
        tokens = [
            Token(sent.start + start, sent.start + end, token)
            for (start, end), token in zip(
                tokenizer.span_tokenize(sent.text),
                tokenizer.tokenize(sent.text)
            )
        ]
        
#         print(sent)
#         for t in tokens:
#             print(t)
            
        # retrieve labels for each sentence
        AnnotatedSpan = namedtuple('AnnotatedSpan', ['start', 'end', 'label'])
        df = doc_annotations[(doc_annotations.unitStart >= sent.start) & (doc_annotations.unitEnd <= sent.end)]
        sent_labels = [AnnotatedSpan(r.unitStart, r.unitEnd, 'unit') for r in df.itertuples()]
#         for l in sent_labels:
#             print("sent_labels", l)
            
        annotated_tokens = []
        for token in tokens:
            # initialise the annotation tag for the current token as 'O'
            tag = 'O'
            #!!!!!!!!
            for sl in sent_labels:
                # check whether the current token is within the range of the current annotated span
                isInCurrRange = set(range(token.start, token.end)).intersection(set(range(sl.start, sl.end)))
                if isInCurrRange:
                    # choose not to use BIO tag due to some corner examples
                    # unit is within the span of a token (e.g. quantity='5≤2θ/°≤80', unit='°')
                    tag = 'unit'
#                     # check whether it's in the beginning (B) of the span
#                     if token.start == sl.start:
#                         tag = 'B-' + sl.label
#                     # otherwise, it's in the internal (I) of the span
#                     else:
#                         tag = 'I-' + sl.label
            #!!!!!!!!
            # append the annotated tag for the current token
            annotated_tokens.append(AnnotatedToken(token.start, token.end, token.text, tag))
        
#         for a in annotated_tokens:
#             print('annotated_tokens', a)
        
        if len(annotated_tokens) == len(tokens):
            annotated_sent.append(annotated_tokens)
    
#     for anns in annotated_sent:
#         for annt in anns:
#             print('annotated_tokens', annt)
            
    example = {
        'docId': doc.docId,
        'sentAnnot': annotated_sent
    }
    examples.append(example)
# Out:
# cnt 0
# docId          S0016236113008041-3171
# annotSet                            2
# annotType                    Quantity
# startOffset                       325
# endOffset                         327
# annotId                        T102-2
# text                               22
# other                 {'unit': 'ppm'}
# Name: 238, dtype: object
# Pandas(Index=17, docId='S0016236113008041-3171', text='Fig. 6 shows the concentrations of minor elements in the solid sorbent, where increasing bed inventory resulted in increasing values observed for Co, Ni, Cu, Mo, Cd, and Sn. In the case of Cu and Sn, values were obtained that were lower than that of the blank for a bed inventory of 4.5 kg, which then increased to values of 22 and 0.22 ppm respectively for 13 kg. In the case of Gd, Dy and U, small decreases in concentration were found for an increasing inventory, however values are low at <1 ppm and the changes observed are small. The remaining elements (Zr, Le, Ce, Pt, and Nd) recorded an increase in concentration for 6 kg over 4.5 kg, and then a decrease from 6 kg to 13 kg. All minor element flue gas concentrations were <0.1 ppm and therefore considered negligible.', texts=[Sentence(start=0, end=4, text='Fig.'), Sentence(start=5, end=173, text='6 shows the concentrations of minor elements in the solid sorbent, where increasing bed inventory resulted in increasing values observed for Co, Ni, Cu, Mo, Cd, and Sn.'), Sentence(start=174, end=364, text='In the case of Cu and Sn, values were obtained that were lower than that of the blank for a bed inventory of 4.5 kg, which then increased to values of 22 and 0.22 ppm respectively for 13 kg.'), Sentence(start=365, end=535, text='In the case of Gd, Dy and U, small decreases in concentration were found for an increasing inventory, however values are low at <1 ppm and the changes observed are small.'), Sentence(start=536, end=683, text='The remaining elements (Zr, Le, Ce, Pt, and Nd) recorded an increase in concentration for 6 kg over 4.5 kg, and then a decrease from 6 kg to 13 kg.'), Sentence(start=684, end=776, text='All minor element flue gas concentrations were <0.1 ppm and therefore considered negligible.')])
#                       docId  annotSet annotType  startOffset  endOffset  \
# 236  S0016236113008041-3171         1  Quantity          283        289
# 238  S0016236113008041-3171         2  Quantity          325        327
# 242  S0016236113008041-3171         3  Quantity          332        340
# 246  S0016236113008041-3171         4  Quantity          358        363
# 248  S0016236113008041-3171         5  Quantity          493        499
# 251  S0016236113008041-3171         6  Quantity          626        642
# 253  S0016236113008041-3171         7  Quantity          669        682
# 255  S0016236113008041-3171         8  Quantity          731        739
#
#      annotId              text                                 other
# 236    T31-1            4.5 kg                        {'unit': 'kg'}
# 238   T102-2                22                       {'unit': 'ppm'}
# 242   T253-3          0.22 ppm                       {'unit': 'ppm'}
# 246    T24-4             13 kg                        {'unit': 'kg'}
# 248    T45-5            <1 ppm  {'mods': ['IsRange'], 'unit': 'ppm'}
# 251    T86-6  6 kg over 4.5 kg                        {'unit': 'kg'}
# 253    T58-7     6 kg to 13 kg    {'mods': ['IsList'], 'unit': 'kg'}
# 255  T2110-8          <0.1 ppm  {'mods': ['IsRange'], 'unit': 'ppm'}
# cnt 0
# docId          S0016236113008041-3186
# annotSet                            2
# annotType                    Quantity
# startOffset                       196
# endOffset                         200
# annotId                         T52-2
# text                             0.06
# other                 {'unit': 'ppm'}
# Name: 261, dtype: object
# Pandas(Index=18, docId='S0016236113008041-3186', text='Fig. 7 shows solid concentrations of trace elements, of which only Rb, Nb and W were found at concentrations greater than 0.1 ppm. W showed the greatest change, with concentration increasing from 0.06 to 0.42 to 0.74 ppm for inventories 4.5, 6 and 13 kg respectively. All trace element flue gas concentrations were found at a concentration of <0.1 ppm and therefore considered negligible.', texts=[Sentence(start=0, end=4, text='Fig.'), Sentence(start=5, end=130, text='7 shows solid concentrations of trace elements, of which only Rb, Nb and W were found at concentrations greater than 0.1 ppm.'), Sentence(start=131, end=267, text='W showed the greatest change, with concentration increasing from 0.06 to 0.42 to 0.74 ppm for inventories 4.5, 6 and 13 kg respectively.'), Sentence(start=268, end=388, text='All trace element flue gas concentrations were found at a concentration of <0.1 ppm and therefore considered negligible.')])
#                       docId  annotSet annotType  startOffset  endOffset  \
# 258  S0016236113008041-3186         1  Quantity          109        129
# 261  S0016236113008041-3186         2  Quantity          196        200
# 265  S0016236113008041-3186         3  Quantity          204        208
# 269  S0016236113008041-3186         4  Quantity          212        220
# 273  S0016236113008041-3186         5  Quantity          237        253
# 275  S0016236113008041-3186         6  Quantity          343        351
#
#     annotId                  text                                 other
# 258   T11-1  greater than 0.1 ppm  {'mods': ['IsRange'], 'unit': 'ppm'}
# 261   T52-2                  0.06                       {'unit': 'ppm'}
# 265   T63-3                  0.42                       {'unit': 'ppm'}
# 269   T24-4              0.74 ppm                       {'unit': 'ppm'}
# 273   T75-5      4.5, 6 and 13 kg                        {'unit': 'kg'}
# 275   T48-6              <0.1 ppm  {'mods': ['IsRange'], 'unit': 'ppm'}
# cnt 0
# docId          S0016236113008041-3186
# annotSet                            3
# annotType                    Quantity
# startOffset                       204
# endOffset                         208
# annotId                         T63-3
# text                             0.42
# other                 {'unit': 'ppm'}
# Name: 265, dtype: object
# Pandas(Index=18, docId='S0016236113008041-3186', text='Fig. 7 shows solid concentrations of trace elements, of which only Rb, Nb and W were found at concentrations greater than 0.1 ppm. W showed the greatest change, with concentration increasing from 0.06 to 0.42 to 0.74 ppm for inventories 4.5, 6 and 13 kg respectively. All trace element flue gas concentrations were found at a concentration of <0.1 ppm and therefore considered negligible.', texts=[Sentence(start=0, end=4, text='Fig.'), Sentence(start=5, end=130, text='7 shows solid concentrations of trace elements, of which only Rb, Nb and W were found at concentrations greater than 0.1 ppm.'), Sentence(start=131, end=267, text='W showed the greatest change, with concentration increasing from 0.06 to 0.42 to 0.74 ppm for inventories 4.5, 6 and 13 kg respectively.'), Sentence(start=268, end=388, text='All trace element flue gas concentrations were found at a concentration of <0.1 ppm and therefore considered negligible.')])
#                       docId  annotSet annotType  startOffset  endOffset  \
# 258  S0016236113008041-3186         1  Quantity          109        129
# 261  S0016236113008041-3186         2  Quantity          196        200
# 265  S0016236113008041-3186         3  Quantity          204        208
# 269  S0016236113008041-3186         4  Quantity          212        220
# 273  S0016236113008041-3186         5  Quantity          237        253
# 275  S0016236113008041-3186         6  Quantity          343        351
#
#     annotId                  text                                 other
# 258   T11-1  greater than 0.1 ppm  {'mods': ['IsRange'], 'unit': 'ppm'}
# 261   T52-2                  0.06                       {'unit': 'ppm'}
# 265   T63-3                  0.42                       {'unit': 'ppm'}
# 269   T24-4              0.74 ppm                       {'unit': 'ppm'}
# 273   T75-5      4.5, 6 and 13 kg                        {'unit': 'kg'}
# 275   T48-6              <0.1 ppm  {'mods': ['IsRange'], 'unit': 'ppm'}
# cnt 0
# docId          S0016236113008041-3269
# annotSet                           10
# annotType                    Quantity
# startOffset                       989
# endOffset                         992
# annotId                      T1510-10
# text                              9.4
# other                 {'unit': 'ppm'}
# Name: 314, dtype: object
# Pandas(Index=20, docId='S0016236113008041-3269', text='Fig. 9 shows that increasing SO2 concentration has some effect on major element concentration in solids. Concentrations of Mg, Al, Si, P, K, Br, Sr, Y, Ba and Pb appear to decrease as SO2 concentration increases. However, there appears to be little difference between concentrations for 1000 and 2000 ppm, the greatest change in concentration being from 0 to 1000 ppm SO2. The trend in the batch experiments whereby concentrations of elements at 1000 ppm were generally lower than at 0 and 2000 ppm, is also seen for some elements in the looping cycle test including Cr, Mn and Fe, but not to the same extent as was seen in the batch tests. Ti shows the same trend for these tests as for single column tests, with 1000 ppm SO2 showing higher concentrations of Ti (135 ppm for single column, 407 ppm for looping test) compared to 0 and 2000 ppm SO2 at values close to 10 ppm Ti in both tests. Zn is the only major element showing a clear increase in concentration with SO2, increasing from 9.4 to 14.1 to 66.8 ppm for SO2 concentrations of 0, 1000 and 2000 ppm respectively.', texts=[Sentence(start=0, end=4, text='Fig.'), Sentence(start=5, end=104, text='9 shows that increasing SO2 concentration has some effect on major element concentration in solids.'), Sentence(start=105, end=212, text='Concentrations of Mg, Al, Si, P, K, Br, Sr, Y, Ba and Pb appear to decrease as SO2 concentration increases.'), Sentence(start=213, end=372, text='However, there appears to be little difference between concentrations for 1000 and 2000 ppm, the greatest change in concentration being from 0 to 1000 ppm SO2.'), Sentence(start=373, end=640, text='The trend in the batch experiments whereby concentrations of elements at 1000 ppm were generally lower than at 0 and 2000 ppm, is also seen for some elements in the looping cycle test including Cr, Mn and Fe, but not to the same extent as was seen in the batch tests.'), Sentence(start=641, end=891, text='Ti shows the same trend for these tests as for single column tests, with 1000 ppm SO2 showing higher concentrations of Ti (135 ppm for single column, 407 ppm for looping test) compared to 0 and 2000 ppm SO2 at values close to 10 ppm Ti in both tests.'), Sentence(start=892, end=1073, text='Zn is the only major element showing a clear increase in concentration with SO2, increasing from 9.4 to 14.1 to 66.8 ppm for SO2 concentrations of 0, 1000 and 2000 ppm respectively.')])
#                       docId  annotSet annotType  startOffset  endOffset  \
# 281  S0016236113008041-3269         1  Quantity          287        304
# 284  S0016236113008041-3269         2  Quantity          354        367
# 287  S0016236113008041-3269         3  Quantity          446        454
# 290  S0016236113008041-3269         4  Quantity          484        498
# 293  S0016236113008041-3269         5  Quantity          714        722
# 296  S0016236113008041-3269         6  Quantity          764        771
# 301  S0016236113008041-3269         7  Quantity          791        798
# 306  S0016236113008041-3269         8  Quantity          829        843
# 309  S0016236113008041-3269         9  Quantity          858        873
# 314  S0016236113008041-3269        10  Quantity          989        992
# 318  S0016236113008041-3269        11  Quantity          996       1000
# 322  S0016236113008041-3269        12  Quantity         1004       1012
# 326  S0016236113008041-3269        13  Quantity         1039       1059
#
#       annotId                  text  \
# 281     T41-1     1000 and 2000 ppm
# 284     T32-2         0 to 1000 ppm
# 287     T53-3              1000 ppm
# 290     T64-4        0 and 2000 ppm
# 293     T75-5              1000 ppm
# 296     T96-6               135 ppm
# 301    T117-7               407 ppm
# 306     T88-8        0 and 2000 ppm
# 309    T109-9       close to 10 ppm
# 314  T1510-10                   9.4
# 318  T1611-11                  14.1
# 322   T112-12              66.8 ppm
# 326  T1713-13  0, 1000 and 2000 ppm
#
#                                           other
# 281         {'mods': ['IsList'], 'unit': 'ppm'}
# 284        {'mods': ['IsRange'], 'unit': 'ppm'}
# 287                             {'unit': 'ppm'}
# 290         {'mods': ['IsList'], 'unit': 'ppm'}
# 293                             {'unit': 'ppm'}
# 296                             {'unit': 'ppm'}
# 301                             {'unit': 'ppm'}
# 306         {'mods': ['IsList'], 'unit': 'ppm'}
# 309  {'mods': ['IsApproximate'], 'unit': 'ppm'}
# 314                             {'unit': 'ppm'}
# 318                             {'unit': 'ppm'}
# 322                             {'unit': 'ppm'}
# 326                             {'unit': 'ppm'}
# cnt 0
# docId          S0016236113008041-3269
# annotSet                           11
# annotType                    Quantity
# startOffset                       996
# endOffset                        1000
# annotId                      T1611-11
# text                             14.1
# other                 {'unit': 'ppm'}
# Name: 318, dtype: object
# Pandas(Index=20, docId='S0016236113008041-3269', text='Fig. 9 shows that increasing SO2 concentration has some effect on major element concentration in solids. Concentrations of Mg, Al, Si, P, K, Br, Sr, Y, Ba and Pb appear to decrease as SO2 concentration increases. However, there appears to be little difference between concentrations for 1000 and 2000 ppm, the greatest change in concentration being from 0 to 1000 ppm SO2. The trend in the batch experiments whereby concentrations of elements at 1000 ppm were generally lower than at 0 and 2000 ppm, is also seen for some elements in the looping cycle test including Cr, Mn and Fe, but not to the same extent as was seen in the batch tests. Ti shows the same trend for these tests as for single column tests, with 1000 ppm SO2 showing higher concentrations of Ti (135 ppm for single column, 407 ppm for looping test) compared to 0 and 2000 ppm SO2 at values close to 10 ppm Ti in both tests. Zn is the only major element showing a clear increase in concentration with SO2, increasing from 9.4 to 14.1 to 66.8 ppm for SO2 concentrations of 0, 1000 and 2000 ppm respectively.', texts=[Sentence(start=0, end=4, text='Fig.'), Sentence(start=5, end=104, text='9 shows that increasing SO2 concentration has some effect on major element concentration in solids.'), Sentence(start=105, end=212, text='Concentrations of Mg, Al, Si, P, K, Br, Sr, Y, Ba and Pb appear to decrease as SO2 concentration increases.'), Sentence(start=213, end=372, text='However, there appears to be little difference between concentrations for 1000 and 2000 ppm, the greatest change in concentration being from 0 to 1000 ppm SO2.'), Sentence(start=373, end=640, text='The trend in the batch experiments whereby concentrations of elements at 1000 ppm were generally lower than at 0 and 2000 ppm, is also seen for some elements in the looping cycle test including Cr, Mn and Fe, but not to the same extent as was seen in the batch tests.'), Sentence(start=641, end=891, text='Ti shows the same trend for these tests as for single column tests, with 1000 ppm SO2 showing higher concentrations of Ti (135 ppm for single column, 407 ppm for looping test) compared to 0 and 2000 ppm SO2 at values close to 10 ppm Ti in both tests.'), Sentence(start=892, end=1073, text='Zn is the only major element showing a clear increase in concentration with SO2, increasing from 9.4 to 14.1 to 66.8 ppm for SO2 concentrations of 0, 1000 and 2000 ppm respectively.')])
#                       docId  annotSet annotType  startOffset  endOffset  \
# 281  S0016236113008041-3269         1  Quantity          287        304
# 284  S0016236113008041-3269         2  Quantity          354        367
# 287  S0016236113008041-3269         3  Quantity          446        454
# 290  S0016236113008041-3269         4  Quantity          484        498
# 293  S0016236113008041-3269         5  Quantity          714        722
# 296  S0016236113008041-3269         6  Quantity          764        771
# 301  S0016236113008041-3269         7  Quantity          791        798
# 306  S0016236113008041-3269         8  Quantity          829        843
# 309  S0016236113008041-3269         9  Quantity          858        873
# 314  S0016236113008041-3269        10  Quantity          989        992
# 318  S0016236113008041-3269        11  Quantity          996       1000
# 322  S0016236113008041-3269        12  Quantity         1004       1012
# 326  S0016236113008041-3269        13  Quantity         1039       1059
#
#       annotId                  text  \
# 281     T41-1     1000 and 2000 ppm
# 284     T32-2         0 to 1000 ppm
# 287     T53-3              1000 ppm
# 290     T64-4        0 and 2000 ppm
# 293     T75-5              1000 ppm
# 296     T96-6               135 ppm
# 301    T117-7               407 ppm
# 306     T88-8        0 and 2000 ppm
# 309    T109-9       close to 10 ppm
# 314  T1510-10                   9.4
# 318  T1611-11                  14.1
# 322   T112-12              66.8 ppm
# 326  T1713-13  0, 1000 and 2000 ppm
#
#                                           other
# 281         {'mods': ['IsList'], 'unit': 'ppm'}
# 284        {'mods': ['IsRange'], 'unit': 'ppm'}
# 287                             {'unit': 'ppm'}
# 290         {'mods': ['IsList'], 'unit': 'ppm'}
# 293                             {'unit': 'ppm'}
# 296                             {'unit': 'ppm'}
# 301                             {'unit': 'ppm'}
# 306         {'mods': ['IsList'], 'unit': 'ppm'}
# 309  {'mods': ['IsApproximate'], 'unit': 'ppm'}
# 314                             {'unit': 'ppm'}
# 318                             {'unit': 'ppm'}
# 322                             {'unit': 'ppm'}
# 326                             {'unit': 'ppm'}
# cnt 0
# docId          S0016236113008041-3290
# annotSet                            2
# annotType                    Quantity
# startOffset                       203
# endOffset                         207
# annotId                         T52-2
# text                             0.63
# other                 {'unit': 'ppm'}
# Name: 332, dtype: object
# Pandas(Index=21, docId='S0016236113008041-3290', text='Fig. 10 shows how gaseous major element concentrations were affected by flue gas SO2 concentration. Concentrations of all were very low at <1 ppm, with Fe and Si present in the highest concentrations at 0.63 and 0.51 ppm respectively. For several elements, 1000 ppm SO2 resulted in either the highest concentrations, as was the case for Na, Al, and Si, or the lowest concentrations, as was the case for Fe, when compared to 0 and 2000 ppm SO2.', texts=[Sentence(start=0, end=4, text='Fig.'), Sentence(start=5, end=99, text='10 shows how gaseous major element concentrations were affected by flue gas SO2 concentration.'), Sentence(start=100, end=234, text='Concentrations of all were very low at <1 ppm, with Fe and Si present in the highest concentrations at 0.63 and 0.51 ppm respectively.'), Sentence(start=235, end=443, text='For several elements, 1000 ppm SO2 resulted in either the highest concentrations, as was the case for Na, Al, and Si, or the lowest concentrations, as was the case for Fe, when compared to 0 and 2000 ppm SO2.')])
#                       docId  annotSet annotType  startOffset  endOffset  \
# 329  S0016236113008041-3290         1  Quantity          139        145
# 332  S0016236113008041-3290         2  Quantity          203        207
# 335  S0016236113008041-3290         3  Quantity          212        220
# 338  S0016236113008041-3290         4  Quantity          257        265
# 340  S0016236113008041-3290         5  Quantity          424        438
#
#     annotId            text                                 other
# 329   T11-1          <1 ppm  {'mods': ['IsRange'], 'unit': 'ppm'}
# 332   T52-2            0.63                       {'unit': 'ppm'}
# 335   T23-3        0.51 ppm                       {'unit': 'ppm'}
# 338   T34-4        1000 ppm                       {'unit': 'ppm'}
# 340   T45-5  0 and 2000 ppm   {'mods': ['IsList'], 'unit': 'ppm'}

# %%
examples
# Out:
# [{'docId': 'S0012821X12004384-1302',
#   'sentAnnot': [[AnnotatedToken(start=0, end=14, text='Correspondence', label='O'),
#     AnnotatedToken(start=15, end=23, text='analysis', label='O'),
#     AnnotatedToken(start=24, end=25, text='(', label='O'),
#     AnnotatedToken(start=25, end=27, text='CA', label='O'),
#     AnnotatedToken(start=27, end=28, text=')', label='O'),
#     AnnotatedToken(start=29, end=32, text='and', label='O'),
#     AnnotatedToken(start=33, end=44, text='statistical', label='O'),
#     AnnotatedToken(start=45, end=54, text='diversity', label='O'),
#     AnnotatedToken(start=55, end=63, text='analysis', label='O'),
#     AnnotatedToken(start=64, end=68, text='were', label='O'),
#     AnnotatedToken(start=69, end=76, text='carried', label='O'),
#     AnnotatedToken(start=77, end=80, text='out', label='O'),
#     AnnotatedToken(start=81, end=83, text='on', label='O'),
#     AnnotatedToken(start=84, end=87, text='the', label='O'),
#     AnnotatedToken(start=88, end=101, text='palynological', label='O'),
#     AnnotatedToken(start=102, end=109, text='dataset', label='O'),
#     AnnotatedToken(start=110, end=111, text='(', label='O'),
#     AnnotatedToken(start=111, end=116, text='total', label='O'),
#     AnnotatedToken(start=117, end=123, text='counts', label='O'),
#     AnnotatedToken(start=124, end=127, text='per', label='O'),
#     AnnotatedToken(start=128, end=132, text='gram', label='O'),
#     AnnotatedToken(start=132, end=133, text=')', label='O'),
#     AnnotatedToken(start=134, end=136, text='to', label='O'),
#     AnnotatedToken(start=137, end=144, text='confirm', label='O'),
#     AnnotatedToken(start=145, end=155, text='assemblage', label='O'),
#     AnnotatedToken(start=156, end=168, text='designations', label='O'),
#     AnnotatedToken(start=169, end=170, text='(', label='O'),
#     AnnotatedToken(start=170, end=174, text='Figs', label='O'),
#     AnnotatedToken(start=174, end=175, text='.', label='O')],
#    [AnnotatedToken(start=176, end=177, text='4', label='O'),
#     AnnotatedToken(start=178, end=181, text='and', label='O'),
#     AnnotatedToken(start=182, end=183, text='5', label='O'),
#     AnnotatedToken(start=183, end=184, text=')', label='O'),
#     AnnotatedToken(start=184, end=185, text=',', label='O'),
#     AnnotatedToken(start=186, end=188, text='to', label='O'),
#     AnnotatedToken(start=189, end=197, text='identify', label='O'),
#     AnnotatedToken(start=198, end=201, text='any', label='O'),
#     AnnotatedToken(start=202, end=213, text='disturbance', label='O'),
#     AnnotatedToken(start=214, end=216, text='to', label='O'),
#     AnnotatedToken(start=217, end=220, text='the', label='O'),
#     AnnotatedToken(start=221, end=225, text='core', label='O'),
#     AnnotatedToken(start=226, end=231, text='prior', label='O'),
#     AnnotatedToken(start=232, end=234, text='to', label='O'),
#     AnnotatedToken(start=235, end=249, text='interpretation', label='O'),
#     AnnotatedToken(start=249, end=250, text=',', label='O'),
#     AnnotatedToken(start=251, end=254, text='and', label='O'),
#     AnnotatedToken(start=255, end=257, text='to', label='O'),
#     AnnotatedToken(start=258, end=266, text='estimate', label='O'),
#     AnnotatedToken(start=267, end=276, text='diversity', label='O'),
#     AnnotatedToken(start=277, end=278, text='(', label='O'),
#     AnnotatedToken(start=278, end=281, text='Fig', label='O'),
#     AnnotatedToken(start=281, end=282, text='.', label='O')],
#    [AnnotatedToken(start=283, end=284, text='6', label='O'),
#     AnnotatedToken(start=284, end=285, text=')', label='O'),
#     AnnotatedToken(start=285, end=286, text='.', label='O')],
#    [AnnotatedToken(start=287, end=301, text='Dinoflagellate', label='O'),
#     AnnotatedToken(start=302, end=306, text='cyst', label='O'),
#     AnnotatedToken(start=307, end=318, text='assemblages', label='O'),
#     AnnotatedToken(start=319, end=320, text='(', label='O'),
#     AnnotatedToken(start=320, end=323, text='DA1', label='O'),
#     AnnotatedToken(start=323, end=324, text='–', label='O'),
#     AnnotatedToken(start=324, end=327, text='DA5', label='O'),
#     AnnotatedToken(start=327, end=328, text=')', label='O'),
#     AnnotatedToken(start=329, end=332, text='and', label='O'),
#     AnnotatedToken(start=333, end=339, text='pollen', label='O'),
#     AnnotatedToken(start=340, end=351, text='assemblages', label='O'),
#     AnnotatedToken(start=352, end=353, text='(', label='O'),
#     AnnotatedToken(start=353, end=356, text='PA1', label='O'),
#     AnnotatedToken(start=356, end=357, text='–', label='O'),
#     AnnotatedToken(start=357, end=360, text='PA4', label='O'),
#     AnnotatedToken(start=360, end=361, text=')', label='O'),
#     AnnotatedToken(start=362, end=366, text='were', label='O'),
#     AnnotatedToken(start=367, end=374, text='defined', label='O'),
#     AnnotatedToken(start=375, end=377, text='by', label='O'),
#     AnnotatedToken(start=378, end=386, text='visually', label='O'),
#     AnnotatedToken(start=387, end=396, text='comparing', label='O'),
#     AnnotatedToken(start=397, end=404, text='changes', label='O'),
#     AnnotatedToken(start=405, end=407, text='in', label='O'),
#     AnnotatedToken(start=408, end=411, text='the', label='O'),
#     AnnotatedToken(start=412, end=419, text='species', label='O'),
#     AnnotatedToken(start=420, end=429, text='dominance', label='O'),
#     AnnotatedToken(start=430, end=431, text='(', label='O'),
#     AnnotatedToken(start=431, end=435, text='Figs', label='O'),
#     AnnotatedToken(start=435, end=436, text='.', label='O')],
#    [AnnotatedToken(start=437, end=438, text='7', label='O'),
#     AnnotatedToken(start=439, end=442, text='and', label='O'),
#     AnnotatedToken(start=443, end=444, text='8', label='O'),
#     AnnotatedToken(start=444, end=445, text=')', label='O'),
#     AnnotatedToken(start=445, end=446, text=',', label='O'),
#     AnnotatedToken(start=447, end=450, text='and', label='O'),
#     AnnotatedToken(start=451, end=460, text='confirmed', label='O'),
#     AnnotatedToken(start=461, end=463, text='by', label='O'),
#     AnnotatedToken(start=464, end=466, text='CA', label='O'),
#     AnnotatedToken(start=467, end=468, text='(', label='O'),
#     AnnotatedToken(start=468, end=471, text='Fig', label='O'),
#     AnnotatedToken(start=471, end=472, text='.', label='O')],
#    [AnnotatedToken(start=473, end=474, text='4', label='O'),
#     AnnotatedToken(start=474, end=475, text=')', label='O'),
#     AnnotatedToken(start=476, end=481, text='using', label='O'),
#     AnnotatedToken(start=482, end=485, text='the', label='O'),
#     AnnotatedToken(start=486, end=491, text='first', label='O'),
#     AnnotatedToken(start=492, end=497, text='three', label='O'),
#     AnnotatedToken(start=498, end=502, text='axes', label='O'),
#     AnnotatedToken(start=503, end=504, text='(', label='O'),
#     AnnotatedToken(start=504, end=514, text='describing', label='O'),
#     AnnotatedToken(start=515, end=518, text='the', label='O'),
#     AnnotatedToken(start=519, end=526, text='highest', label='O'),
#     AnnotatedToken(start=527, end=538, text='percentages', label='O'),
#     AnnotatedToken(start=539, end=541, text='of', label='O'),
#     AnnotatedToken(start=542, end=550, text='variance', label='O'),
#     AnnotatedToken(start=550, end=551, text=')', label='O'),
#     AnnotatedToken(start=551, end=552, text='.', label='O')],
#    [AnnotatedToken(start=553, end=557, text='Five', label='O'),
#     AnnotatedToken(start=558, end=565, text='samples', label='O'),
#     AnnotatedToken(start=566, end=570, text='from', label='O'),
#     AnnotatedToken(start=571, end=576, text='below', label='O'),
#     AnnotatedToken(start=577, end=580, text='the', label='O'),
#     AnnotatedToken(start=581, end=584, text='CIE', label='O'),
#     AnnotatedToken(start=585, end=587, text='at', label='O'),
#     AnnotatedToken(start=588, end=592, text='2619', label='O'),
#     AnnotatedToken(start=592, end=593, text='.', label='O'),
#     AnnotatedToken(start=593, end=595, text='60', label='O'),
#     AnnotatedToken(start=595, end=596, text=',', label='O'),
#     AnnotatedToken(start=597, end=601, text='2617', label='O'),
#     AnnotatedToken(start=601, end=602, text='.', label='O'),
#     AnnotatedToken(start=602, end=604, text='35', label='O'),
#     AnnotatedToken(start=604, end=605, text=',', label='O'),
#     AnnotatedToken(start=606, end=610, text='2617', label='O'),
#     AnnotatedToken(start=610, end=611, text='.', label='O'),
#     AnnotatedToken(start=611, end=613, text='44', label='O'),
#     AnnotatedToken(start=613, end=614, text=',', label='O'),
#     AnnotatedToken(start=615, end=619, text='2614', label='O'),
#     AnnotatedToken(start=619, end=620, text='.', label='O'),
#     AnnotatedToken(start=620, end=622, text='73', label='O'),
#     AnnotatedToken(start=622, end=623, text=',', label='O'),
#     AnnotatedToken(start=624, end=627, text='and', label='O'),
#     AnnotatedToken(start=628, end=632, text='2614', label='O'),
#     AnnotatedToken(start=632, end=633, text='.', label='O'),
#     AnnotatedToken(start=633, end=635, text='71', label='O'),
#     AnnotatedToken(start=636, end=637, text='m', label='unit'),
#     AnnotatedToken(start=638, end=639, text='(', label='O'),
#     AnnotatedToken(start=639, end=648, text='indicated', label='O'),
#     AnnotatedToken(start=649, end=651, text='in', label='O'),
#     AnnotatedToken(start=652, end=655, text='Fig', label='O'),
#     AnnotatedToken(start=655, end=656, text='.', label='O')],
#    [AnnotatedToken(start=657, end=658, text='5', label='O'),
#     AnnotatedToken(start=658, end=659, text=')', label='O'),
#     AnnotatedToken(start=660, end=667, text='contain', label='O'),
#     AnnotatedToken(start=668, end=680, text='Apectodinium', label='O'),
#     AnnotatedToken(start=680, end=681, text=',', label='O'),
#     AnnotatedToken(start=682, end=684, text='in', label='O'),
#     AnnotatedToken(start=685, end=693, text='contrast', label='O'),
#     AnnotatedToken(start=694, end=696, text='to', label='O'),
#     AnnotatedToken(start=697, end=700, text='the', label='O'),
#     AnnotatedToken(start=701, end=706, text='other', label='O'),
#     AnnotatedToken(start=707, end=714, text='samples', label='O'),
#     AnnotatedToken(start=715, end=720, text='below', label='O'),
#     AnnotatedToken(start=721, end=724, text='the', label='O'),
#     AnnotatedToken(start=725, end=728, text='CIE', label='O'),
#     AnnotatedToken(start=729, end=730, text='(', label='O'),
#     AnnotatedToken(start=730, end=734, text='Figs', label='O'),
#     AnnotatedToken(start=734, end=735, text='.', label='O')],
#    [AnnotatedToken(start=736, end=737, text='3', label='O'),
#     AnnotatedToken(start=738, end=741, text='and', label='O'),
#     AnnotatedToken(start=742, end=743, text='7', label='O'),
#     AnnotatedToken(start=743, end=744, text=')', label='O'),
#     AnnotatedToken(start=744, end=745, text='.', label='O')],
#    [AnnotatedToken(start=746, end=750, text='Some', label='O'),
#     AnnotatedToken(start=751, end=753, text='of', label='O'),
#     AnnotatedToken(start=754, end=759, text='these', label='O'),
#     AnnotatedToken(start=760, end=767, text='samples', label='O'),
#     AnnotatedToken(start=768, end=769, text='(', label='O'),
#     AnnotatedToken(start=769, end=773, text='2619', label='O'),
#     AnnotatedToken(start=773, end=774, text='.', label='O'),
#     AnnotatedToken(start=774, end=776, text='60', label='O'),
#     AnnotatedToken(start=776, end=777, text=',', label='O'),
#     AnnotatedToken(start=778, end=782, text='2614', label='O'),
#     AnnotatedToken(start=782, end=783, text='.', label='O'),
#     AnnotatedToken(start=783, end=785, text='73', label='O'),
#     AnnotatedToken(start=785, end=786, text=',', label='O'),
#     AnnotatedToken(start=787, end=790, text='and', label='O'),
#     AnnotatedToken(start=791, end=795, text='2614', label='O'),
#     AnnotatedToken(start=795, end=796, text='.', label='O'),
#     AnnotatedToken(start=796, end=798, text='71', label='O'),
#     AnnotatedToken(start=799, end=800, text='m', label='unit'),
#     AnnotatedToken(start=800, end=801, text=')', label='O'),
#     AnnotatedToken(start=802, end=806, text='also', label='O'),
#     AnnotatedToken(start=807, end=814, text='contain', label='O'),
#     AnnotatedToken(start=815, end=823, text='negative', label='O'),
#     AnnotatedToken(start=824, end=831, text='δ13CTOC', label='O'),
#     AnnotatedToken(start=831, end=832, text=',', label='O'),
#     AnnotatedToken(start=833, end=843, text='indicative', label='O'),
#     AnnotatedToken(start=844, end=846, text='of', label='O'),
#     AnnotatedToken(start=847, end=850, text='the', label='O'),
#     AnnotatedToken(start=851, end=854, text='CIE', label='O'),
#     AnnotatedToken(start=855, end=856, text='(', label='O'),
#     AnnotatedToken(start=856, end=859, text='Fig', label='O'),
#     AnnotatedToken(start=859, end=860, text='.', label='O')],
#    [AnnotatedToken(start=861, end=862, text='3', label='O'),
#     AnnotatedToken(start=862, end=863, text=')', label='O'),
#     AnnotatedToken(start=863, end=864, text='.', label='O')],
#    [AnnotatedToken(start=865, end=867, text='To', label='O'),
#     AnnotatedToken(start=868, end=872, text='test', label='O'),
#     AnnotatedToken(start=873, end=875, text='if', label='O'),
#     AnnotatedToken(start=876, end=886, text='coincident', label='O'),
#     AnnotatedToken(start=887, end=893, text='pollen', label='O'),
#     AnnotatedToken(start=894, end=897, text='and', label='O'),
#     AnnotatedToken(start=898, end=903, text='spore', label='O'),
#     AnnotatedToken(start=904, end=911, text='changes', label='O'),
#     AnnotatedToken(start=912, end=916, text='also', label='O'),
#     AnnotatedToken(start=917, end=922, text='occur', label='O'),
#     AnnotatedToken(start=923, end=925, text='in', label='O'),
#     AnnotatedToken(start=926, end=931, text='these', label='O'),
#     AnnotatedToken(start=932, end=939, text='samples', label='O'),
#     AnnotatedToken(start=939, end=940, text=',', label='O'),
#     AnnotatedToken(start=941, end=943, text='we', label='O'),
#     AnnotatedToken(start=944, end=948, text='used', label='O'),
#     AnnotatedToken(start=949, end=951, text='CA', label='O'),
#     AnnotatedToken(start=952, end=954, text='on', label='O'),
#     AnnotatedToken(start=955, end=958, text='the', label='O'),
#     AnnotatedToken(start=959, end=965, text='pollen', label='O'),
#     AnnotatedToken(start=966, end=969, text='and', label='O'),
#     AnnotatedToken(start=970, end=975, text='spore', label='O'),
#     AnnotatedToken(start=976, end=980, text='data', label='O'),
#     AnnotatedToken(start=981, end=985, text='only', label='O'),
#     AnnotatedToken(start=986, end=987, text='(', label='O'),
#     AnnotatedToken(start=987, end=990, text='Fig', label='O'),
#     AnnotatedToken(start=990, end=991, text='.', label='O')],
#    [AnnotatedToken(start=992, end=994, text='5a', label='O'),
#     AnnotatedToken(start=994, end=995, text=')', label='O'),
#     AnnotatedToken(start=995, end=996, text='.', label='O')],
#    [AnnotatedToken(start=997, end=1000, text='PA1', label='O'),
#     AnnotatedToken(start=1000, end=1001, text='–', label='O'),
#     AnnotatedToken(start=1001, end=1004, text='PA4', label='O'),
#     AnnotatedToken(start=1005, end=1006, text='(', label='O'),
#     AnnotatedToken(start=1006, end=1013, text='symbols', label='O'),
#     AnnotatedToken(start=1013, end=1014, text=')', label='O'),
#     AnnotatedToken(start=1015, end=1019, text='plot', label='O'),
#     AnnotatedToken(start=1020, end=1022, text='in', label='O'),
#     AnnotatedToken(start=1023, end=1031, text='clusters', label='O'),
#     AnnotatedToken(start=1031, end=1032, text=',', label='O'),
#     AnnotatedToken(start=1033, end=1043, text='signifying', label='O'),
#     AnnotatedToken(start=1044, end=1049, text='their', label='O'),
#     AnnotatedToken(start=1050, end=1063, text='palynological', label='O'),
#     AnnotatedToken(start=1064, end=1074, text='similarity', label='O'),
#     AnnotatedToken(start=1074, end=1075, text='.', label='O')],
#    [AnnotatedToken(start=1076, end=1079, text='The', label='O'),
#     AnnotatedToken(start=1080, end=1087, text='species', label='O'),
#     AnnotatedToken(start=1088, end=1092, text='most', label='O'),
#     AnnotatedToken(start=1093, end=1103, text='associated', label='O'),
#     AnnotatedToken(start=1104, end=1108, text='with', label='O'),
#     AnnotatedToken(start=1109, end=1111, text='an', label='O'),
#     AnnotatedToken(start=1112, end=1122, text='assemblage', label='O'),
#     AnnotatedToken(start=1123, end=1126, text='are', label='O'),
#     AnnotatedToken(start=1127, end=1136, text='clustered', label='O'),
#     AnnotatedToken(start=1137, end=1141, text='with', label='O'),
#     AnnotatedToken(start=1142, end=1145, text='the', label='O'),
#     AnnotatedToken(start=1146, end=1153, text='samples', label='O'),
#     AnnotatedToken(start=1154, end=1158, text='from', label='O'),
#     AnnotatedToken(start=1159, end=1163, text='that', label='O'),
#     AnnotatedToken(start=1164, end=1174, text='assemblage', label='O'),
#     AnnotatedToken(start=1174, end=1175, text='.', label='O')],
#    [AnnotatedToken(start=1176, end=1179, text='For', label='O'),
#     AnnotatedToken(start=1180, end=1187, text='example', label='O'),
#     AnnotatedToken(start=1187, end=1188, text=',', label='O'),
#     AnnotatedToken(start=1189, end=1209, text='Inaperturopollenites', label='O'),
#     AnnotatedToken(start=1210, end=1216, text='hiatus', label='O'),
#     AnnotatedToken(start=1217, end=1220, text='and', label='O'),
#     AnnotatedToken(start=1221, end=1230, text='bisaccate', label='O'),
#     AnnotatedToken(start=1231, end=1237, text='pollen', label='O'),
#     AnnotatedToken(start=1238, end=1239, text='(', label='O'),
#     AnnotatedToken(start=1239, end=1245, text='highly', label='O'),
#     AnnotatedToken(start=1246, end=1254, text='abundant', label='O'),
#     AnnotatedToken(start=1255, end=1261, text='before', label='O'),
#     AnnotatedToken(start=1262, end=1265, text='the', label='O'),
#     AnnotatedToken(start=1266, end=1269, text='CIE', label='O'),
#     AnnotatedToken(start=1269, end=1270, text=',', label='O'),
#     AnnotatedToken(start=1271, end=1274, text='Fig', label='O'),
#     AnnotatedToken(start=1274, end=1275, text='.', label='O')],
#    [AnnotatedToken(start=1276, end=1277, text='8', label='O'),
#     AnnotatedToken(start=1277, end=1278, text=')', label='O'),
#     AnnotatedToken(start=1279, end=1282, text='are', label='O'),
#     AnnotatedToken(start=1283, end=1287, text='high', label='O'),
#     AnnotatedToken(start=1288, end=1290, text='on', label='O'),
#     AnnotatedToken(start=1291, end=1295, text='axis', label='O'),
#     AnnotatedToken(start=1296, end=1297, text='1', label='O'),
#     AnnotatedToken(start=1298, end=1303, text='where', label='O'),
#     AnnotatedToken(start=1304, end=1307, text='the', label='O'),
#     AnnotatedToken(start=1308, end=1315, text='earlier', label='O'),
#     AnnotatedToken(start=1316, end=1323, text='samples', label='O'),
#     AnnotatedToken(start=1324, end=1328, text='from', label='O'),
#     AnnotatedToken(start=1329, end=1332, text='PA1', label='O'),
#     AnnotatedToken(start=1333, end=1336, text='and', label='O'),
#     AnnotatedToken(start=1337, end=1340, text='PA2', label='O'),
#     AnnotatedToken(start=1341, end=1346, text='occur', label='O'),
#     AnnotatedToken(start=1346, end=1347, text=',', label='O'),
#     AnnotatedToken(start=1348, end=1351, text='and', label='O'),
#     AnnotatedToken(start=1352, end=1367, text='Caryapollenites', label='O'),
#     AnnotatedToken(start=1368, end=1371, text='spp', label='O'),
#     AnnotatedToken(start=1371, end=1372, text='.', label='O')],
#    [AnnotatedToken(start=1373, end=1376, text='and', label='O'),
#     AnnotatedToken(start=1377, end=1383, text='fungal', label='O'),
#     AnnotatedToken(start=1384, end=1390, text='spores', label='O'),
#     AnnotatedToken(start=1391, end=1392, text='(', label='O'),
#     AnnotatedToken(start=1392, end=1400, text='abundant', label='O'),
#     AnnotatedToken(start=1401, end=1406, text='after', label='O'),
#     AnnotatedToken(start=1407, end=1410, text='the', label='O'),
#     AnnotatedToken(start=1411, end=1414, text='CIE', label='O'),
#     AnnotatedToken(start=1414, end=1415, text=',', label='O'),
#     AnnotatedToken(start=1416, end=1419, text='Fig', label='O'),
#     AnnotatedToken(start=1419, end=1420, text='.', label='O')],
#    [AnnotatedToken(start=1421, end=1422, text='8', label='O'),
#     AnnotatedToken(start=1422, end=1423, text=')', label='O'),
#     AnnotatedToken(start=1424, end=1427, text='are', label='O'),
#     AnnotatedToken(start=1428, end=1431, text='low', label='O'),
#     AnnotatedToken(start=1432, end=1434, text='on', label='O'),
#     AnnotatedToken(start=1435, end=1439, text='axis', label='O'),
#     AnnotatedToken(start=1440, end=1441, text='1', label='O'),
#     AnnotatedToken(start=1442, end=1446, text='near', label='O'),
#     AnnotatedToken(start=1447, end=1450, text='the', label='O'),
#     AnnotatedToken(start=1451, end=1458, text='younger', label='O'),
#     AnnotatedToken(start=1459, end=1466, text='samples', label='O'),
#     AnnotatedToken(start=1467, end=1471, text='from', label='O'),
#     AnnotatedToken(start=1472, end=1475, text='PA4', label='O'),
#     AnnotatedToken(start=1475, end=1476, text='.', label='O')],
#    [AnnotatedToken(start=1477, end=1480, text='The', label='O'),
#     AnnotatedToken(start=1481, end=1484, text='two', label='O'),
#     AnnotatedToken(start=1485, end=1492, text='samples', label='O'),
#     AnnotatedToken(start=1493, end=1497, text='2619', label='O'),
#     AnnotatedToken(start=1497, end=1498, text='.', label='O'),
#     AnnotatedToken(start=1498, end=1500, text='60', label='O'),
#     AnnotatedToken(start=1501, end=1504, text='and', label='O'),
#     AnnotatedToken(start=1505, end=1509, text='2614', label='O'),
#     AnnotatedToken(start=1509, end=1510, text='.', label='O'),
#     AnnotatedToken(start=1510, end=1512, text='71', label='O'),
#     AnnotatedToken(start=1513, end=1517, text='have', label='O'),
#     AnnotatedToken(start=1518, end=1519, text='a', label='O'),
#     AnnotatedToken(start=1520, end=1525, text='spore', label='O'),
#     AnnotatedToken(start=1526, end=1529, text='and', label='O'),
#     AnnotatedToken(start=1530, end=1536, text='pollen', label='O'),
#     AnnotatedToken(start=1537, end=1550, text='palynological', label='O'),
#     AnnotatedToken(start=1551, end=1560, text='signature', label='O'),
#     AnnotatedToken(start=1561, end=1568, text='similar', label='O'),
#     AnnotatedToken(start=1569, end=1571, text='to', label='O'),
#     AnnotatedToken(start=1572, end=1579, text='samples', label='O'),
#     AnnotatedToken(start=1580, end=1584, text='from', label='O'),
#     AnnotatedToken(start=1585, end=1588, text='PA3', label='O'),
#     AnnotatedToken(start=1588, end=1590, text='/4', label='O'),
#     AnnotatedToken(start=1591, end=1597, text='during', label='O'),
#     AnnotatedToken(start=1598, end=1601, text='the', label='O'),
#     AnnotatedToken(start=1602, end=1605, text='CIE', label='O'),
#     AnnotatedToken(start=1606, end=1607, text='(', label='O'),
#     AnnotatedToken(start=1607, end=1611, text='plot', label='O'),
#     AnnotatedToken(start=1612, end=1617, text='lower', label='O'),
#     AnnotatedToken(start=1618, end=1620, text='on', label='O'),
#     AnnotatedToken(start=1621, end=1625, text='axis', label='O'),
#     AnnotatedToken(start=1626, end=1627, text='1', label='O'),
#     AnnotatedToken(start=1627, end=1628, text=')', label='O'),
#     AnnotatedToken(start=1629, end=1632, text='and', label='O'),
#     AnnotatedToken(start=1633, end=1636, text='are', label='O'),
#     AnnotatedToken(start=1637, end=1643, text='either', label='O'),
#     AnnotatedToken(start=1644, end=1647, text='not', label='O'),
#     AnnotatedToken(start=1648, end=1650, text='in', label='O'),
#     AnnotatedToken(start=1651, end=1654, text='the', label='O'),
#     AnnotatedToken(start=1655, end=1662, text='correct', label='O'),
#     AnnotatedToken(start=1663, end=1671, text='location', label='O'),
#     AnnotatedToken(start=1672, end=1673, text='(', label='O'),
#     AnnotatedToken(start=1673, end=1675, text='it', label='O'),
#     AnnotatedToken(start=1676, end=1682, text='cannot', label='O'),
#     AnnotatedToken(start=1683, end=1685, text='be', label='O'),
#     AnnotatedToken(start=1686, end=1696, text='discounted', label='O'),
#     AnnotatedToken(start=1697, end=1701, text='that', label='O'),
#     AnnotatedToken(start=1702, end=1707, text='these', label='O'),
#     AnnotatedToken(start=1708, end=1715, text='samples', label='O'),
#     AnnotatedToken(start=1716, end=1725, text='represent', label='O'),
#     AnnotatedToken(start=1726, end=1738, text='tectonically', label='O'),
#     AnnotatedToken(start=1739, end=1747, text='emplaced', label='O'),
#     AnnotatedToken(start=1748, end=1755, text='younger', label='O'),
#     AnnotatedToken(start=1756, end=1764, text='material', label='O'),
#     AnnotatedToken(start=1765, end=1766, text='(', label='O'),
#     AnnotatedToken(start=1766, end=1771, text='Payne', label='O'),
#     AnnotatedToken(start=1772, end=1774, text='et', label='O'),
#     AnnotatedToken(start=1775, end=1777, text='al', label='O'),
#     AnnotatedToken(start=1777, end=1778, text='.', label='O'),
#     AnnotatedToken(start=1778, end=1779, text=',', label='O'),
#     AnnotatedToken(start=1780, end=1784, text='2005', label='O'),
#     AnnotatedToken(start=1784, end=1785, text=')', label='O'),
#     AnnotatedToken(start=1785, end=1786, text=',', label='O'),
#     AnnotatedToken(start=1787, end=1789, text='or', label='O'),
#     AnnotatedToken(start=1790, end=1794, text='were', label='O'),
#     AnnotatedToken(start=1795, end=1804, text='misplaced', label='O'),
#     AnnotatedToken(start=1805, end=1811, text='during', label='O'),
#     AnnotatedToken(start=1812, end=1820, text='drilling', label='O'),
#     AnnotatedToken(start=1821, end=1831, text='operations', label='O'),
#     AnnotatedToken(start=1832, end=1836, text='core', label='O'),
#     AnnotatedToken(start=1837, end=1845, text='handling', label='O'),
#     AnnotatedToken(start=1845, end=1846, text=')', label='O'),
#     AnnotatedToken(start=1846, end=1847, text=',', label='O'),
#     AnnotatedToken(start=1848, end=1850, text='or', label='O'),
#     AnnotatedToken(start=1851, end=1860, text='represent', label='O'),
#     AnnotatedToken(start=1861, end=1865, text='very', label='O'),
#     AnnotatedToken(start=1866, end=1871, text='short', label='O'),
#     AnnotatedToken(start=1872, end=1880, text='episodes', label='O'),
#     AnnotatedToken(start=1881, end=1883, text='of', label='O'),
#     AnnotatedToken(start=1884, end=1888, text='both', label='O'),
#     AnnotatedToken(start=1889, end=1895, text='marine', label='O'),
#     AnnotatedToken(start=1896, end=1899, text='and', label='O'),
#     AnnotatedToken(start=1900, end=1911, text='terrestrial', label='O'),
#     AnnotatedToken(start=1912, end=1920, text='ecologic', label='O'),
#     AnnotatedToken(start=1921, end=1927, text='change', label='O'),
#     AnnotatedToken(start=1928, end=1930, text='to', label='O'),
#     AnnotatedToken(start=1931, end=1934, text='CIE', label='O'),
#     AnnotatedToken(start=1934, end=1935, text='-', label='O'),
#     AnnotatedToken(start=1935, end=1939, text='type', label='O'),
#     AnnotatedToken(start=1940, end=1950, text='conditions', label='O'),
#     AnnotatedToken(start=1950, end=1951, text='.', label='O')],
#    [AnnotatedToken(start=1952, end=1955, text='The', label='O'),
#     AnnotatedToken(start=1956, end=1961, text='rapid', label='O'),
#     AnnotatedToken(start=1962, end=1965, text='and', label='O'),
#     AnnotatedToken(start=1966, end=1975, text='transient', label='O'),
#     AnnotatedToken(start=1976, end=1982, text='nature', label='O'),
#     AnnotatedToken(start=1983, end=1985, text='of', label='O'),
#     AnnotatedToken(start=1986, end=1991, text='these', label='O'),
#     AnnotatedToken(start=1992, end=1995, text='two', label='O'),
#     AnnotatedToken(start=1996, end=2002, text='shifts', label='O'),
#     AnnotatedToken(start=2003, end=2010, text='appears', label='O'),
#     AnnotatedToken(start=2011, end=2013, text='to', label='O'),
#     AnnotatedToken(start=2014, end=2021, text='suggest', label='O'),
#     AnnotatedToken(start=2022, end=2026, text='that', label='O'),
#     AnnotatedToken(start=2027, end=2030, text='the', label='O'),
#     AnnotatedToken(start=2031, end=2037, text='latter', label='O'),
#     AnnotatedToken(start=2038, end=2049, text='explanation', label='O'),
#     AnnotatedToken(start=2050, end=2053, text='may', label='O'),
#     AnnotatedToken(start=2054, end=2056, text='be', label='O'),
#     AnnotatedToken(start=2057, end=2065, text='unlikely', label='O'),
#     AnnotatedToken(start=2065, end=2066, text=',', label='O'),
#     AnnotatedToken(start=2067, end=2070, text='and', label='O'),
#     AnnotatedToken(start=2071, end=2073, text='we', label='O'),
#     AnnotatedToken(start=2074, end=2078, text='have', label='O'),
#     AnnotatedToken(start=2079, end=2088, text='therefore', label='O'),
#     AnnotatedToken(start=2089, end=2095, text='shaded', label='O'),
#     AnnotatedToken(start=2096, end=2103, text='samples', label='O'),
#     AnnotatedToken(start=2104, end=2108, text='from', label='O'),
#     AnnotatedToken(start=2109, end=2114, text='these', label='O'),
#     AnnotatedToken(start=2115, end=2118, text='two', label='O'),
#     AnnotatedToken(start=2119, end=2125, text='depths', label='O'),
#     AnnotatedToken(start=2126, end=2128, text='in', label='O'),
#     AnnotatedToken(start=2129, end=2133, text='Figs', label='O'),
#     AnnotatedToken(start=2133, end=2134, text='.', label='O')],
#    [AnnotatedToken(start=2135, end=2136, text='3', label='O'),
#     AnnotatedToken(start=2136, end=2137, text=',', label='O'),
#     AnnotatedToken(start=2138, end=2139, text='6', label='O'),
#     AnnotatedToken(start=2139, end=2140, text='–', label='O'),
#     AnnotatedToken(start=2140, end=2141, text='9', label='O'),
#     AnnotatedToken(start=2141, end=2142, text='.', label='O')]]},
#  {'docId': 'S0012821X12004384-1405',
#   'sentAnnot': [[AnnotatedToken(start=0, end=14, text='Dinoflagellate', label='O'),
#     AnnotatedToken(start=15, end=20, text='cysts', label='O'),
#     AnnotatedToken(start=21, end=25, text='have', label='O'),
#     AnnotatedToken(start=26, end=30, text='been', label='O'),
#     AnnotatedToken(start=31, end=35, text='used', label='O'),
#     AnnotatedToken(start=36, end=47, text='extensively', label='O'),
#     AnnotatedToken(start=48, end=51, text='for', label='O'),
#     AnnotatedToken(start=52, end=66, text='reconstructing', label='O'),
#     AnnotatedToken(start=67, end=84, text='paleoenvironments', label='O'),
#     AnnotatedToken(start=85, end=87, text='in', label='O'),
#     AnnotatedToken(start=88, end=91, text='the', label='O'),
#     AnnotatedToken(start=92, end=101, text='Paleogene', label='O'),
#     AnnotatedToken(start=102, end=103, text='(', label='O'),
#     AnnotatedToken(start=103, end=106, text='see', label='O'),
#     AnnotatedToken(start=107, end=115, text='overview', label='O'),
#     AnnotatedToken(start=116, end=118, text='in', label='O'),
#     AnnotatedToken(start=119, end=125, text='Sluijs', label='O'),
#     AnnotatedToken(start=126, end=128, text='et', label='O'),
#     AnnotatedToken(start=129, end=131, text='al', label='O'),
#     AnnotatedToken(start=131, end=132, text='.', label='O'),
#     AnnotatedToken(start=132, end=133, text=',', label='O'),
#     AnnotatedToken(start=134, end=138, text='2005', label='O'),
#     AnnotatedToken(start=138, end=139, text=')', label='O'),
#     AnnotatedToken(start=139, end=140, text=',', label='O'),
#     AnnotatedToken(start=141, end=143, text='as', label='O'),
#     AnnotatedToken(start=144, end=148, text='they', label='O'),
#     AnnotatedToken(start=149, end=152, text='are', label='O'),
#     AnnotatedToken(start=153, end=165, text='particularly', label='O'),
#     AnnotatedToken(start=166, end=175, text='sensitive', label='O'),
#     AnnotatedToken(start=176, end=178, text='to', label='O'),
#     AnnotatedToken(start=179, end=186, text='changes', label='O'),
#     AnnotatedToken(start=187, end=189, text='in', label='O'),
#     AnnotatedToken(start=190, end=198, text='salinity', label='O'),
#     AnnotatedToken(start=198, end=199, text=',', label='O'),
#     AnnotatedToken(start=200, end=211, text='temperature', label='O'),
#     AnnotatedToken(start=211, end=212, text=',', label='O'),
#     AnnotatedToken(start=213, end=216, text='and', label='O'),
#     AnnotatedToken(start=217, end=225, text='nutrient', label='O'),
#     AnnotatedToken(start=226, end=232, text='levels', label='O'),
#     AnnotatedToken(start=233, end=234, text='(', label='O'),
#     AnnotatedToken(start=234, end=240, text='Powell', label='O'),
#     AnnotatedToken(start=241, end=243, text='et', label='O'),
#     AnnotatedToken(start=244, end=246, text='al', label='O'),
#     AnnotatedToken(start=246, end=247, text='.', label='O'),
#     AnnotatedToken(start=247, end=248, text=',', label='O'),
#     AnnotatedToken(start=249, end=253, text='1992', label='O'),
#     AnnotatedToken(start=253, end=254, text=';', label='O'),
#     AnnotatedToken(start=255, end=260, text='Pross', label='O'),
#     AnnotatedToken(start=261, end=264, text='and', label='O'),
#     AnnotatedToken(start=265, end=274, text='Brinkhuis', label='O'),
#     AnnotatedToken(start=275, end=279, text='2005', label='O'),
#     AnnotatedToken(start=279, end=280, text=';', label='O'),
#     AnnotatedToken(start=281, end=287, text='Sluijs', label='O'),
#     AnnotatedToken(start=288, end=290, text='et', label='O'),
#     AnnotatedToken(start=291, end=293, text='al', label='O'),
#     AnnotatedToken(start=293, end=294, text='.', label='O'),
#     AnnotatedToken(start=294, end=295, text=',', label='O'),
#     AnnotatedToken(start=296, end=300, text='2005', label='O'),
#     AnnotatedToken(start=300, end=301, text=')', label='O'),
#     AnnotatedToken(start=301, end=302, text='.', label='O')],
#    [AnnotatedToken(start=303, end=305, text='We', label='O'),
#     AnnotatedToken(start=306, end=315, text='calculate', label='O'),
#     AnnotatedToken(start=316, end=321, text='“%low', label='O'),
#     AnnotatedToken(start=322, end=330, text='salinity', label='O'),
#     AnnotatedToken(start=331, end=345, text='dinoflagellate', label='O'),
#     AnnotatedToken(start=346, end=351, text='cysts', label='O'),
#     AnnotatedToken(start=351, end=352, text='”', label='O'),
#     AnnotatedToken(start=353, end=354, text='(', label='O'),
#     AnnotatedToken(start=354, end=358, text='Figs', label='O'),
#     AnnotatedToken(start=358, end=359, text='.', label='O')],
#    [AnnotatedToken(start=360, end=361, text='7', label='O'),
#     AnnotatedToken(start=361, end=362, text='–', label='O'),
#     AnnotatedToken(start=362, end=363, text='9', label='O'),
#     AnnotatedToken(start=363, end=364, text=')', label='O'),
#     AnnotatedToken(start=365, end=367, text='by', label='O'),
#     AnnotatedToken(start=368, end=376, text='grouping', label='O'),
#     AnnotatedToken(start=377, end=382, text='cysts', label='O'),
#     AnnotatedToken(start=383, end=385, text='of', label='O'),
#     AnnotatedToken(start=386, end=393, text='similar', label='O'),
#     AnnotatedToken(start=394, end=402, text='inferred', label='O'),
#     AnnotatedToken(start=403, end=411, text='ecologic', label='O'),
#     AnnotatedToken(start=412, end=423, text='preferences', label='O'),
#     AnnotatedToken(start=424, end=425, text='(', label='O'),
#     AnnotatedToken(start=425, end=428, text='see', label='O'),
#     AnnotatedToken(start=429, end=432, text='Fig', label='O'),
#     AnnotatedToken(start=432, end=433, text='.', label='O')],
#    [AnnotatedToken(start=434, end=435, text='7', label='O'),
#     AnnotatedToken(start=435, end=436, text=',', label='O'),
#     AnnotatedToken(start=437, end=440, text='and', label='O'),
#     AnnotatedToken(start=441, end=451, text='discussion', label='O'),
#     AnnotatedToken(start=452, end=454, text='in', label='O'),
#     AnnotatedToken(start=455, end=458, text='the', label='O'),
#     AnnotatedToken(start=459, end=472, text='Supplementary', label='O'),
#     AnnotatedToken(start=473, end=481, text='Material', label='O'),
#     AnnotatedToken(start=481, end=482, text=')', label='O'),
#     AnnotatedToken(start=483, end=485, text='to', label='O'),
#     AnnotatedToken(start=486, end=493, text='provide', label='O'),
#     AnnotatedToken(start=494, end=496, text='an', label='O'),
#     AnnotatedToken(start=497, end=507, text='indication', label='O'),
#     AnnotatedToken(start=508, end=510, text='of', label='O'),
#     AnnotatedToken(start=511, end=524, text='environmental', label='O'),
#     AnnotatedToken(start=525, end=531, text='change', label='O'),
#     AnnotatedToken(start=531, end=532, text=',', label='O'),
#     AnnotatedToken(start=533, end=536, text='and', label='O'),
#     AnnotatedToken(start=537, end=539, text='by', label='O'),
#     AnnotatedToken(start=540, end=549, text='excluding', label='O'),
#     AnnotatedToken(start=550, end=557, text='species', label='O'),
#     AnnotatedToken(start=558, end=560, text='of', label='O'),
#     AnnotatedToken(start=561, end=570, text='uncertain', label='O'),
#     AnnotatedToken(start=571, end=579, text='affinity', label='O'),
#     AnnotatedToken(start=580, end=584, text='such', label='O'),
#     AnnotatedToken(start=585, end=587, text='as', label='O'),
#     AnnotatedToken(start=588, end=600, text='Apectodinium', label='O'),
#     AnnotatedToken(start=600, end=601, text='.', label='O')],
#    [AnnotatedToken(start=602, end=609, text='Samples', label='O'),
#     AnnotatedToken(start=610, end=614, text='with', label='O'),
#     AnnotatedToken(start=615, end=620, text='fewer', label='O'),
#     AnnotatedToken(start=621, end=625, text='than', label='O'),
#     AnnotatedToken(start=626, end=628, text='20', label='O'),
#     AnnotatedToken(start=629, end=638, text='specimens', label='O'),
#     AnnotatedToken(start=639, end=643, text='were', label='O'),
#     AnnotatedToken(start=644, end=648, text='also', label='O'),
#     AnnotatedToken(start=649, end=657, text='excluded', label='O'),
#     AnnotatedToken(start=657, end=658, text='.', label='O')],
#    [AnnotatedToken(start=659, end=666, text='Despite', label='O'),
#     AnnotatedToken(start=667, end=670, text='the', label='O'),
#     AnnotatedToken(start=671, end=682, text='limitations', label='O'),
#     AnnotatedToken(start=683, end=685, text='of', label='O'),
#     AnnotatedToken(start=686, end=690, text='this', label='O'),
#     AnnotatedToken(start=691, end=697, text='method', label='O'),
#     AnnotatedToken(start=697, end=698, text=',', label='O'),
#     AnnotatedToken(start=699, end=702, text='the', label='O'),
#     AnnotatedToken(start=703, end=708, text='large', label='O'),
#     AnnotatedToken(start=709, end=718, text='variation', label='O'),
#     AnnotatedToken(start=719, end=721, text='in', label='O'),
#     AnnotatedToken(start=722, end=725, text='the', label='O'),
#     AnnotatedToken(start=726, end=730, text='%low', label='O'),
#     AnnotatedToken(start=731, end=739, text='salinity', label='O'),
#     AnnotatedToken(start=740, end=754, text='dinoflagellate', label='O'),
#     AnnotatedToken(start=755, end=760, text='cysts', label='O'),
#     AnnotatedToken(start=761, end=762, text='(', label='O'),
#     AnnotatedToken(start=762, end=769, text='ranging', label='O'),
#     AnnotatedToken(start=770, end=774, text='from', label='O'),
#     AnnotatedToken(start=775, end=776, text='0', label='O'),
#     AnnotatedToken(start=776, end=777, text='%', label='unit'),
#     AnnotatedToken(start=778, end=780, text='to', label='O'),
#     AnnotatedToken(start=781, end=783, text='80', label='O'),
#     AnnotatedToken(start=783, end=785, text='%)', label='O'),
#     AnnotatedToken(start=786, end=793, text='clearly', label='O'),
#     AnnotatedToken(start=794, end=803, text='indicates', label='O'),
#     AnnotatedToken(start=804, end=808, text='that', label='O'),
#     AnnotatedToken(start=809, end=820, text='significant', label='O'),
#     AnnotatedToken(start=821, end=834, text='environmental', label='O'),
#     AnnotatedToken(start=835, end=842, text='changes', label='O'),
#     AnnotatedToken(start=843, end=845, text='in', label='O'),
#     AnnotatedToken(start=846, end=853, text='surface', label='O'),
#     AnnotatedToken(start=854, end=859, text='water', label='O'),
#     AnnotatedToken(start=860, end=870, text='conditions', label='O'),
#     AnnotatedToken(start=871, end=879, text='occurred', label='O'),
#     AnnotatedToken(start=880, end=886, text='during', label='O'),
#     AnnotatedToken(start=887, end=890, text='the', label='O'),
#     AnnotatedToken(start=891, end=894, text='CIE', label='O'),
#     AnnotatedToken(start=895, end=900, text='onset', label='O'),
#     AnnotatedToken(start=901, end=903, text='in', label='O'),
#     AnnotatedToken(start=904, end=907, text='the', label='O'),
#     AnnotatedToken(start=908, end=915, text='central', label='O'),
#     AnnotatedToken(start=916, end=921, text='North', label='O'),
#     AnnotatedToken(start=922, end=925, text='Sea', label='O'),
#     AnnotatedToken(start=925, end=926, text=',', label='O'),
#     AnnotatedToken(start=927, end=930, text='and', label='O'),
#     AnnotatedToken(start=931, end=933, text='is', label='O'),
#     AnnotatedToken(start=934, end=943, text='supported', label='O'),
#     AnnotatedToken(start=944, end=946, text='by', label='O'),
#     AnnotatedToken(start=947, end=953, text='coeval', label='O'),
#     AnnotatedToken(start=954, end=961, text='changes', label='O'),
#     AnnotatedToken(start=962, end=964, text='in', label='O'),
#     AnnotatedToken(start=965, end=968, text='the', label='O'),
#     AnnotatedToken(start=969, end=980, text='sedimentary', label='O'),
#     AnnotatedToken(start=981, end=987, text='carbon', label='O'),
#     AnnotatedToken(start=987, end=996, text='/nitrogen', label='O'),
#     AnnotatedToken(start=997, end=998, text='(', label='O'),
#     AnnotatedToken(start=998, end=999, text='C', label='O'),
#     AnnotatedToken(start=999, end=1002, text='/N)', label='O'),
#     AnnotatedToken(start=1003, end=1008, text='ratio', label='O'),
#     AnnotatedToken(start=1009, end=1010, text='(', label='O'),
#     AnnotatedToken(start=1010, end=1013, text='Fig', label='O'),
#     AnnotatedToken(start=1013, end=1014, text='.', label='O')],
#    [AnnotatedToken(start=1015, end=1017, text='10', label='O'),
#     AnnotatedToken(start=1017, end=1018, text=')', label='O'),
#     AnnotatedToken(start=1019, end=1024, text='which', label='O'),
#     AnnotatedToken(start=1025, end=1033, text='reflects', label='O'),
#     AnnotatedToken(start=1034, end=1041, text='changes', label='O'),
#     AnnotatedToken(start=1042, end=1044, text='in', label='O'),
#     AnnotatedToken(start=1045, end=1048, text='the', label='O'),
#     AnnotatedToken(start=1049, end=1059, text='proportion', label='O'),
#     AnnotatedToken(start=1060, end=1062, text='of', label='O'),
#     AnnotatedToken(start=1063, end=1074, text='terrestrial', label='O'),
#     AnnotatedToken(start=1074, end=1081, text='/marine', label='O'),
#     AnnotatedToken(start=1082, end=1089, text='organic', label='O'),
#     AnnotatedToken(start=1090, end=1098, text='material', label='O'),
#     AnnotatedToken(start=1099, end=1108, text='deposited', label='O'),
#     AnnotatedToken(start=1109, end=1111, text='in', label='O'),
#     AnnotatedToken(start=1112, end=1115, text='the', label='O'),
#     AnnotatedToken(start=1116, end=1121, text='North', label='O'),
#     AnnotatedToken(start=1122, end=1125, text='Sea', label='O'),
#     AnnotatedToken(start=1126, end=1131, text='Basin', label='O'),
#     AnnotatedToken(start=1132, end=1135, text='due', label='O'),
#     AnnotatedToken(start=1136, end=1138, text='to', label='O'),
#     AnnotatedToken(start=1139, end=1150, text='terrestrial', label='O'),
#     AnnotatedToken(start=1151, end=1157, text='runoff', label='O'),
#     AnnotatedToken(start=1158, end=1161, text='and', label='O'),
#     AnnotatedToken(start=1162, end=1174, text='productivity', label='O'),
#     AnnotatedToken(start=1175, end=1176, text='(', label='O'),
#     AnnotatedToken(start=1176, end=1179, text='see', label='O'),
#     AnnotatedToken(start=1180, end=1187, text='Section', label='O'),
#     AnnotatedToken(start=1188, end=1189, text='4', label='O'),
#     AnnotatedToken(start=1189, end=1190, text='.', label='O'),
#     AnnotatedToken(start=1190, end=1191, text='4', label='O'),
#     AnnotatedToken(start=1191, end=1192, text=')', label='O'),
#     AnnotatedToken(start=1192, end=1193, text='.', label='O')]]},
#  {'docId': 'S0012821X12004384-1415',
#   'sentAnnot': [[AnnotatedToken(start=0, end=14, text='Dinoflagellate', label='O'),
#     AnnotatedToken(start=15, end=19, text='cyst', label='O'),
#     AnnotatedToken(start=20, end=30, text='assemblage', label='O'),
#     AnnotatedToken(start=31, end=32, text='1', label='O'),
#     AnnotatedToken(start=33, end=34, text='(', label='O'),
#     AnnotatedToken(start=34, end=37, text='DA1', label='O'),
#     AnnotatedToken(start=37, end=38, text=',', label='O'),
#     AnnotatedToken(start=39, end=43, text='from', label='unit'),
#     AnnotatedToken(start=44, end=48, text='2632', label='O'),
#     AnnotatedToken(start=49, end=51, text='to', label='O'),
#     AnnotatedToken(start=52, end=56, text='2618', label='O'),
#     AnnotatedToken(start=57, end=58, text='m', label='O'),
#     AnnotatedToken(start=58, end=59, text=',', label='O'),
#     AnnotatedToken(start=60, end=63, text='Fig', label='O'),
#     AnnotatedToken(start=63, end=64, text='.', label='O')],
#    [AnnotatedToken(start=65, end=67, text='7p', label='O'),
#     AnnotatedToken(start=67, end=68, text=')', label='O'),
#     AnnotatedToken(start=69, end=77, text='contains', label='O'),
#     AnnotatedToken(start=78, end=82, text='high', label='O'),
#     AnnotatedToken(start=83, end=94, text='proportions', label='O'),
#     AnnotatedToken(start=95, end=97, text='of', label='O'),
#     AnnotatedToken(start=98, end=107, text='typically', label='O'),
#     AnnotatedToken(start=108, end=112, text='open', label='O'),
#     AnnotatedToken(start=113, end=119, text='marine', label='O'),
#     AnnotatedToken(start=120, end=123, text='and', label='O'),
#     AnnotatedToken(start=124, end=129, text='hence', label='O'),
#     AnnotatedToken(start=130, end=136, text='normal', label='O'),
#     AnnotatedToken(start=137, end=143, text='marine', label='O'),
#     AnnotatedToken(start=144, end=152, text='salinity', label='O'),
#     AnnotatedToken(start=153, end=163, text='associated', label='O'),
#     AnnotatedToken(start=164, end=177, text='Achomosphaera', label='O'),
#     AnnotatedToken(start=177, end=190, text='/Spiniferites', label='O'),
#     AnnotatedToken(start=191, end=194, text='spp', label='O'),
#     AnnotatedToken(start=194, end=195, text='.', label='O'),
#     AnnotatedToken(start=195, end=196, text=',', label='O'),
#     AnnotatedToken(start=197, end=213, text='undifferentiated', label='O'),
#     AnnotatedToken(start=214, end=221, text='chorate', label='O'),
#     AnnotatedToken(start=222, end=227, text='cysts', label='O'),
#     AnnotatedToken(start=228, end=231, text='and', label='O'),
#     AnnotatedToken(start=232, end=242, text='Areoligera', label='O'),
#     AnnotatedToken(start=242, end=256, text='/Glaphyrocysta', label='O'),
#     AnnotatedToken(start=257, end=260, text='spp', label='O'),
#     AnnotatedToken(start=260, end=261, text='.', label='O')],
#    [AnnotatedToken(start=262, end=265, text='DA1', label='O'),
#     AnnotatedToken(start=266, end=270, text='also', label='O'),
#     AnnotatedToken(start=271, end=279, text='contains', label='O'),
#     AnnotatedToken(start=280, end=282, text='on', label='O'),
#     AnnotatedToken(start=283, end=290, text='average', label='O'),
#     AnnotatedToken(start=291, end=292, text='5', label='O'),
#     AnnotatedToken(start=292, end=293, text='%', label='unit'),
#     AnnotatedToken(start=294, end=304, text='peridinoid', label='O'),
#     AnnotatedToken(start=305, end=310, text='cysts', label='O'),
#     AnnotatedToken(start=311, end=320, text='including', label='O'),
#     AnnotatedToken(start=321, end=331, text='Deflandrea', label='O'),
#     AnnotatedToken(start=332, end=335, text='spp', label='O'),
#     AnnotatedToken(start=335, end=336, text='.', label='O')],
#    [AnnotatedToken(start=337, end=345, text='regarded', label='O'),
#     AnnotatedToken(start=346, end=348, text='as', label='O'),
#     AnnotatedToken(start=349, end=350, text='a', label='O'),
#     AnnotatedToken(start=351, end=358, text='coastal', label='O'),
#     AnnotatedToken(start=358, end=366, text='/neritic', label='O'),
#     AnnotatedToken(start=367, end=372, text='taxon', label='O'),
# ...
#     AnnotatedToken(start=977, end=982, text='those', label='O'),
#     AnnotatedToken(start=983, end=986, text='who', label='O'),
#     AnnotatedToken(start=987, end=990, text='are', label='O'),
#     AnnotatedToken(start=991, end=995, text='more', label='O'),
#     AnnotatedToken(start=996, end=1004, text='neurotic', label='O'),
#     AnnotatedToken(start=1005, end=1008, text='may', label='O'),
#     AnnotatedToken(start=1009, end=1014, text='think', label='O'),
#     AnnotatedToken(start=1015, end=1020, text='their', label='O'),
#     AnnotatedToken(start=1021, end=1029, text='tinnitus', label='O'),
#     AnnotatedToken(start=1030, end=1032, text='is', label='O'),
#     AnnotatedToken(start=1033, end=1043, text='indicative', label='O'),
#     AnnotatedToken(start=1044, end=1046, text='of', label='O'),
#     AnnotatedToken(start=1047, end=1048, text='a', label='O'),
#     AnnotatedToken(start=1049, end=1053, text='more', label='O'),
#     AnnotatedToken(start=1054, end=1061, text='serious', label='O'),
#     AnnotatedToken(start=1062, end=1071, text='condition', label='O'),
#     AnnotatedToken(start=1072, end=1075, text='and', label='O'),
#     AnnotatedToken(start=1076, end=1085, text='therefore', label='O'),
#     AnnotatedToken(start=1086, end=1090, text='find', label='O'),
#     AnnotatedToken(start=1091, end=1094, text='the', label='O'),
#     AnnotatedToken(start=1095, end=1103, text='tinnitus', label='O'),
#     AnnotatedToken(start=1104, end=1108, text='more', label='O'),
#     AnnotatedToken(start=1109, end=1119, text='bothersome', label='O'),
#     AnnotatedToken(start=1119, end=1120, text='.', label='O')],
#    [AnnotatedToken(start=1121, end=1124, text='The', label='O'),
#     AnnotatedToken(start=1125, end=1132, text='finding', label='O'),
#     AnnotatedToken(start=1133, end=1137, text='that', label='O'),
#     AnnotatedToken(start=1138, end=1149, text='personality', label='O'),
#     AnnotatedToken(start=1150, end=1156, text='traits', label='O'),
#     AnnotatedToken(start=1157, end=1161, text='such', label='O'),
#     AnnotatedToken(start=1162, end=1164, text='as', label='O'),
#     AnnotatedToken(start=1165, end=1176, text='neuroticism', label='O'),
#     AnnotatedToken(start=1177, end=1180, text='can', label='O'),
#     AnnotatedToken(start=1181, end=1191, text='contribute', label='O'),
#     AnnotatedToken(start=1192, end=1194, text='to', label='O'),
#     AnnotatedToken(start=1195, end=1203, text='tinnitus', label='O'),
#     AnnotatedToken(start=1204, end=1213, text='awareness', label='O'),
#     AnnotatedToken(start=1214, end=1217, text='and', label='O'),
#     AnnotatedToken(start=1218, end=1226, text='distress', label='O'),
#     AnnotatedToken(start=1227, end=1229, text='is', label='O'),
#     AnnotatedToken(start=1230, end=1239, text='important', label='O'),
#     AnnotatedToken(start=1240, end=1244, text='when', label='O'),
#     AnnotatedToken(start=1245, end=1256, text='considering', label='O'),
#     AnnotatedToken(start=1257, end=1266, text='treatment', label='O'),
#     AnnotatedToken(start=1267, end=1277, text='approaches', label='O'),
#     AnnotatedToken(start=1278, end=1285, text='because', label='O'),
#     AnnotatedToken(start=1286, end=1297, text='personality', label='O'),
#     AnnotatedToken(start=1298, end=1304, text='traits', label='O'),
#     AnnotatedToken(start=1305, end=1308, text='are', label='O'),
#     AnnotatedToken(start=1309, end=1318, text='generally', label='O'),
#     AnnotatedToken(start=1319, end=1325, text='stable', label='O'),
#     AnnotatedToken(start=1326, end=1330, text='over', label='O'),
#     AnnotatedToken(start=1331, end=1335, text='time', label='O'),
#     AnnotatedToken(start=1336, end=1337, text='[', label='O'),
#     AnnotatedToken(start=1337, end=1339, text='41', label='O'),
#     AnnotatedToken(start=1339, end=1340, text=']', label='O'),
#     AnnotatedToken(start=1340, end=1341, text=',', label='O'),
#     AnnotatedToken(start=1342, end=1350, text='although', label='O'),
#     AnnotatedToken(start=1351, end=1354, text='the', label='O'),
#     AnnotatedToken(start=1355, end=1363, text='absolute', label='O'),
#     AnnotatedToken(start=1364, end=1369, text='level', label='O'),
#     AnnotatedToken(start=1370, end=1372, text='of', label='O'),
#     AnnotatedToken(start=1373, end=1384, text='personality', label='O'),
#     AnnotatedToken(start=1385, end=1391, text='traits', label='O'),
#     AnnotatedToken(start=1392, end=1395, text='can', label='O'),
#     AnnotatedToken(start=1396, end=1402, text='change', label='O'),
#     AnnotatedToken(start=1403, end=1404, text='[', label='O'),
#     AnnotatedToken(start=1404, end=1406, text='42', label='O'),
#     AnnotatedToken(start=1406, end=1407, text=']', label='O'),
#     AnnotatedToken(start=1407, end=1408, text='.', label='O')],
#    [AnnotatedToken(start=1409, end=1413, text='Thus', label='O'),
#     AnnotatedToken(start=1414, end=1416, text='it', label='O'),
#     AnnotatedToken(start=1417, end=1419, text='is', label='O'),
#     AnnotatedToken(start=1420, end=1428, text='possible', label='O'),
#     AnnotatedToken(start=1429, end=1433, text='that', label='O'),
#     AnnotatedToken(start=1434, end=1447, text='psychological', label='O'),
#     AnnotatedToken(start=1448, end=1461, text='interventions', label='O'),
#     AnnotatedToken(start=1462, end=1465, text='may', label='O'),
#     AnnotatedToken(start=1466, end=1468, text='be', label='O'),
#     AnnotatedToken(start=1469, end=1479, text='beneficial', label='O'),
#     AnnotatedToken(start=1480, end=1483, text='for', label='O'),
#     AnnotatedToken(start=1484, end=1492, text='tinnitus', label='O'),
#     AnnotatedToken(start=1493, end=1501, text='patients', label='O'),
#     AnnotatedToken(start=1502, end=1510, text='although', label='O'),
#     AnnotatedToken(start=1511, end=1514, text='the', label='O'),
#     AnnotatedToken(start=1515, end=1522, text='effects', label='O'),
#     AnnotatedToken(start=1523, end=1526, text='may', label='O'),
#     AnnotatedToken(start=1527, end=1529, text='be', label='O'),
#     AnnotatedToken(start=1530, end=1537, text='gradual', label='O'),
#     AnnotatedToken(start=1538, end=1539, text='[', label='O'),
#     AnnotatedToken(start=1539, end=1541, text='11', label='O'),
#     AnnotatedToken(start=1541, end=1542, text=']', label='O'),
#     AnnotatedToken(start=1542, end=1543, text='.', label='O')]]},
#  {'docId': 'S0022459611006116-1160',
#   'sentAnnot': [[AnnotatedToken(start=0, end=3, text='The', label='O'),
#     AnnotatedToken(start=4, end=11, text='ternary', label='O'),
#     AnnotatedToken(start=12, end=21, text='magnesium', label='O'),
#     AnnotatedToken(start=22, end=29, text='nitride', label='O'),
#     AnnotatedToken(start=30, end=39, text='fluorides', label='O'),
#     AnnotatedToken(start=40, end=44, text='were', label='O'),
#     AnnotatedToken(start=45, end=53, text='prepared', label='O'),
#     AnnotatedToken(start=54, end=56, text='by', label='O'),
#     AnnotatedToken(start=57, end=60, text='the', label='O'),
#     AnnotatedToken(start=61, end=65, text='high', label='O'),
#     AnnotatedToken(start=66, end=77, text='temperature', label='O'),
#     AnnotatedToken(start=78, end=83, text='solid', label='O'),
#     AnnotatedToken(start=84, end=89, text='state', label='O'),
#     AnnotatedToken(start=90, end=98, text='reaction', label='O'),
#     AnnotatedToken(start=99, end=101, text='of', label='O'),
#     AnnotatedToken(start=102, end=116, text='stoichiometric', label='O'),
#     AnnotatedToken(start=117, end=124, text='amounts', label='O'),
#     AnnotatedToken(start=125, end=127, text='of', label='O'),
#     AnnotatedToken(start=128, end=139, text='synthesised', label='O'),
#     AnnotatedToken(start=140, end=145, text='Mg3N2', label='O'),
#     AnnotatedToken(start=146, end=150, text='with', label='O'),
#     AnnotatedToken(start=151, end=160, text='anhydrous', label='O'),
#     AnnotatedToken(start=161, end=165, text='MgF2', label='O'),
#     AnnotatedToken(start=166, end=167, text='(', label='O'),
#     AnnotatedToken(start=167, end=174, text='Aldrich', label='O'),
#     AnnotatedToken(start=174, end=175, text=',', label='O'),
#     AnnotatedToken(start=176, end=178, text='99', label='O'),
#     AnnotatedToken(start=178, end=179, text='.', label='O'),
#     AnnotatedToken(start=179, end=180, text='9', label='O'),
#     AnnotatedToken(start=180, end=183, text='%).', label='unit')],
#    [AnnotatedToken(start=184, end=187, text='All', label='O'),
#     AnnotatedToken(start=188, end=201, text='manipulations', label='O'),
#     AnnotatedToken(start=202, end=206, text='were', label='O'),
#     AnnotatedToken(start=207, end=214, text='carried', label='O'),
#     AnnotatedToken(start=215, end=218, text='out', label='O'),
#     AnnotatedToken(start=219, end=224, text='under', label='O'),
#     AnnotatedToken(start=225, end=230, text='inert', label='O'),
#     AnnotatedToken(start=231, end=239, text='nitrogen', label='O'),
#     AnnotatedToken(start=240, end=242, text='or', label='O'),
#     AnnotatedToken(start=243, end=248, text='argon', label='O'),
#     AnnotatedToken(start=249, end=260, text='atmospheres', label='O'),
#     AnnotatedToken(start=260, end=261, text='.', label='O')],
#    [AnnotatedToken(start=262, end=265, text='The', label='O'),
#     AnnotatedToken(start=266, end=277, text='appropriate', label='O'),
#     AnnotatedToken(start=278, end=279, text='1', label='O'),
#     AnnotatedToken(start=279, end=281, text=':3', label='O'),
#     AnnotatedToken(start=282, end=285, text='and', label='O'),
#     AnnotatedToken(start=286, end=287, text='1', label='O'),
#     AnnotatedToken(start=287, end=289, text=':1', label='O'),
#     AnnotatedToken(start=290, end=304, text='stoichiometric', label='O'),
#     AnnotatedToken(start=305, end=310, text='molar', label='O'),
#     AnnotatedToken(start=311, end=317, text='ratios', label='O'),
#     AnnotatedToken(start=318, end=322, text='were', label='O'),
#     AnnotatedToken(start=323, end=327, text='used', label='O'),
#     AnnotatedToken(start=328, end=330, text='in', label='O'),
#     AnnotatedToken(start=331, end=334, text='the', label='O'),
#     AnnotatedToken(start=335, end=344, text='synthesis', label='O'),
#     AnnotatedToken(start=345, end=347, text='of', label='O'),
#     AnnotatedToken(start=348, end=354, text='Mg3NF3', label='O'),
#     AnnotatedToken(start=355, end=356, text='(', label='O'),
#     AnnotatedToken(start=356, end=357, text='1', label='O'),
#     AnnotatedToken(start=357, end=358, text=')', label='O'),
#     AnnotatedToken(start=359, end=362, text='and', label='O'),
#     AnnotatedToken(start=363, end=368, text='Mg2NF', label='O'),
#     AnnotatedToken(start=369, end=370, text='(', label='O'),
#     AnnotatedToken(start=370, end=371, text='2', label='O'),
#     AnnotatedToken(start=371, end=372, text=')', label='O'),
#     AnnotatedToken(start=373, end=385, text='respectively', label='O'),
#     AnnotatedToken(start=385, end=386, text=',', label='O'),
#     AnnotatedToken(start=387, end=389, text='as', label='O'),
#     AnnotatedToken(start=390, end=395, text='shown', label='O'),
#     AnnotatedToken(start=396, end=401, text='below', label='O'),
#     AnnotatedToken(start=401, end=444, text=':(1)Mg3N2+3MgF2→2Mg3NF3(2)Mg3N2+MgF2→2Mg2NF', label='O')]]},
#  {'docId': 'S0022459611006116-1195',
#   'sentAnnot': [[AnnotatedToken(start=0, end=3, text='All', label='O'),
#     AnnotatedToken(start=4, end=12, text='products', label='O'),
#     AnnotatedToken(start=13, end=17, text='were', label='O'),
#     AnnotatedToken(start=18, end=27, text='initially', label='O'),
#     AnnotatedToken(start=28, end=41, text='characterised', label='O'),
#     AnnotatedToken(start=42, end=44, text='by', label='O'),
#     AnnotatedToken(start=45, end=48, text='PXD', label='O'),
#     AnnotatedToken(start=48, end=49, text='.', label='O')],
#    [AnnotatedToken(start=50, end=54, text='Data', label='O'),
#     AnnotatedToken(start=55, end=59, text='were', label='O'),
#     AnnotatedToken(start=60, end=69, text='collected', label='O'),
#     AnnotatedToken(start=70, end=75, text='using', label='O'),
#     AnnotatedToken(start=76, end=77, text='a', label='O'),
#     AnnotatedToken(start=78, end=85, text='Philips', label='O'),
#     AnnotatedToken(start=86, end=87, text='X', label='O'),
#     AnnotatedToken(start=87, end=88, text='-', label='O'),
#     AnnotatedToken(start=88, end=92, text='pert', label='O'),
#     AnnotatedToken(start=93, end=107, text='diffractometer', label='O'),
#     AnnotatedToken(start=108, end=117, text='operating', label='O'),
#     AnnotatedToken(start=118, end=122, text='with', label='O'),
#     AnnotatedToken(start=123, end=127, text='CuKα', label='O'),
#     AnnotatedToken(start=128, end=137, text='radiation', label='O'),
#     AnnotatedToken(start=137, end=138, text='.', label='O')],
#    [AnnotatedToken(start=139, end=146, text='Initial', label='O'),
#     AnnotatedToken(start=147, end=152, text='scans', label='O'),
#     AnnotatedToken(start=153, end=157, text='were', label='O'),
#     AnnotatedToken(start=158, end=165, text='carried', label='O'),
#     AnnotatedToken(start=166, end=169, text='out', label='O'),
#     AnnotatedToken(start=170, end=174, text='from', label='O'),
#     AnnotatedToken(start=175, end=176, text='5', label='O'),
#     AnnotatedToken(start=176, end=184, text='≤2θ/°≤80', label='unit'),
#     AnnotatedToken(start=185, end=189, text='with', label='O'),
#     AnnotatedToken(start=190, end=191, text='a', label='O'),
#     AnnotatedToken(start=192, end=196, text='step', label='O'),
#     AnnotatedToken(start=197, end=201, text='size', label='O'),
#     AnnotatedToken(start=202, end=204, text='of', label='O'),
#     AnnotatedToken(start=205, end=206, text='0', label='O'),
#     AnnotatedToken(start=206, end=207, text='.', label='O'),
#     AnnotatedToken(start=207, end=209, text='02', label='O'),
#     AnnotatedToken(start=209, end=210, text='°', label='unit'),
#     AnnotatedToken(start=211, end=214, text='and', label='O'),
#     AnnotatedToken(start=215, end=216, text='a', label='O'),
#     AnnotatedToken(start=217, end=221, text='scan', label='O'),
#     AnnotatedToken(start=222, end=226, text='time', label='O'),
#     AnnotatedToken(start=227, end=229, text='of', label='O'),
#     AnnotatedToken(start=230, end=232, text='50', label='O'),
#     AnnotatedToken(start=233, end=236, text='min', label='unit'),
#     AnnotatedToken(start=236, end=237, text='.', label='O')],
#    [AnnotatedToken(start=238, end=241, text='Due', label='O'),
#     AnnotatedToken(start=242, end=244, text='to', label='O'),
#     AnnotatedToken(start=245, end=248, text='the', label='O'),
#     AnnotatedToken(start=249, end=252, text='air', label='O'),
#     AnnotatedToken(start=252, end=253, text='-', label='O'),
#     AnnotatedToken(start=253, end=262, text='sensitive', label='O'),
#     AnnotatedToken(start=263, end=269, text='nature', label='O'),
#     AnnotatedToken(start=270, end=272, text='of', label='O'),
#     AnnotatedToken(start=273, end=276, text='the', label='O'),
#     AnnotatedToken(start=277, end=285, text='products', label='O'),
#     AnnotatedToken(start=285, end=286, text=',', label='O'),
#     AnnotatedToken(start=287, end=288, text='a', label='O'),
#     AnnotatedToken(start=289, end=298, text='dedicated', label='O'),
#     AnnotatedToken(start=299, end=302, text='air', label='O'),
#     AnnotatedToken(start=302, end=303, text='-', label='O'),
#     AnnotatedToken(start=303, end=308, text='tight', label='O'),
#     AnnotatedToken(start=309, end=318, text='aluminium', label='O'),
#     AnnotatedToken(start=319, end=325, text='sample', label='O'),
#     AnnotatedToken(start=326, end=332, text='holder', label='O'),
#     AnnotatedToken(start=333, end=337, text='with', label='O'),
#     AnnotatedToken(start=338, end=343, text='Mylar', label='O'),
#     AnnotatedToken(start=344, end=351, text='windows', label='O'),
#     AnnotatedToken(start=352, end=355, text='was', label='O'),
#     AnnotatedToken(start=356, end=364, text='employed', label='O'),
#     AnnotatedToken(start=365, end=366, text='[', label='O'),
#     AnnotatedToken(start=366, end=368, text='24', label='O'),
#     AnnotatedToken(start=368, end=369, text=']', label='O'),
#     AnnotatedToken(start=369, end=370, text='.', label='O')]]}]

# %%
# write the annotated NER training data into a file
f = open("trial.txt", "w", encoding='UTF-8')

for example in examples:
    annotated_sent = example['sentAnnot']
    for sent in annotated_sent:
        for token in sent:
            f.write(token.text + '\t' + token.label + '\n')
        f.write('\n')

f.close()

# %% [markdown]
# ## Useless

# %%
# sentenizer.span_tokenize()
# x = 'Five samples from below the CIE at 2619.60, 2617.35, 2617.44, 2614.73, and 2614.71 m (indicated in Fig.'
# print(sentenizer.span_tokenize(x))
# l = []
# for (start, end), text in zip(sentenizer.span_tokenize(x), sentenizer.tokenize(x)):
#     l.append(Sentence(start, end, text))
# l
# docs.loc[:, 'texts_unit'] = docs.text.apply(
#     lambda x: [
#         Sentence(start, end, text) for (start, end), text in zip(
#             sentenizer.span_tokenize(x), sentenizer.tokenize(x)
#         )
#     ]
# )

# for sent in doc.texts:
#     tokens = [
#         Token(sent.start + start, sent.start + end, token)
#         for (start, end), token in zip(
#             tokenizer.span_tokenize(sent.text),
#             tokenizer.tokenize(sent.text)
#         )
#     ]
unit = "m per second"
quantity = "10 m per second m"
sent_text = "the speed of the car is 10 m per second m"

tk_unit = tokenizer.tokenize(unit)
print(tk_unit)

q_tokens = [
        Token(start, end, token)
        for (start, end), token in zip(
            tokenizer.span_tokenize(quantity),
            tokenizer.tokenize(quantity)
        )
    ]

mark = -1
cnt = len(tk_unit)
cnt2 = 0
# for t_u in tk_unit:
#     flag = 0
#     for t_q in q_tokens:
#         if t_u == t_q.text:
#             cnt2 += 1
#             flag = 1
#         else:
#             continue
position = 0
flag = 0
match = False
for i in range(len(q_tokens)):
    while match == False:
        for j in range(len(tk_unit)):
            if position == j:
                if q_tokens[i].text == tk_unit[j]:
                    # the current token in the quantity matchs the current token in the unit 
                    flag = 1
                    cnt2 += 1
                    position = j+1
                    match = True
                    break
                else:
                    # the current quantity token doesn't match the current unit token - not the exact match
                    # reset all parameters
                    flag = 0
                    cnt2 = 0
                    position = 0
    #             break
    if flag == 1 and cnt2 == cnt:
        mark = q_tokens[i-(cnt-1)].start
        break

# for (l, r), t in zip(tokenizer.span_tokenize(quantity),tokenizer.tokenize(quantity)):
#     q_tokens.append(Token(l, r, t))
#     for t_u in tk_unit:
#         if t_u == t:
#             cnt -= 1
#         else:
#             break
#     if cnt == 0:
#         mark = l
#         break

s = -1
e = -1
for i in range(len(q_tokens)):
    if q_tokens[i].start == mark:
        s = mark
        end_tk = q_tokens[i+cnt-1]
        e = end_tk.end
print(s)
print(e)
print(q_tokens)
# Out:
# ['m', 'per', 'second']
# 0
# 2
# [Token(start=0, end=2, text='10'), Token(start=3, end=4, text='m'), Token(start=5, end=8, text='per'), Token(start=9, end=15, text='second'), Token(start=16, end=17, text='m')]

# %%
annotations
# Out:
#                       docId  annotSet         annotType  startOffset  \
# 0    S0012821X12004384-1302         1          Quantity          553
# 1    S0012821X12004384-1302         1    MeasuredEntity          558
# 2    S0012821X12004384-1302         2          Quantity          588
# 3    S0012821X12004384-1302         2    MeasuredEntity          558
# 4    S0012821X12004384-1302         2         Qualifier          571
# ..                      ...       ...               ...          ...
# 827  S0022459611006116-1195         2  MeasuredProperty          192
# 828  S0022459611006116-1195         2    MeasuredEntity          139
# 829  S0022459611006116-1195         3          Quantity          230
# 830  S0022459611006116-1195         3  MeasuredProperty          217
# 831  S0022459611006116-1195         3    MeasuredEntity          139
#
#      endOffset annotId                                               text  \
# 0          557   T91-1                                               Five
# 1          565  T101-1                                            samples
# 2          637   T12-2  2619.60, 2617.35, 2617.44, 2614.73, and 2614.71 m
# 3          565  T102-2                                            samples
# 4          584  T152-2                                      below the CIE
# ..         ...     ...                                                ...
# 827        201   T32-2                                          step size
# 828        152   T52-2                                      Initial scans
# 829        236   T13-3                                             50 min
# 830        226   T23-3                                          scan time
# 831        152   T53-3                                      Initial scans
#
#                                  other
# 0                {'mods': ['IsCount']}
# 1             {'HasQuantity': 'T91-1'}
# 2    {'mods': ['IsList'], 'unit': 'm'}
# 3             {'HasQuantity': 'T12-2'}
# 4              {'Qualifies': 'T102-2'}
# ..                                 ...
# 827           {'HasQuantity': 'T42-2'}
# 828           {'HasProperty': 'T32-2'}
# 829                    {'unit': 'min'}
# 830           {'HasQuantity': 'T13-3'}
# 831           {'HasProperty': 'T23-3'}
#
# [832 rows x 8 columns]

# %%
import re

unit = "m per second"
quantity = "10 m m per second m"
sent_text = "the speed of the car is 10 m per second m"

# stra = 'bread is good'
p = re.compile(unit)
result1 = p.search(quantity).span()
print(result1[0])
result2 = p.search(quantity).group()
print(result2)
# Out:
# 5
# m per second

# %%
quantity = "10 m m per second m"
q_tokens = [
        Token(start, end, token)
        for (start, end), token in zip(
            tokenizer.span_tokenize(quantity),
            tokenizer.tokenize(quantity)
        )
    ]
print(q_tokens)
# Out:
# [Token(start=0, end=2, text='10'), Token(start=3, end=4, text='m'), Token(start=5, end=6, text='m'), Token(start=7, end=10, text='per'), Token(start=11, end=17, text='second'), Token(start=18, end=19, text='m')]
