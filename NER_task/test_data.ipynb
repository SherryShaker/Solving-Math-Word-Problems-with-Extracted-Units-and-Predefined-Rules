# %% [markdown]
# ## Data Loading

# %%
import os
import json
from glob import glob
import numpy as np
import pandas as pd
from collections import namedtuple
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktTrainer
from nltk.tokenize import RegexpTokenizer

# %%
train_docs_dir = 'C:/Users/DELL/Desktop/MeasEval/data/eval'

train_texts = ' '.join([open(txt_file, 'r').read() for txt_file in glob(os.path.join(train_docs_dir,'*.txt'))])
trainer = PunktTrainer()
trainer.INCLUDE_ALL_COLLOCS = True
trainer.train(train_texts)

sentenizer = PunktSentenceTokenizer(trainer.get_params())
tokenizer = RegexpTokenizer(r'\w+|\(|\)|\[|\]|[-–.,]|\S+')

# %%
annotations_dir = 'C:/Users/DELL/Desktop/MeasEval/data/eval/tsv'
docs_dir = 'C:/Users/DELL/Desktop/MeasEval/data/eval/text'

Sentence = namedtuple('Sentence', ['start', 'end', 'text'])

tsv_files = glob(os.path.join(annotations_dir,'*.tsv')) if annotations_dir is not None else []
txt_files = glob(os.path.join(docs_dir,'*.txt'))

docs = {'docId': [], 'text': []}
for txt_file in txt_files:
    docs['text'].append(open(txt_file, 'r', encoding='UTF-8').read())
    docs['docId'].append(os.path.split(txt_file)[1].split('.')[0])
#     docs['docId'].append(txt_file.split('/')[-1].split('.')[0])

docs = pd.DataFrame(docs)

docs.loc[:, 'texts'] = docs.text.apply(
    lambda x: [
        Sentence(start, end, text) for (start, end), text in zip(
            sentenizer.span_tokenize(x), sentenizer.tokenize(x)
        )
    ]
)

# %%
docs
# Out:
#                       docId  \
# 0    S0012821X12004384-1610
# 1     S0012821X12004384-990
# 2    S0012821X13007309-1649
# 3    S0016236113008041-3127
# 4    S0016236113008041-3257
# ..                      ...
# 130   S2213671113000738-667
# 131   S2213671113000738-787
# 132   S2213671113000908-643
# 133   S2213671113000921-756
# 134  S2213671113001306-1385
#
#                                                   text  \
# 0    The brief peak in Apectodinium, AOM and low sa...
# 1    Correspondence analysis (first two axes) for: ...
# 2    Lithology in the CTBI includes interbedded sha...
# 3    Thermodynamic modelling using MTDATA software ...
# 4    SEM–EDS analysis of sorbent sampled from the c...
# ..                                                 ...
# 130  Next, we investigated the expression of major ...
# 131  For in vivo studies, the fixed frozen brains w...
# 132  (F) After 25 days of differentiation, cells ex...
# 133  (B) IF analysis of day 8 SOX2-GFP AFE cultures...
# 134  On first postoperative exam (days 3–5), a whit...
#
#                                                  texts
# 0    [(0, 104, The brief peak in Apectodinium, AOM ...
# 1    [(0, 291, Correspondence analysis (first two a...
# 2    [(0, 103, Lithology in the CTBI includes inter...
# 3    [(0, 241, Thermodynamic modelling using MTDATA...
# 4    [(0, 155, SEM–EDS analysis of sorbent sampled ...
# ..                                                 ...
# 130  [(0, 118, Next, we investigated the expression...
# 131  [(0, 133, For in vivo studies, the fixed froze...
# 132  [(0, 91, (F) After 25 days of differentiation,...
# 133  [(0, 77, (B) IF analysis of day 8 SOX2-GFP AFE...
# 134  [(0, 203, On first postoperative exam (days 3–...
#
# [135 rows x 3 columns]

# %%
if annotations_dir is not None:
    annotations = pd.read_csv(tsv_files[0], sep='\t')
    for tsv_file in tsv_files[1:]:
        annotations = annotations.append(pd.read_csv(tsv_file, sep='\t'), ignore_index=True)
    annotations = annotations.replace(np.nan, '{}')
    annotations.loc[:, 'other'] = annotations.other.apply(lambda x: eval(x))
else:
    annotations = pd.DataFrame(columns=['docId', 'annotSet', 'annotType', 'startOffset', 'endOffset', 'annotId', 'text', 'other'])

# %%
annotations
# Out:
#                        docId  annotSet       annotType  startOffset  \
# 0     S0012821X12004384-1610         1        Quantity           90
# 1     S0012821X12004384-1610         1  MeasuredEntity            4
# 2     S0012821X12004384-1610         1       Qualifier           15
# 3     S0012821X12004384-1610         2        Quantity          669
# 4     S0012821X12004384-1610         2  MeasuredEntity          638
# ...                      ...       ...             ...          ...
# 1485   S2213671113000921-756         1        Quantity           69
# 1486   S2213671113000921-756         1  MeasuredEntity           48
# 1487  S2213671113001306-1385         1        Quantity          310
# 1488  S2213671113001306-1385         1  MeasuredEntity          293
# 1489  S2213671113001306-1385         1       Qualifier          324
#
#       endOffset annotId                 text  \
# 0            98    T1-1             2617.4 m
# 1            14    T3-1           brief peak
# 2            30    T4-1      in Apectodinium
# 3           688    T1-2  2619.6 and 2614.7 m
# 4           649    T3-2          other peaks
# ...         ...     ...                  ...
# 1485         75    T1-1               200 μm
# 1486         57    T2-1            scale bar
# 1487        323    T1-1        beyond 1 week
# 1488        308    T2-1      follow-up exams
# 1489        337    T4-1        postoperation
#
#                                       other
# 0                             {'unit': 'm'}
# 1                   {'HasQuantity': 'T1-1'}
# 2                     {'Qualifies': 'T3-1'}
# 3         {'mods': ['IsList'], 'unit': 'm'}
# 4                   {'HasQuantity': 'T1-2'}
# ...                                     ...
# 1485                         {'unit': 'μm'}
# 1486                {'HasQuantity': 'T1-1'}
# 1487  {'mods': ['IsRange'], 'unit': 'week'}
# 1488                {'HasQuantity': 'T1-1'}
# 1489                  {'Qualifies': 'T1-1'}
#
# [1490 rows x 8 columns]

# %% [markdown]
# ## Q, ME, MP, Qlr Tagging

# %%
# annotating tokens in each sentence for each doc

# examples = [exmaple]
# annotated_sent = [annotated_tokens[]]
# example = {
#     'docId': doc.docId,
#     'sentAnnot': annotated_sent
# }

Token = namedtuple('Token', ['start', 'end', 'text'])
AnnotatedToken = namedtuple('AnnotatedToken', ['start', 'end', 'text', 'label'])
only_labels='Quantity+MeasuredProperty+MeasuredEntity+Qualifier'

examples = []
for doc in docs.itertuples():
    doc_annotations = annotations[(annotations.docId == doc.docId) & (annotations.annotType.isin(only_labels.split('+')))]
#     print(doc)
#     print(doc_annotations)
    
    annotated_sent = []
    for sent in doc.texts:
        tokens = [
            Token(sent.start + start, sent.start + end, token)
            for (start, end), token in zip(
                tokenizer.span_tokenize(sent.text),
                tokenizer.tokenize(sent.text)
            )
        ]
        
#         print(sent)
#         for t in tokens:
#             print(t)
            
        # retrieve labels for each sentence
        AnnotatedSpan = namedtuple('AnnotatedSpan', ['start', 'end', 'label'])
        df = doc_annotations[(doc_annotations.startOffset >= sent.start) & (doc_annotations.endOffset <= sent.end)]
        sent_labels = [AnnotatedSpan(r.startOffset, r.endOffset, r.annotType) for r in df.itertuples()]
#         for l in sent_labels:
#             print("sent_labels", l)
            
        annotated_tokens = []
        for token in tokens:
            # initialise the annotation tag for the current token as 'O'
            tag = 'O'
            for sl in sent_labels:
                # check whether the current token is within the range of the current annotated span
                isInCurrRange = set(range(token.start, token.end)).intersection(set(range(sl.start, sl.end)))
                if isInCurrRange:
                    # check whether it's in the beginning (B) of the span
                    if token.start == sl.start:
                        tag = 'B-' + sl.label
                    # otherwise, it's in the internal (I) of the span
                    else:
                        tag = 'I-' + sl.label
            # append the annotated tag for the current token
            annotated_tokens.append(AnnotatedToken(token.start, token.end, token.text, tag))
        
#         for a in annotated_tokens:
#             print('annotated_tokens', a)
        
        if len(annotated_tokens) == len(tokens):
            annotated_sent.append(annotated_tokens)
    
#     for anns in annotated_sent:
#         for annt in anns:
#             print('annotated_tokens', annt)
            
    example = {
        'docId': doc.docId,
        'sentAnnot': annotated_sent
    }
    examples.append(example)

# %%
examples
# Out:
# [{'docId': 'S0012821X12004384-1610',
#   'sentAnnot': [[AnnotatedToken(start=0, end=3, text='The', label='O'),
#     AnnotatedToken(start=4, end=9, text='brief', label='B-MeasuredEntity'),
#     AnnotatedToken(start=10, end=14, text='peak', label='I-MeasuredEntity'),
#     AnnotatedToken(start=15, end=17, text='in', label='B-Qualifier'),
#     AnnotatedToken(start=18, end=30, text='Apectodinium', label='I-Qualifier'),
#     AnnotatedToken(start=30, end=31, text=',', label='O'),
#     AnnotatedToken(start=32, end=35, text='AOM', label='O'),
#     AnnotatedToken(start=36, end=39, text='and', label='O'),
#     AnnotatedToken(start=40, end=43, text='low', label='O'),
#     AnnotatedToken(start=44, end=52, text='salinity', label='O'),
#     AnnotatedToken(start=53, end=67, text='dinoflagellate', label='O'),
#     AnnotatedToken(start=68, end=73, text='cysts', label='O'),
#     AnnotatedToken(start=74, end=75, text='(', label='O'),
#     AnnotatedToken(start=75, end=85, text='Deflandrea', label='O'),
#     AnnotatedToken(start=85, end=86, text=')', label='O'),
#     AnnotatedToken(start=87, end=89, text='at', label='O'),
#     AnnotatedToken(start=90, end=94, text='2617', label='B-Quantity'),
#     AnnotatedToken(start=94, end=95, text='.', label='I-Quantity'),
#     AnnotatedToken(start=95, end=96, text='4', label='I-Quantity'),
#     AnnotatedToken(start=97, end=98, text='m', label='I-Quantity'),
#     AnnotatedToken(start=99, end=100, text='(', label='O'),
#     AnnotatedToken(start=100, end=103, text='Fig', label='O'),
#     AnnotatedToken(start=103, end=104, text='.', label='O')],
#    [AnnotatedToken(start=105, end=106, text='7', label='O'),
#     AnnotatedToken(start=106, end=107, text=')', label='O'),
#     AnnotatedToken(start=108, end=116, text='indicate', label='O'),
#     AnnotatedToken(start=117, end=118, text='a', label='O'),
#     AnnotatedToken(start=119, end=127, text='sporadic', label='O'),
#     AnnotatedToken(start=128, end=135, text='episode', label='O'),
#     AnnotatedToken(start=136, end=138, text='of', label='O'),
#     AnnotatedToken(start=139, end=146, text='surface', label='O'),
#     AnnotatedToken(start=147, end=152, text='water', label='O'),
#     AnnotatedToken(start=153, end=163, text='freshening', label='O'),
#     AnnotatedToken(start=163, end=178, text='/eutrophication', label='O'),
#     AnnotatedToken(start=179, end=185, text='before', label='O'),
#     AnnotatedToken(start=186, end=189, text='the', label='O'),
#     AnnotatedToken(start=190, end=193, text='CIE', label='O'),
#     AnnotatedToken(start=193, end=194, text=',', label='O'),
#     AnnotatedToken(start=195, end=200, text='which', label='O'),
#     AnnotatedToken(start=201, end=203, text='is', label='O'),
#     AnnotatedToken(start=204, end=208, text='best', label='O'),
#     AnnotatedToken(start=209, end=218, text='explained', label='O'),
#     AnnotatedToken(start=219, end=221, text='by', label='O'),
#     AnnotatedToken(start=222, end=224, text='an', label='O'),
#     AnnotatedToken(start=225, end=233, text='increase', label='O'),
#     AnnotatedToken(start=234, end=236, text='in', label='O'),
#     AnnotatedToken(start=237, end=245, text='regional', label='O'),
#     AnnotatedToken(start=246, end=259, text='precipitation', label='O'),
#     AnnotatedToken(start=260, end=263, text='due', label='O'),
#     AnnotatedToken(start=264, end=266, text='to', label='O'),
#     AnnotatedToken(start=267, end=270, text='its', label='O'),
#     AnnotatedToken(start=271, end=276, text='rapid', label='O'),
#     AnnotatedToken(start=277, end=283, text='nature', label='O'),
#     AnnotatedToken(start=283, end=284, text='.', label='O')],
#    [AnnotatedToken(start=285, end=286, text='A', label='O'),
#     AnnotatedToken(start=287, end=297, text='coincident', label='O'),
#     AnnotatedToken(start=298, end=307, text='reduction', label='O'),
#     AnnotatedToken(start=308, end=310, text='in', label='O'),
#     AnnotatedToken(start=311, end=312, text='I', label='O'),
#     AnnotatedToken(start=312, end=313, text='.', label='O'),
#     AnnotatedToken(start=314, end=320, text='hiatus', label='O'),
#     AnnotatedToken(start=321, end=326, text='swamp', label='O'),
#     AnnotatedToken(start=327, end=335, text='conifers', label='O'),
#     AnnotatedToken(start=336, end=345, text='indicates', label='O'),
#     AnnotatedToken(start=346, end=354, text='possible', label='O'),
#     AnnotatedToken(start=355, end=366, text='disturbance', label='O'),
#     AnnotatedToken(start=367, end=369, text='of', label='O'),
#     AnnotatedToken(start=370, end=376, text='nearby', label='O'),
#     AnnotatedToken(start=377, end=384, text='coastal', label='O'),
#     AnnotatedToken(start=385, end=397, text='environments', label='O'),
#     AnnotatedToken(start=398, end=406, text='possibly', label='O'),
#     AnnotatedToken(start=407, end=411, text='from', label='O'),
#     AnnotatedToken(start=412, end=420, text='flooding', label='O'),
#     AnnotatedToken(start=421, end=422, text='(', label='O'),
#     AnnotatedToken(start=422, end=425, text='see', label='O'),
#     AnnotatedToken(start=426, end=433, text='Section', label='O'),
#     AnnotatedToken(start=434, end=435, text='4', label='O'),
#     AnnotatedToken(start=435, end=436, text='.', label='O'),
#     AnnotatedToken(start=436, end=437, text='5', label='O'),
#     AnnotatedToken(start=437, end=438, text=')', label='O'),
#     AnnotatedToken(start=438, end=439, text='.', label='O')],
#    [AnnotatedToken(start=440, end=442, text='An', label='O'),
#     AnnotatedToken(start=443, end=453, text='associated', label='O'),
#     AnnotatedToken(start=454, end=463, text='reduction', label='O'),
#     AnnotatedToken(start=464, end=466, text='in', label='O'),
#     AnnotatedToken(start=467, end=471, text='δ13C', label='O'),
#     AnnotatedToken(start=472, end=475, text='may', label='O'),
#     AnnotatedToken(start=476, end=480, text='have', label='O'),
#     AnnotatedToken(start=481, end=485, text='been', label='O'),
#     AnnotatedToken(start=486, end=492, text='caused', label='O'),
#     AnnotatedToken(start=493, end=495, text='by', label='O'),
#     AnnotatedToken(start=496, end=510, text='stratification', label='O'),
#     AnnotatedToken(start=511, end=513, text='of', label='O'),
#     AnnotatedToken(start=514, end=517, text='the', label='O'),
#     AnnotatedToken(start=518, end=523, text='North', label='O'),
#     AnnotatedToken(start=524, end=527, text='Sea', label='O'),
#     AnnotatedToken(start=528, end=532, text='from', label='O'),
#     AnnotatedToken(start=533, end=535, text='an', label='O'),
#     AnnotatedToken(start=536, end=544, text='enhanced', label='O'),
#     AnnotatedToken(start=545, end=554, text='halocline', label='O'),
#     AnnotatedToken(start=554, end=555, text=',', label='O'),
#     AnnotatedToken(start=556, end=564, text='trapping', label='O'),
#     AnnotatedToken(start=565, end=568, text='12C', label='O'),
#     AnnotatedToken(start=568, end=569, text='-', label='O'),
#     AnnotatedToken(start=569, end=577, text='enriched', label='O'),
#     AnnotatedToken(start=578, end=585, text='organic', label='O'),
#     AnnotatedToken(start=586, end=592, text='carbon', label='O'),
#     AnnotatedToken(start=593, end=595, text='at', label='O'),
#     AnnotatedToken(start=596, end=601, text='depth', label='O'),
#     AnnotatedToken(start=601, end=602, text='.', label='O')],
#    [AnnotatedToken(start=603, end=607, text='This', label='O'),
#     AnnotatedToken(start=608, end=616, text='scenario', label='O'),
#     AnnotatedToken(start=617, end=620, text='may', label='O'),
#     AnnotatedToken(start=621, end=625, text='also', label='O'),
#     AnnotatedToken(start=626, end=633, text='explain', label='O'),
#     AnnotatedToken(start=634, end=637, text='the', label='O'),
#     AnnotatedToken(start=638, end=643, text='other', label='B-MeasuredEntity'),
#     AnnotatedToken(start=644, end=649, text='peaks', label='I-MeasuredEntity'),
#     AnnotatedToken(start=650, end=652, text='in', label='B-Qualifier'),
#     AnnotatedToken(start=653, end=665, text='Apectodinium', label='I-Qualifier'),
#     AnnotatedToken(start=666, end=668, text='at', label='O'),
#     AnnotatedToken(start=669, end=673, text='2619', label='B-Quantity'),
#     AnnotatedToken(start=673, end=674, text='.', label='I-Quantity'),
#     AnnotatedToken(start=674, end=675, text='6', label='I-Quantity'),
#     AnnotatedToken(start=676, end=679, text='and', label='I-Quantity'),
#     AnnotatedToken(start=680, end=684, text='2614', label='I-Quantity'),
#     AnnotatedToken(start=684, end=685, text='.', label='I-Quantity'),
#     AnnotatedToken(start=685, end=686, text='7', label='I-Quantity'),
#     AnnotatedToken(start=687, end=688, text='m', label='I-Quantity'),
#     AnnotatedToken(start=689, end=690, text='(', label='O'),
#     AnnotatedToken(start=690, end=698, text='although', label='O'),
#     AnnotatedToken(start=699, end=702, text='see', label='O'),
#     AnnotatedToken(start=703, end=710, text='Section', label='O'),
#     AnnotatedToken(start=711, end=712, text='4', label='O'),
#     AnnotatedToken(start=712, end=713, text='.', label='O'),
#     AnnotatedToken(start=713, end=714, text='1', label='O'),
#     AnnotatedToken(start=714, end=715, text=')', label='O'),
#     AnnotatedToken(start=715, end=716, text='.', label='O')]]},
#  {'docId': 'S0012821X12004384-990',
#   'sentAnnot': [[AnnotatedToken(start=0, end=14, text='Correspondence', label='O'),
#     AnnotatedToken(start=15, end=23, text='analysis', label='O'),
#     AnnotatedToken(start=24, end=25, text='(', label='O'),
#     AnnotatedToken(start=25, end=30, text='first', label='B-Qualifier'),
#     AnnotatedToken(start=31, end=34, text='two', label='B-Quantity'),
#     AnnotatedToken(start=35, end=39, text='axes', label='B-MeasuredEntity'),
#     AnnotatedToken(start=39, end=40, text=')', label='O'),
#     AnnotatedToken(start=41, end=44, text='for', label='O'),
#     AnnotatedToken(start=44, end=45, text=':', label='O'),
#     AnnotatedToken(start=46, end=47, text='(', label='O'),
#     AnnotatedToken(start=47, end=48, text='a', label='O'),
#     AnnotatedToken(start=48, end=49, text=')', label='O'),
#     AnnotatedToken(start=50, end=56, text='spores', label='O'),
#     AnnotatedToken(start=57, end=60, text='and', label='O'),
#     AnnotatedToken(start=61, end=67, text='pollen', label='O'),
#     AnnotatedToken(start=68, end=75, text='species', label='O'),
#     AnnotatedToken(start=76, end=77, text='(', label='O'),
#     AnnotatedToken(start=77, end=82, text='total', label='B-Qualifier'),
#     AnnotatedToken(start=83, end=89, text='counts', label='I-Qualifier'),
#     AnnotatedToken(start=90, end=93, text='per', label='I-Qualifier'),
#     AnnotatedToken(start=94, end=98, text='gram', label='I-Qualifier'),
#     AnnotatedToken(start=98, end=99, text=',', label='O'),
#     AnnotatedToken(start=100, end=104, text='axis', label='B-MeasuredProperty'),
#     AnnotatedToken(start=105, end=106, text='1', label='I-MeasuredProperty'),
#     AnnotatedToken(start=106, end=110, text='=39%', label='I-Quantity'),
#     AnnotatedToken(start=111, end=113, text='of', label='O'),
#     AnnotatedToken(start=114, end=119, text='total', label='B-MeasuredEntity'),
#     AnnotatedToken(start=120, end=128, text='variance', label='I-MeasuredEntity'),
#     AnnotatedToken(start=128, end=129, text=',', label='O'),
#     AnnotatedToken(start=130, end=134, text='axis', label='B-MeasuredProperty'),
#     AnnotatedToken(start=135, end=136, text='2', label='I-MeasuredProperty'),
#     AnnotatedToken(start=136, end=140, text='=17%', label='I-Quantity'),
#     AnnotatedToken(start=141, end=143, text='of', label='O'),
#     AnnotatedToken(start=144, end=149, text='total', label='B-MeasuredEntity'),
#     AnnotatedToken(start=150, end=158, text='variance', label='I-MeasuredEntity'),
#     AnnotatedToken(start=158, end=159, text=')', label='O'),
#     AnnotatedToken(start=160, end=163, text='and', label='O'),
#     AnnotatedToken(start=164, end=165, text='(', label='O'),
#     AnnotatedToken(start=165, end=166, text='b', label='O'),
#     AnnotatedToken(start=166, end=167, text=')', label='O'),
#     AnnotatedToken(start=168, end=182, text='dinoflagellate', label='O'),
#     AnnotatedToken(start=183, end=188, text='cysts', label='O'),
#     AnnotatedToken(start=189, end=190, text='(', label='O'),
#     AnnotatedToken(start=190, end=195, text='total', label='B-Qualifier'),
#     AnnotatedToken(start=196, end=202, text='counts', label='I-Qualifier'),
#     AnnotatedToken(start=203, end=206, text='per', label='I-Qualifier'),
#     AnnotatedToken(start=207, end=211, text='gram', label='I-Qualifier'),
#     AnnotatedToken(start=211, end=212, text=',', label='O'),
#     AnnotatedToken(start=213, end=217, text='axis', label='B-MeasuredProperty'),
#     AnnotatedToken(start=218, end=219, text='1', label='I-MeasuredProperty'),
#     AnnotatedToken(start=219, end=223, text='=31%', label='I-Quantity'),
#     AnnotatedToken(start=224, end=226, text='of', label='O'),
#     AnnotatedToken(start=227, end=232, text='total', label='B-MeasuredEntity'),
#     AnnotatedToken(start=233, end=241, text='variance', label='I-MeasuredEntity'),
#     AnnotatedToken(start=241, end=242, text=',', label='O'),
#     AnnotatedToken(start=243, end=247, text='axis', label='B-MeasuredProperty'),
#     AnnotatedToken(start=248, end=249, text='2', label='I-MeasuredProperty'),
#     AnnotatedToken(start=249, end=253, text='=11%', label='I-Quantity'),
#     AnnotatedToken(start=254, end=256, text='of', label='O'),
#     AnnotatedToken(start=257, end=262, text='total', label='B-MeasuredEntity'),
#     AnnotatedToken(start=263, end=271, text='variance', label='I-MeasuredEntity'),
#     AnnotatedToken(start=271, end=272, text=')', label='O'),
#     AnnotatedToken(start=272, end=273, text=',', label='O'),
#     AnnotatedToken(start=274, end=276, text='in', label='O'),
#     AnnotatedToken(start=277, end=281, text='core', label='O'),
#     AnnotatedToken(start=282, end=284, text='22', label='O'),
#     AnnotatedToken(start=284, end=291, text='/10a-4.', label='O')],
#    [AnnotatedToken(start=292, end=299, text='Symbols', label='O'),
#     AnnotatedToken(start=300, end=308, text='indicate', label='O'),
#     AnnotatedToken(start=309, end=315, text='depths', label='O'),
#     AnnotatedToken(start=316, end=319, text='for', label='O'),
#     AnnotatedToken(start=320, end=324, text='each', label='O'),
#     AnnotatedToken(start=325, end=331, text='pollen', label='O'),
#     AnnotatedToken(start=332, end=342, text='assemblage', label='O'),
#     AnnotatedToken(start=343, end=344, text='(', label='O'),
#     AnnotatedToken(start=344, end=346, text='PA', label='O'),
#     AnnotatedToken(start=346, end=347, text=')', label='O'),
#     AnnotatedToken(start=348, end=351, text='and', label='O'),
#     AnnotatedToken(start=352, end=366, text='dinoflagellate', label='O'),
#     AnnotatedToken(start=367, end=371, text='cyst', label='O'),
#     AnnotatedToken(start=372, end=382, text='assemblage', label='O'),
#     AnnotatedToken(start=383, end=384, text='(', label='O'),
#     AnnotatedToken(start=384, end=386, text='DA', label='O'),
#     AnnotatedToken(start=386, end=387, text=')', label='O'),
#     AnnotatedToken(start=387, end=388, text=',', label='O'),
#     AnnotatedToken(start=389, end=392, text='and', label='O'),
#     AnnotatedToken(start=393, end=398, text='their', label='O'),
#     AnnotatedToken(start=399, end=414, text='correspondingly', label='O'),
#     AnnotatedToken(start=415, end=419, text='most', label='O'),
#     AnnotatedToken(start=420, end=430, text='associated', label='O'),
#     AnnotatedToken(start=431, end=442, text='palynomorph', label='O'),
#     AnnotatedToken(start=443, end=450, text='species', label='O'),
#     AnnotatedToken(start=450, end=451, text='.', label='O')],
#    [AnnotatedToken(start=452, end=458, text='Marked', label='O'),
#     AnnotatedToken(start=459, end=465, text='depths', label='O'),
#     AnnotatedToken(start=466, end=467, text='(', label='O'),
#     AnnotatedToken(start=467, end=470, text='red', label='O'),
#     AnnotatedToken(start=470, end=471, text=')', label='O'),
#     AnnotatedToken(start=472, end=480, text='indicate', label='O'),
#     AnnotatedToken(start=481, end=484, text='the', label='O'),
#     AnnotatedToken(start=485, end=492, text='samples', label='O'),
#     AnnotatedToken(start=493, end=497, text='with', label='O'),
#     AnnotatedToken(start=498, end=501, text='pre', label='O'),
#     AnnotatedToken(start=501, end=502, text='-', label='O'),
#     AnnotatedToken(start=502, end=505, text='CIE', label='O'),
#     AnnotatedToken(start=506, end=511, text='peaks', label='O'),
#     AnnotatedToken(start=512, end=514, text='in', label='O'),
#     AnnotatedToken(start=515, end=527, text='Apectodinium', label='O'),
#     AnnotatedToken(start=528, end=531, text='and', label='O'),
#     AnnotatedToken(start=532, end=539, text='δ13CTOC', label='O'),
#     AnnotatedToken(start=539, end=540, text='.', label='O')],
#    [AnnotatedToken(start=541, end=548, text='Samples', label='B-MeasuredEntity'),
#     AnnotatedToken(start=549, end=551, text='at', label='O'),
#     AnnotatedToken(start=552, end=556, text='2619', label='B-Quantity'),
#     AnnotatedToken(start=556, end=557, text='.', label='I-Quantity'),
#     AnnotatedToken(start=557, end=559, text='60', label='I-Quantity'),
#     AnnotatedToken(start=560, end=561, text='m', label='I-Quantity'),
#     AnnotatedToken(start=562, end=565, text='and', label='I-Quantity'),
#     AnnotatedToken(start=566, end=570, text='2614', label='I-Quantity'),
#     AnnotatedToken(start=570, end=571, text='.', label='I-Quantity'),
#     AnnotatedToken(start=571, end=573, text='71', label='I-Quantity'),
#     AnnotatedToken(start=574, end=575, text='m', label='I-Quantity'),
#     AnnotatedToken(start=576, end=577, text='(', label='O'),
#     AnnotatedToken(start=577, end=580, text='see', label='O'),
#     AnnotatedToken(start=581, end=584, text='Fig', label='O'),
#     AnnotatedToken(start=584, end=585, text='.', label='O')],
#    [AnnotatedToken(start=586, end=587, text='4', label='O'),
#     AnnotatedToken(start=587, end=588, text=')', label='O'),
#     AnnotatedToken(start=589, end=593, text='plot', label='O'),
#     AnnotatedToken(start=594, end=599, text='close', label='O'),
#     AnnotatedToken(start=600, end=602, text='to', label='O'),
#     AnnotatedToken(start=603, end=607, text='post', label='O'),
#     AnnotatedToken(start=607, end=608, text='-', label='O'),
#     AnnotatedToken(start=608, end=611, text='CIE', label='O'),
#     AnnotatedToken(start=612, end=617, text='onset', label='O'),
#     AnnotatedToken(start=618, end=629, text='assemblages', label='O'),
#     AnnotatedToken(start=630, end=633, text='PA3', label='O'),
#     AnnotatedToken(start=634, end=637, text='and', label='O'),
#     AnnotatedToken(start=638, end=641, text='PA4', label='O'),
#     AnnotatedToken(start=641, end=642, text=',', label='O'),
#     AnnotatedToken(start=643, end=646, text='and', label='O'),
#     AnnotatedToken(start=647, end=653, text='either', label='O'),
#     AnnotatedToken(start=654, end=663, text='represent', label='O'),
#     AnnotatedToken(start=664, end=673, text='ephemeral', label='O'),
#     AnnotatedToken(start=674, end=682, text='episodes', label='O'),
#     AnnotatedToken(start=683, end=685, text='of', label='O'),
#     AnnotatedToken(start=686, end=692, text='marine', label='O'),
#     AnnotatedToken(start=693, end=696, text='and', label='O'),
#     AnnotatedToken(start=697, end=707, text='vegetation', label='O'),
#     AnnotatedToken(start=708, end=715, text='changes', label='O'),
#     AnnotatedToken(start=716, end=718, text='to', label='O'),
#     AnnotatedToken(start=719, end=723, text='post', label='O'),
#     AnnotatedToken(start=723, end=724, text='-', label='O'),
#     AnnotatedToken(start=724, end=727, text='CIE', label='O'),
#     AnnotatedToken(start=728, end=733, text='onset', label='O'),
#     AnnotatedToken(start=734, end=738, text='type', label='O'),
#     AnnotatedToken(start=739, end=749, text='conditions', label='O'),
#     AnnotatedToken(start=749, end=750, text=',', label='O'),
#     AnnotatedToken(start=751, end=753, text='or', label='O'),
#     AnnotatedToken(start=754, end=762, text='possible', label='O'),
#     AnnotatedToken(start=763, end=772, text='misplaced', label='O'),
#     AnnotatedToken(start=773, end=780, text='samples', label='O'),
#     AnnotatedToken(start=781, end=787, text='during', label='O'),
#     AnnotatedToken(start=788, end=796, text='drilling', label='O'),
#     AnnotatedToken(start=797, end=807, text='operations', label='O'),
#     AnnotatedToken(start=808, end=812, text='core', label='O'),
#     AnnotatedToken(start=813, end=821, text='handling', label='O'),
#     AnnotatedToken(start=821, end=822, text='.', label='O')],
#    [AnnotatedToken(start=823, end=831, text='Analysis', label='O'),
#     AnnotatedToken(start=832, end=839, text='carried', label='O'),
#     AnnotatedToken(start=840, end=843, text='out', label='O'),
#     AnnotatedToken(start=844, end=849, text='using', label='O'),
#     AnnotatedToken(start=850, end=853, text='the', label='O'),
#     AnnotatedToken(start=854, end=862, text='software', label='O'),
#     AnnotatedToken(start=863, end=865, text='of', label='O'),
#     AnnotatedToken(start=866, end=872, text='Hammer', label='O'),
#     AnnotatedToken(start=873, end=875, text='et', label='O'),
#     AnnotatedToken(start=876, end=878, text='al', label='O'),
#     AnnotatedToken(start=878, end=879, text='.', label='O')],
#    [AnnotatedToken(start=880, end=881, text='(', label='O'),
#     AnnotatedToken(start=881, end=885, text='2005', label='O'),
#     AnnotatedToken(start=885, end=886, text=')', label='O'),
#     AnnotatedToken(start=886, end=887, text='.', label='O')],
#    [AnnotatedToken(start=888, end=889, text='(', label='O'),
#     AnnotatedToken(start=889, end=892, text='For', label='O'),
#     AnnotatedToken(start=893, end=907, text='interpretation', label='O'),
#     AnnotatedToken(start=908, end=910, text='of', label='O'),
#     AnnotatedToken(start=911, end=914, text='the', label='O'),
#     AnnotatedToken(start=915, end=925, text='references', label='O'),
#     AnnotatedToken(start=926, end=928, text='to', label='O'),
#     AnnotatedToken(start=929, end=934, text='color', label='O'),
#     AnnotatedToken(start=935, end=937, text='in', label='O'),
#     AnnotatedToken(start=938, end=942, text='this', label='O'),
#     AnnotatedToken(start=943, end=949, text='figure', label='O'),
#     AnnotatedToken(start=950, end=957, text='caption', label='O'),
#     AnnotatedToken(start=957, end=958, text=',', label='O'),
#     AnnotatedToken(start=959, end=962, text='the', label='O'),
#     AnnotatedToken(start=963, end=969, text='reader', label='O'),
#     AnnotatedToken(start=970, end=972, text='is', label='O'),
#     AnnotatedToken(start=973, end=981, text='referred', label='O'),
#     AnnotatedToken(start=982, end=984, text='to', label='O'),
#     AnnotatedToken(start=985, end=988, text='the', label='O'),
#     AnnotatedToken(start=989, end=992, text='web', label='O'),
#     AnnotatedToken(start=993, end=1000, text='version', label='O'),
#     AnnotatedToken(start=1001, end=1003, text='of', label='O'),
#     AnnotatedToken(start=1004, end=1008, text='this', label='O'),
#     AnnotatedToken(start=1009, end=1016, text='article', label='O'),
#     AnnotatedToken(start=1016, end=1017, text='.', label='O'),
#     AnnotatedToken(start=1017, end=1018, text=')', label='O')]]},
#  {'docId': 'S0012821X13007309-1649',
#   'sentAnnot': [[AnnotatedToken(start=0, end=9, text='Lithology', label='O'),
#     AnnotatedToken(start=10, end=12, text='in', label='O'),
#     AnnotatedToken(start=13, end=16, text='the', label='O'),
#     AnnotatedToken(start=17, end=21, text='CTBI', label='O'),
#     AnnotatedToken(start=22, end=30, text='includes', label='O'),
#     AnnotatedToken(start=31, end=42, text='interbedded', label='O'),
#     AnnotatedToken(start=43, end=49, text='shales', label='O'),
#     AnnotatedToken(start=49, end=50, text=',', label='O'),
#     AnnotatedToken(start=51, end=56, text='clays', label='O'),
#     AnnotatedToken(start=57, end=60, text='and', label='O'),
#     AnnotatedToken(start=61, end=70, text='mudstones', label='O'),
#     AnnotatedToken(start=70, end=71, text=',', label='O'),
#     AnnotatedToken(start=72, end=76, text='some', label='O'),
#     AnnotatedToken(start=77, end=79, text='of', label='O'),
#     AnnotatedToken(start=80, end=85, text='which', label='O'),
#     AnnotatedToken(start=86, end=89, text='are', label='O'),
#     AnnotatedToken(start=90, end=102, text='pyritiferous', label='O'),
#     AnnotatedToken(start=102, end=103, text='.', label='O')],
#    [AnnotatedToken(start=104, end=107, text='The', label='O'),
#     AnnotatedToken(start=108, end=115, text='organic', label='O'),
#     AnnotatedToken(start=116, end=122, text='matter', label='O'),
#     AnnotatedToken(start=123, end=125, text='in', label='O'),
#     AnnotatedToken(start=126, end=129, text='the', label='O'),
#     AnnotatedToken(start=130, end=135, text='black', label='O'),
#     AnnotatedToken(start=136, end=142, text='shales', label='O'),
#     AnnotatedToken(start=143, end=145, text='is', label='O'),
#     AnnotatedToken(start=146, end=148, text='of', label='O'),
#     AnnotatedToken(start=149, end=155, text='marine', label='O'),
#     AnnotatedToken(start=156, end=162, text='origin', label='O'),
#     AnnotatedToken(start=162, end=163, text=',', label='O'),
#     AnnotatedToken(start=164, end=167, text='but', label='O'),
#     AnnotatedToken(start=168, end=176, text='includes', label='O'),
#     AnnotatedToken(start=177, end=178, text='a', label='O'),
#     AnnotatedToken(start=179, end=190, text='significant', label='O'),
#     AnnotatedToken(start=191, end=199, text='fraction', label='O'),
#     AnnotatedToken(start=200, end=202, text='of', label='O'),
#     AnnotatedToken(start=203, end=214, text='terrigenous', label='O'),
#     AnnotatedToken(start=215, end=223, text='material', label='O'),
#     AnnotatedToken(start=224, end=225, text='(', label='O'),
#     AnnotatedToken(start=225, end=232, text='Forster', label='O'),
#     AnnotatedToken(start=233, end=235, text='et', label='O'),
#     AnnotatedToken(start=236, end=238, text='al', label='O'),
#     AnnotatedToken(start=238, end=239, text='.', label='O'),
#     AnnotatedToken(start=239, end=240, text=',', label='O'),
#     AnnotatedToken(start=241, end=245, text='2008', label='O'),
#     AnnotatedToken(start=245, end=246, text=')', label='O'),
#     AnnotatedToken(start=246, end=247, text='.', label='O')],
#    [AnnotatedToken(start=248, end=251, text='The', label='O'),
#     AnnotatedToken(start=252, end=257, text='black', label='O'),
#     AnnotatedToken(start=258, end=264, text='shales', label='O'),
#     AnnotatedToken(start=265, end=268, text='are', label='O'),
#     AnnotatedToken(start=269, end=275, text='highly', label='O'),
#     AnnotatedToken(start=276, end=285, text='laminated', label='O'),
#     AnnotatedToken(start=286, end=289, text='and', label='O'),
#     AnnotatedToken(start=290, end=300, text='relatively', label='O'),
#     AnnotatedToken(start=301, end=312, text='undisturbed', label='O'),
#     AnnotatedToken(start=313, end=315, text='by', label='O'),
#     AnnotatedToken(start=316, end=328, text='bioturbation', label='O'),
#     AnnotatedToken(start=328, end=329, text='.', label='O')],
#    [AnnotatedToken(start=330, end=333, text='The', label='O'),
#     AnnotatedToken(start=334, end=341, text='δ13Corg', label='O'),
#     AnnotatedToken(start=342, end=348, text='record', label='O'),
#     AnnotatedToken(start=349, end=351, text='is', label='O'),
#     AnnotatedToken(start=352, end=362, text='incomplete', label='O'),
#     AnnotatedToken(start=363, end=366, text='due', label='O'),
#     AnnotatedToken(start=367, end=369, text='to', label='O'),
#     AnnotatedToken(start=370, end=374, text='poor', label='O'),
#     AnnotatedToken(start=375, end=379, text='core', label='O'),
#     AnnotatedToken(start=380, end=388, text='recovery', label='O'),
#     AnnotatedToken(start=389, end=392, text='and', label='O'),
#     AnnotatedToken(start=393, end=396, text='low', label='O'),
#     AnnotatedToken(start=397, end=403, text='sample', label='O'),
#     AnnotatedToken(start=404, end=409, text='yield', label='O'),
#     AnnotatedToken(start=409, end=410, text=',', label='O'),
#     AnnotatedToken(start=411, end=414, text='but', label='O'),
#     AnnotatedToken(start=415, end=417, text='an', label='O'),
#     AnnotatedToken(start=418, end=427, text='excursion', label='O'),
#     AnnotatedToken(start=428, end=438, text='signifying', label='O'),
#     AnnotatedToken(start=439, end=442, text='OAE', label='B-MeasuredEntity'),
#     AnnotatedToken(start=443, end=444, text='2', label='I-MeasuredEntity'),
#     AnnotatedToken(start=445, end=447, text='is', label='O'),
#     AnnotatedToken(start=448, end=456, text='recorded', label='O'),
#     AnnotatedToken(start=456, end=457, text=':', label='O'),
#     AnnotatedToken(start=458, end=459, text='a', label='O'),
#     AnnotatedToken(start=460, end=461, text='0', label='B-Quantity'),
#     AnnotatedToken(start=461, end=462, text='.', label='I-Quantity'),
#     AnnotatedToken(start=462, end=463, text='5', label='I-Quantity'),
#     AnnotatedToken(start=463, end=464, text='‰', label='I-Quantity'),
#     AnnotatedToken(start=465, end=469, text='VPDB', label='B-Qualifier'),
#     AnnotatedToken(start=470, end=478, text='negative', label='I-MeasuredProperty'),
#     AnnotatedToken(start=479, end=484, text='shift', label='I-MeasuredProperty'),
#     AnnotatedToken(start=485, end=496, text='immediately', label='O'),
#     AnnotatedToken(start=497, end=505, text='precedes', label='O'),
#     AnnotatedToken(start=506, end=509, text='the', label='O'),
#     AnnotatedToken(start=510, end=511, text='4', label='B-MeasuredProperty'),
#     AnnotatedToken(start=511, end=512, text='‰', label='I-MeasuredProperty'),
#     AnnotatedToken(start=513, end=521, text='positive', label='I-MeasuredProperty'),
#     AnnotatedToken(start=522, end=531, text='excursion', label='I-MeasuredProperty'),
#     AnnotatedToken(start=531, end=532, text=',', label='O'),
#     AnnotatedToken(start=533, end=538, text='−27.7', label='B-Quantity'),
#     AnnotatedToken(start=539, end=541, text='to', label='I-Quantity'),
#     AnnotatedToken(start=542, end=548, text='−23.7‰', label='I-Quantity'),
#     AnnotatedToken(start=549, end=550, text='(', label='O'),
#     AnnotatedToken(start=550, end=553, text='Fig', label='O'),
#     AnnotatedToken(start=553, end=554, text='.', label='O')],
#    [AnnotatedToken(start=555, end=556, text='2', label='O'),
#     AnnotatedToken(start=556, end=557, text=';', label='O'),
#     AnnotatedToken(start=558, end=571, text='Supplementary', label='O'),
#     AnnotatedToken(start=572, end=580, text='Material', label='O'),
#     AnnotatedToken(start=580, end=581, text=',', label='O'),
#     AnnotatedToken(start=582, end=587, text='Table', label='O'),
#     AnnotatedToken(start=588, end=590, text='1f', label='O'),
#     AnnotatedToken(start=590, end=591, text=';', label='O'),
#     AnnotatedToken(start=592, end=599, text='Forster', label='O'),
#     AnnotatedToken(start=600, end=602, text='et', label='O'),
#     AnnotatedToken(start=603, end=605, text='al', label='O'),
#     AnnotatedToken(start=605, end=606, text='.', label='O'),
#     AnnotatedToken(start=606, end=607, text=',', label='O'),
#     AnnotatedToken(start=608, end=612, text='2008', label='O'),
#     AnnotatedToken(start=612, end=613, text=')', label='O'),
#     AnnotatedToken(start=613, end=614, text='.', label='O')],
#    [AnnotatedToken(start=615, end=618, text='The', label='O'),
#     AnnotatedToken(start=619, end=633, text='characteristic', label='O'),
#     AnnotatedToken(start=634, end=643, text='excursion', label='B-MeasuredEntity'),
#     AnnotatedToken(start=644, end=649, text='spans', label='O'),
#     AnnotatedToken(start=650, end=652, text='∼2', label='B-Quantity'),
#     AnnotatedToken(start=653, end=654, text='m', label='I-Quantity'),
#     AnnotatedToken(start=655, end=657, text='of', label='O'),
#     AnnotatedToken(start=658, end=664, text='finely', label='O'),
#     AnnotatedToken(start=665, end=676, text='interbedded', label='O'),
#     AnnotatedToken(start=677, end=683, text='shales', label='O'),
#     AnnotatedToken(start=684, end=687, text='and', label='O'),
#     AnnotatedToken(start=688, end=697, text='mudstones', label='O'),
#     AnnotatedToken(start=697, end=698, text='.', label='O')],
#    [AnnotatedToken(start=699, end=709, text='Throughout', label='O'),
#     AnnotatedToken(start=710, end=713, text='OAE', label='B-MeasuredEntity'),
#     AnnotatedToken(start=714, end=715, text='2', label='I-MeasuredEntity'),
#     AnnotatedToken(start=715, end=716, text=',', label='O'),
#     AnnotatedToken(start=717, end=720, text='the', label='O'),
#     AnnotatedToken(start=721, end=728, text='δ13Corg', label='B-MeasuredProperty'),
#     AnnotatedToken(start=729, end=735, text='values', label='I-MeasuredProperty'),
#     AnnotatedToken(start=736, end=745, text='fluctuate', label='O'),
#     AnnotatedToken(start=746, end=753, text='between', label='B-Quantity'),
#     AnnotatedToken(start=754, end=761, text='∼−23.5‰', label='I-Quantity'),
#     AnnotatedToken(start=762, end=764, text='to', label='I-Quantity'),
#     AnnotatedToken(start=765, end=772, text='−27.5‰.', label='I-Quantity')],
#    [AnnotatedToken(start=773, end=776, text='The', label='O'),
#     AnnotatedToken(start=777, end=784, text='maximum', label='B-MeasuredProperty'),
#     AnnotatedToken(start=785, end=795, text='enrichment', label='I-MeasuredProperty'),
#     AnnotatedToken(start=796, end=798, text='in', label='O'),
#     AnnotatedToken(start=799, end=802, text='the', label='O'),
#     AnnotatedToken(start=803, end=810, text='δ13Corg', label='B-MeasuredEntity'),
#     AnnotatedToken(start=811, end=813, text='is', label='O'),
#     AnnotatedToken(start=814, end=816, text='at', label='O'),
#     AnnotatedToken(start=817, end=821, text='1035', label='B-Quantity'),
#     AnnotatedToken(start=821, end=822, text='.', label='I-Quantity'),
#     AnnotatedToken(start=822, end=824, text='75', label='I-Quantity'),
#     AnnotatedToken(start=825, end=829, text='mbsf', label='I-Quantity'),
#     AnnotatedToken(start=829, end=830, text=',', label='O'),
#     AnnotatedToken(start=831, end=836, text='∼3.52', label='B-Quantity'),
#     AnnotatedToken(start=837, end=838, text='m', label='I-Quantity'),
#     AnnotatedToken(start=839, end=843, text='into', label='B-Qualifier'),
#     AnnotatedToken(start=844, end=847, text='OAE', label='I-Qualifier'),
#     AnnotatedToken(start=848, end=849, text='2', label='I-Qualifier'),
#     AnnotatedToken(start=850, end=851, text='(', label='O'),
#     AnnotatedToken(start=851, end=858, text='Forster', label='O'),
#     AnnotatedToken(start=859, end=861, text='et', label='O'),
#     AnnotatedToken(start=862, end=864, text='al', label='O'),
#     AnnotatedToken(start=864, end=865, text='.', label='O'),
#     AnnotatedToken(start=865, end=866, text=',', label='O'),
#     AnnotatedToken(start=867, end=871, text='2008', label='O'),
#     AnnotatedToken(start=871, end=872, text=')', label='O'),
#     AnnotatedToken(start=872, end=873, text='.', label='O')]]},
#  {'docId': 'S0016236113008041-3127',
#   'sentAnnot': [[AnnotatedToken(start=0, end=13, text='Thermodynamic', label='O'),
#     AnnotatedToken(start=14, end=23, text='modelling', label='O'),
#     AnnotatedToken(start=24, end=29, text='using', label='O'),
#     AnnotatedToken(start=30, end=36, text='MTDATA', label='O'),
#     AnnotatedToken(start=37, end=45, text='software', label='O'),
#     AnnotatedToken(start=46, end=49, text='was', label='O'),
#     AnnotatedToken(start=50, end=60, text='undertaken', label='O'),
#     AnnotatedToken(start=61, end=63, text='in', label='O'),
#     AnnotatedToken(start=64, end=72, text='addition', label='O'),
#     AnnotatedToken(start=73, end=75, text='to', label='O'),
#     AnnotatedToken(start=76, end=81, text='pilot', label='O'),
#     AnnotatedToken(start=82, end=87, text='scale', label='O'),
#     AnnotatedToken(start=88, end=93, text='tests', label='O'),
#     AnnotatedToken(start=93, end=94, text=',', label='O'),
#     AnnotatedToken(start=95, end=97, text='in', label='O'),
#     AnnotatedToken(start=98, end=99, text='a', label='O'),
#     AnnotatedToken(start=100, end=103, text='bid', label='O'),
#     AnnotatedToken(start=104, end=106, text='to', label='O'),
#     AnnotatedToken(start=107, end=114, text='improve', label='O'),
#     AnnotatedToken(start=115, end=128, text='understanding', label='O'),
#     AnnotatedToken(start=129, end=131, text='of', label='O'),
#     AnnotatedToken(start=132, end=135, text='the', label='O'),
#     AnnotatedToken(start=136, end=142, text='likely', label='O'),
#     AnnotatedToken(start=143, end=152, text='compounds', label='O'),
#     AnnotatedToken(start=153, end=156, text='and', label='O'),
#     AnnotatedToken(start=157, end=167, text='associated', label='O'),
#     AnnotatedToken(start=168, end=173, text='phase', label='O'),
#     AnnotatedToken(start=174, end=183, text='formation', label='O'),
#     AnnotatedToken(start=184, end=186, text='of', label='O'),
#     AnnotatedToken(start=187, end=195, text='elements', label='O'),
#     AnnotatedToken(start=196, end=201, text='under', label='O'),
#     AnnotatedToken(start=202, end=213, text='carbonation', label='O'),
#     AnnotatedToken(start=214, end=217, text='and', label='O'),
#     AnnotatedToken(start=218, end=229, text='calcination', label='O'),
#     AnnotatedToken(start=230, end=240, text='conditions', label='O'),
#     AnnotatedToken(start=240, end=241, text='.', label='O')],
#    [AnnotatedToken(start=242, end=251, text='Modelling', label='O'),
#     AnnotatedToken(start=252, end=255, text='was', label='O'),
#     AnnotatedToken(start=256, end=266, text='undertaken', label='O'),
#     AnnotatedToken(start=267, end=270, text='for', label='O'),
#     AnnotatedToken(start=271, end=272, text='4', label='B-Quantity'),
#     AnnotatedToken(start=273, end=278, text='major', label='B-MeasuredEntity'),
#     AnnotatedToken(start=279, end=287, text='elements', label='I-MeasuredEntity'),
#     AnnotatedToken(start=288, end=289, text='(', label='O'),
#     AnnotatedToken(start=289, end=290, text='C', label='O'),
#     AnnotatedToken(start=290, end=291, text=',', label='O'),
#     AnnotatedToken(start=292, end=294, text='Ca', label='O'),
#     AnnotatedToken(start=294, end=295, text=',', label='O'),
#     AnnotatedToken(start=296, end=297, text='O', label='O'),
#     AnnotatedToken(start=297, end=298, text=',', label='O'),
#     AnnotatedToken(start=299, end=302, text='and', label='O'),
#     AnnotatedToken(start=303, end=304, text='H', label='O'),
#     AnnotatedToken(start=304, end=305, text=')', label='O'),
#     AnnotatedToken(start=306, end=309, text='and', label='O'),
#     AnnotatedToken(start=310, end=312, text='up', label='B-Quantity'),
#     AnnotatedToken(start=313, end=315, text='to', label='I-Quantity'),
#     AnnotatedToken(start=316, end=317, text='9', label='I-Quantity'),
#     AnnotatedToken(start=318, end=323, text='minor', label='B-MeasuredEntity'),
#     AnnotatedToken(start=324, end=332, text='elements', label='I-MeasuredEntity'),
#     AnnotatedToken(start=333, end=334, text='(', label='O'),
#     AnnotatedToken(start=334, end=336, text='Ba', label='O'),
#     AnnotatedToken(start=336, end=337, text=',', label='O'),
#     AnnotatedToken(start=338, end=340, text='Cd', label='O'),
#     AnnotatedToken(start=340, end=341, text=',', label='O'),
#     AnnotatedToken(start=342, end=344, text='Cr', label='O'),
#     AnnotatedToken(start=344, end=345, text=',', label='O'),
#     AnnotatedToken(start=346, end=347, text='K', label='O'),
#     AnnotatedToken(start=347, end=348, text=',', label='O'),
#     AnnotatedToken(start=349, end=351, text='Mg', label='O'),
#     AnnotatedToken(start=351, end=352, text=',', label='O'),
#     AnnotatedToken(start=353, end=355, text='Ni', label='O'),
#     AnnotatedToken(start=355, end=356, text=',', label='O'),
#     AnnotatedToken(start=357, end=359, text='Sr', label='O'),
#     AnnotatedToken(start=359, end=360, text=',', label='O'),
#     AnnotatedToken(start=361, end=363, text='Ti', label='O'),
#     AnnotatedToken(start=363, end=364, text=',', label='O'),
#     AnnotatedToken(start=365, end=368, text='and', label='O'),
#     AnnotatedToken(start=369, end=371, text='Zn', label='O'),
#     AnnotatedToken(start=371, end=372, text=')', label='O'),
#     AnnotatedToken(start=373, end=378, text='based', label='O'),
#     AnnotatedToken(start=379, end=381, text='on', label='O'),
#     AnnotatedToken(start=382, end=387, text='those', label='O'),
#     AnnotatedToken(start=388, end=393, text='which', label='O'),
#     AnnotatedToken(start=394, end=397, text='are', label='O'),
#     AnnotatedToken(start=398, end=408, text='considered', label='O'),
#     AnnotatedToken(start=409, end=411, text='to', label='O'),
#     AnnotatedToken(start=412, end=414, text='be', label='O'),
#     AnnotatedToken(start=415, end=419, text='most', label='O'),
#     AnnotatedToken(start=420, end=428, text='volatile', label='O'),
#     AnnotatedToken(start=428, end=429, text=',', label='O'),
#     AnnotatedToken(start=430, end=434, text='have', label='O'),
#     AnnotatedToken(start=435, end=438, text='the', label='O'),
#     AnnotatedToken(start=439, end=447, text='greatest', label='O'),
#     AnnotatedToken(start=448, end=456, text='negative', label='O'),
#     AnnotatedToken(start=457, end=463, text='impact', label='O'),
#     AnnotatedToken(start=464, end=466, text='on', label='O'),
#     AnnotatedToken(start=467, end=470, text='the', label='O'),
#     AnnotatedToken(start=471, end=482, text='environment', label='O'),
#     AnnotatedToken(start=483, end=486, text='and', label='O'),
#     AnnotatedToken(start=487, end=493, text='health', label='O'),
#     AnnotatedToken(start=493, end=494, text=',', label='O'),
#     AnnotatedToken(start=495, end=498, text='and', label='O'),
#     AnnotatedToken(start=499, end=504, text='which', label='O'),
#     AnnotatedToken(start=505, end=509, text='were', label='O'),
#     AnnotatedToken(start=510, end=517, text='present', label='O'),
#     AnnotatedToken(start=518, end=520, text='in', label='O'),
#     AnnotatedToken(start=521, end=524, text='the', label='O'),
#     AnnotatedToken(start=525, end=532, text='highest', label='O'),
#     AnnotatedToken(start=533, end=543, text='quantities', label='O'),
#     AnnotatedToken(start=544, end=546, text='in', label='O'),
#     AnnotatedToken(start=547, end=550, text='the', label='O'),
#     AnnotatedToken(start=551, end=560, text='limestone', label='O'),
#     AnnotatedToken(start=561, end=563, text='as', label='O'),
#     AnnotatedToken(start=564, end=574, text='identified', label='O'),
#     AnnotatedToken(start=575, end=577, text='by', label='O'),
#     AnnotatedToken(start=578, end=581, text='ICP', label='O'),
#     AnnotatedToken(start=581, end=582, text='-', label='O'),
#     AnnotatedToken(start=582, end=584, text='MS', label='O'),
#     AnnotatedToken(start=585, end=593, text='analysis', label='O'),
#     AnnotatedToken(start=594, end=596, text='as', label='O'),
#     AnnotatedToken(start=597, end=605, text='outlined', label='O'),
#     AnnotatedToken(start=606, end=608, text='in', label='O'),
#     AnnotatedToken(start=609, end=614, text='Table', label='O'),
#     AnnotatedToken(start=615, end=616, text='2', label='O'),
#     AnnotatedToken(start=616, end=617, text=',', label='O'),
#     AnnotatedToken(start=618, end=620, text='in', label='O'),
#     AnnotatedToken(start=621, end=626, text='order', label='O'),
#     AnnotatedToken(start=627, end=629, text='to', label='O'),
#     AnnotatedToken(start=630, end=641, text='investigate', label='O'),
#     AnnotatedToken(start=642, end=654, text='partitioning', label='O'),
#     AnnotatedToken(start=655, end=664, text='behaviour', label='O'),
#     AnnotatedToken(start=665, end=670, text='under', label='O'),
#     AnnotatedToken(start=671, end=676, text='pilot', label='O'),
#     AnnotatedToken(start=677, end=682, text='scale', label='O'),
#     AnnotatedToken(start=683, end=686, text='CO2', label='O'),
#     AnnotatedToken(start=687, end=694, text='capture', label='O'),
#     AnnotatedToken(start=695, end=705, text='conditions', label='O'),
#     AnnotatedToken(start=705, end=706, text='.', label='O')],
#    [AnnotatedToken(start=707, end=710, text='The', label='O'),
#     AnnotatedToken(start=711, end=721, text='multiphase', label='O'),
#     AnnotatedToken(start=722, end=728, text='module', label='O'),
#     AnnotatedToken(start=729, end=731, text='of', label='O'),
#     AnnotatedToken(start=732, end=738, text='MTDATA', label='O'),
#     AnnotatedToken(start=739, end=742, text='was', label='O'),
#     AnnotatedToken(start=743, end=747, text='used', label='O'),
#     AnnotatedToken(start=748, end=750, text='in', label='O'),
#     AnnotatedToken(start=751, end=754, text='the', label='O'),
#     AnnotatedToken(start=755, end=764, text='modelling', label='B-MeasuredEntity'),
#     AnnotatedToken(start=764, end=765, text=',', label='O'),
#     AnnotatedToken(start=766, end=774, text='combined', label='O'),
#     AnnotatedToken(start=775, end=779, text='with', label='O'),
#     AnnotatedToken(start=780, end=783, text='the', label='O'),
#     AnnotatedToken(start=784, end=794, text='Scientific', label='O'),
#     AnnotatedToken(start=795, end=800, text='Group', label='O'),
#     AnnotatedToken(start=801, end=811, text='Thermodata', label='O'),
#     AnnotatedToken(start=812, end=818, text='Europe', label='O'),
#     AnnotatedToken(start=819, end=820, text='(', label='O'),
#     AnnotatedToken(start=820, end=824, text='SGTE', label='O'),
#     AnnotatedToken(start=824, end=825, text=')', label='O'),
#     AnnotatedToken(start=826, end=834, text='database', label='O'),
#     AnnotatedToken(start=834, end=835, text=',', label='O'),
#     AnnotatedToken(start=836, end=838, text='in', label='O'),
#     AnnotatedToken(start=839, end=844, text='order', label='O'),
#     AnnotatedToken(start=845, end=847, text='to', label='O'),
#     AnnotatedToken(start=848, end=855, text='predict', label='O'),
#     AnnotatedToken(start=856, end=864, text='compound', label='O'),
#     AnnotatedToken(start=864, end=870, text='/phase', label='O'),
#     AnnotatedToken(start=871, end=880, text='formation', label='O'),
#     AnnotatedToken(start=881, end=884, text='for', label='O'),
#     AnnotatedToken(start=885, end=888, text='the', label='O'),
#     AnnotatedToken(start=889, end=897, text='complete', label='O'),
#     AnnotatedToken(start=898, end=909, text='temperature', label='B-Qualifier'),
#     AnnotatedToken(start=910, end=915, text='range', label='I-MeasuredProperty'),
#     AnnotatedToken(start=915, end=916, text=',', label='O'),
#     AnnotatedToken(start=917, end=921, text='from', label='O'),
#     AnnotatedToken(start=922, end=934, text='temperatures', label='O'),
#     AnnotatedToken(start=935, end=937, text='of', label='O'),
#     AnnotatedToken(start=938, end=941, text='600', label='B-Quantity'),
#     AnnotatedToken(start=942, end=945, text='°C,', label='I-Quantity'),
#     AnnotatedToken(start=946, end=948, text='up', label='I-Quantity'),
#     AnnotatedToken(start=949, end=951, text='to', label='I-Quantity'),
#     AnnotatedToken(start=952, end=955, text='750', label='I-Quantity'),
#     AnnotatedToken(start=956, end=958, text='°C', label='I-Quantity'),
#     AnnotatedToken(start=959, end=962, text='for', label='O'),
#     AnnotatedToken(start=963, end=974, text='carbonation', label='B-Qualifier'),
#     AnnotatedToken(start=975, end=978, text='and', label='O'),
#     AnnotatedToken(start=979, end=983, text='1000', label='B-Quantity'),
#     AnnotatedToken(start=984, end=986, text='°C', label='I-Quantity'),
#     AnnotatedToken(start=987, end=990, text='for', label='O'),
#     AnnotatedToken(start=991, end=1002, text='calcination', label='B-Qualifier'),
#     AnnotatedToken(start=1002, end=1003, text=',', label='O'),
#     AnnotatedToken(start=1004, end=1006, text='in', label='O'),
#     AnnotatedToken(start=1007, end=1012, text='steps', label='B-MeasuredProperty'),
#     AnnotatedToken(start=1013, end=1015, text='of', label='O'),
#     AnnotatedToken(start=1016, end=1018, text='20', label='B-Quantity'),
#     AnnotatedToken(start=1019, end=1022, text='°C,', label='I-Quantity'),
#     AnnotatedToken(start=1023, end=1026, text='and', label='O'),
#     AnnotatedToken(start=1027, end=1029, text='at', label='O'),
#     AnnotatedToken(start=1030, end=1041, text='atmospheric', label='O'),
#     AnnotatedToken(start=1042, end=1050, text='pressure', label='O'),
#     AnnotatedToken(start=1050, end=1051, text='.', label='O')],
#    [AnnotatedToken(start=1052, end=1057, text='Molar', label='O'),
# ...
#     AnnotatedToken(start=531, end=532, text='-', label='I-Qualifier'),
#     AnnotatedToken(start=532, end=539, text='derived', label='I-Qualifier'),
#     AnnotatedToken(start=540, end=545, text='iPSCs', label='I-Qualifier'),
#     AnnotatedToken(start=545, end=546, text=',', label='O'),
#     AnnotatedToken(start=547, end=552, text='which', label='O'),
#     AnnotatedToken(start=553, end=556, text='was', label='O'),
#     AnnotatedToken(start=557, end=562, text='again', label='O'),
#     AnnotatedToken(start=563, end=572, text='increased', label='O'),
#     AnnotatedToken(start=573, end=575, text='by', label='O'),
#     AnnotatedToken(start=576, end=584, text='exposure', label='O'),
#     AnnotatedToken(start=585, end=587, text='to', label='O'),
#     AnnotatedToken(start=588, end=591, text='IFN', label='O'),
#     AnnotatedToken(start=591, end=592, text='-', label='O'),
#     AnnotatedToken(start=592, end=593, text='γ', label='O'),
#     AnnotatedToken(start=594, end=595, text='(', label='O'),
#     AnnotatedToken(start=595, end=601, text='Figure', label='O'),
#     AnnotatedToken(start=602, end=604, text='2B', label='O'),
#     AnnotatedToken(start=604, end=605, text=')', label='O'),
#     AnnotatedToken(start=605, end=606, text='.', label='O')],
#    [AnnotatedToken(start=607, end=612, text='These', label='O'),
#     AnnotatedToken(start=613, end=620, text='results', label='O'),
#     AnnotatedToken(start=621, end=628, text='suggest', label='O'),
#     AnnotatedToken(start=629, end=633, text='that', label='O'),
#     AnnotatedToken(start=634, end=639, text='donor', label='O'),
#     AnnotatedToken(start=639, end=640, text='-', label='O'),
#     AnnotatedToken(start=640, end=647, text='derived', label='O'),
#     AnnotatedToken(start=648, end=655, text='neurons', label='O'),
#     AnnotatedToken(start=656, end=661, text='could', label='O'),
#     AnnotatedToken(start=662, end=669, text='express', label='O'),
#     AnnotatedToken(start=670, end=673, text='MHC', label='O'),
#     AnnotatedToken(start=673, end=674, text='-', label='O'),
#     AnnotatedToken(start=674, end=675, text='I', label='O'),
#     AnnotatedToken(start=676, end=680, text='when', label='O'),
#     AnnotatedToken(start=681, end=684, text='INF', label='O'),
#     AnnotatedToken(start=684, end=685, text='-', label='O'),
#     AnnotatedToken(start=685, end=686, text='γ', label='O'),
#     AnnotatedToken(start=687, end=690, text='was', label='O'),
#     AnnotatedToken(start=691, end=699, text='secreted', label='O'),
#     AnnotatedToken(start=700, end=702, text='by', label='O'),
#     AnnotatedToken(start=703, end=706, text='the', label='O'),
#     AnnotatedToken(start=707, end=711, text='host', label='O'),
#     AnnotatedToken(start=712, end=717, text='brain', label='O'),
#     AnnotatedToken(start=718, end=723, text='under', label='O'),
#     AnnotatedToken(start=724, end=736, text='inflammatory', label='O'),
#     AnnotatedToken(start=737, end=747, text='conditions', label='O'),
#     AnnotatedToken(start=747, end=748, text='.', label='O')]]},
#  {'docId': 'S2213671113000738-787',
#   'sentAnnot': [[AnnotatedToken(start=0, end=3, text='For', label='O'),
#     AnnotatedToken(start=4, end=6, text='in', label='O'),
#     AnnotatedToken(start=7, end=11, text='vivo', label='O'),
#     AnnotatedToken(start=12, end=19, text='studies', label='O'),
#     AnnotatedToken(start=19, end=20, text=',', label='O'),
#     AnnotatedToken(start=21, end=24, text='the', label='O'),
#     AnnotatedToken(start=25, end=30, text='fixed', label='B-MeasuredEntity'),
#     AnnotatedToken(start=31, end=37, text='frozen', label='I-MeasuredEntity'),
#     AnnotatedToken(start=38, end=44, text='brains', label='I-MeasuredEntity'),
#     AnnotatedToken(start=45, end=49, text='were', label='I-MeasuredEntity'),
#     AnnotatedToken(start=50, end=56, text='sliced', label='I-MeasuredEntity'),
#     AnnotatedToken(start=57, end=59, text='at', label='O'),
#     AnnotatedToken(start=60, end=62, text='40', label='B-Quantity'),
#     AnnotatedToken(start=63, end=65, text='μm', label='I-Quantity'),
#     AnnotatedToken(start=66, end=75, text='thickness', label='B-MeasuredProperty'),
#     AnnotatedToken(start=76, end=79, text='and', label='O'),
#     AnnotatedToken(start=80, end=95, text='immunologically', label='O'),
#     AnnotatedToken(start=96, end=103, text='stained', label='O'),
#     AnnotatedToken(start=104, end=107, text='via', label='O'),
#     AnnotatedToken(start=108, end=111, text='the', label='O'),
#     AnnotatedToken(start=112, end=116, text='free', label='O'),
#     AnnotatedToken(start=116, end=117, text='-', label='O'),
#     AnnotatedToken(start=117, end=125, text='floating', label='O'),
#     AnnotatedToken(start=126, end=132, text='method', label='O'),
#     AnnotatedToken(start=132, end=133, text='.', label='O')],
#    [AnnotatedToken(start=134, end=137, text='The', label='O'),
#     AnnotatedToken(start=138, end=145, text='primary', label='O'),
#     AnnotatedToken(start=146, end=156, text='antibodies', label='O'),
#     AnnotatedToken(start=157, end=161, text='used', label='O'),
#     AnnotatedToken(start=162, end=165, text='are', label='O'),
#     AnnotatedToken(start=166, end=172, text='listed', label='O'),
#     AnnotatedToken(start=173, end=175, text='in', label='O'),
#     AnnotatedToken(start=176, end=181, text='Table', label='O'),
#     AnnotatedToken(start=182, end=184, text='S3', label='O'),
#     AnnotatedToken(start=184, end=185, text='.', label='O')],
#    [AnnotatedToken(start=186, end=189, text='See', label='O'),
#     AnnotatedToken(start=190, end=194, text='also', label='O'),
#     AnnotatedToken(start=195, end=207, text='Supplemental', label='O'),
#     AnnotatedToken(start=208, end=220, text='Experimental', label='O'),
#     AnnotatedToken(start=221, end=231, text='Procedures', label='O'),
#     AnnotatedToken(start=231, end=232, text='.', label='O')]]},
#  {'docId': 'S2213671113000908-643',
#   'sentAnnot': [[AnnotatedToken(start=0, end=1, text='(', label='O'),
#     AnnotatedToken(start=1, end=2, text='F', label='O'),
#     AnnotatedToken(start=2, end=3, text=')', label='O'),
#     AnnotatedToken(start=4, end=9, text='After', label='O'),
#     AnnotatedToken(start=10, end=12, text='25', label='B-Quantity'),
#     AnnotatedToken(start=13, end=17, text='days', label='I-Quantity'),
#     AnnotatedToken(start=18, end=20, text='of', label='O'),
#     AnnotatedToken(start=21, end=36, text='differentiation', label='B-MeasuredProperty'),
#     AnnotatedToken(start=36, end=37, text=',', label='O'),
#     AnnotatedToken(start=38, end=43, text='cells', label='B-MeasuredEntity'),
#     AnnotatedToken(start=44, end=53, text='expressed', label='O'),
#     AnnotatedToken(start=54, end=61, text='hepatic', label='O'),
#     AnnotatedToken(start=62, end=69, text='markers', label='O'),
#     AnnotatedToken(start=70, end=71, text='(', label='O'),
#     AnnotatedToken(start=71, end=74, text='ALB', label='O'),
#     AnnotatedToken(start=74, end=75, text=',', label='O'),
#     AnnotatedToken(start=76, end=79, text='AFP', label='O'),
#     AnnotatedToken(start=79, end=80, text=',', label='O'),
#     AnnotatedToken(start=81, end=84, text='and', label='O'),
#     AnnotatedToken(start=85, end=89, text='A1AT', label='O'),
#     AnnotatedToken(start=89, end=90, text=')', label='O'),
#     AnnotatedToken(start=90, end=91, text='.', label='O')],
#    [AnnotatedToken(start=92, end=93, text='C', label='O'),
#     AnnotatedToken(start=93, end=94, text=',', label='O'),
#     AnnotatedToken(start=95, end=111, text='undifferentiated', label='O'),
#     AnnotatedToken(start=112, end=116, text='hESC', label='O'),
#     AnnotatedToken(start=116, end=117, text=';', label='O'),
#     AnnotatedToken(start=118, end=121, text='Hep', label='O'),
#     AnnotatedToken(start=121, end=122, text=',', label='O'),
#     AnnotatedToken(start=123, end=127, text='hFSC', label='O'),
#     AnnotatedToken(start=127, end=128, text='-', label='O'),
#     AnnotatedToken(start=128, end=135, text='derived', label='O'),
#     AnnotatedToken(start=136, end=147, text='hepatocytes', label='O'),
#     AnnotatedToken(start=147, end=148, text=';', label='O'),
#     AnnotatedToken(start=149, end=150, text='F', label='O'),
#     AnnotatedToken(start=150, end=151, text=',', label='O'),
#     AnnotatedToken(start=152, end=157, text='fetal', label='O'),
#     AnnotatedToken(start=158, end=163, text='liver', label='O'),
#     AnnotatedToken(start=163, end=164, text=';', label='O'),
#     AnnotatedToken(start=165, end=166, text='A', label='O'),
#     AnnotatedToken(start=166, end=167, text=',', label='O'),
#     AnnotatedToken(start=168, end=173, text='adult', label='O'),
#     AnnotatedToken(start=174, end=179, text='liver', label='O'),
#     AnnotatedToken(start=179, end=180, text=')', label='O'),
#     AnnotatedToken(start=180, end=181, text='.', label='O')]]},
#  {'docId': 'S2213671113000921-756',
#   'sentAnnot': [[AnnotatedToken(start=0, end=1, text='(', label='O'),
#     AnnotatedToken(start=1, end=2, text='B', label='O'),
#     AnnotatedToken(start=2, end=3, text=')', label='O'),
#     AnnotatedToken(start=4, end=6, text='IF', label='O'),
#     AnnotatedToken(start=7, end=15, text='analysis', label='O'),
#     AnnotatedToken(start=16, end=18, text='of', label='O'),
#     AnnotatedToken(start=19, end=22, text='day', label='O'),
#     AnnotatedToken(start=23, end=24, text='8', label='O'),
#     AnnotatedToken(start=25, end=29, text='SOX2', label='O'),
#     AnnotatedToken(start=29, end=30, text='-', label='O'),
#     AnnotatedToken(start=30, end=33, text='GFP', label='O'),
#     AnnotatedToken(start=34, end=37, text='AFE', label='O'),
#     AnnotatedToken(start=38, end=46, text='cultures', label='O'),
#     AnnotatedToken(start=47, end=48, text='(', label='O'),
#     AnnotatedToken(start=48, end=53, text='scale', label='B-MeasuredEntity'),
#     AnnotatedToken(start=54, end=57, text='bar', label='I-MeasuredEntity'),
#     AnnotatedToken(start=58, end=68, text='represents', label='O'),
#     AnnotatedToken(start=69, end=72, text='200', label='B-Quantity'),
#     AnnotatedToken(start=73, end=75, text='μm', label='I-Quantity'),
#     AnnotatedToken(start=75, end=76, text=')', label='O'),
#     AnnotatedToken(start=76, end=77, text='.', label='O')]]},
#  {'docId': 'S2213671113001306-1385',
#   'sentAnnot': [[AnnotatedToken(start=0, end=2, text='On', label='O'),
#     AnnotatedToken(start=3, end=8, text='first', label='O'),
#     AnnotatedToken(start=9, end=22, text='postoperative', label='O'),
#     AnnotatedToken(start=23, end=27, text='exam', label='O'),
#     AnnotatedToken(start=28, end=29, text='(', label='O'),
#     AnnotatedToken(start=29, end=33, text='days', label='O'),
#     AnnotatedToken(start=34, end=35, text='3', label='O'),
#     AnnotatedToken(start=35, end=36, text='–', label='O'),
#     AnnotatedToken(start=36, end=37, text='5', label='O'),
#     AnnotatedToken(start=37, end=38, text=')', label='O'),
#     AnnotatedToken(start=38, end=39, text=',', label='O'),
#     AnnotatedToken(start=40, end=41, text='a', label='O'),
#     AnnotatedToken(start=42, end=47, text='white', label='O'),
#     AnnotatedToken(start=48, end=55, text='retinal', label='O'),
#     AnnotatedToken(start=56, end=63, text='opacity', label='O'),
#     AnnotatedToken(start=64, end=73, text='overlying', label='O'),
#     AnnotatedToken(start=74, end=77, text='the', label='O'),
#     AnnotatedToken(start=78, end=82, text='hRPE', label='O'),
#     AnnotatedToken(start=83, end=90, text='implant', label='O'),
#     AnnotatedToken(start=91, end=94, text='was', label='O'),
#     AnnotatedToken(start=95, end=99, text='seen', label='O'),
#     AnnotatedToken(start=100, end=102, text='on', label='O'),
#     AnnotatedToken(start=103, end=109, text='fundus', label='O'),
#     AnnotatedToken(start=110, end=121, text='photography', label='O'),
#     AnnotatedToken(start=121, end=122, text=',', label='O'),
#     AnnotatedToken(start=123, end=128, text='along', label='O'),
#     AnnotatedToken(start=129, end=133, text='with', label='O'),
#     AnnotatedToken(start=134, end=144, text='occasional', label='O'),
#     AnnotatedToken(start=145, end=158, text='triamcinolone', label='O'),
#     AnnotatedToken(start=159, end=167, text='crystals', label='O'),
#     AnnotatedToken(start=168, end=175, text='trapped', label='O'),
#     AnnotatedToken(start=176, end=182, text='around', label='O'),
#     AnnotatedToken(start=183, end=186, text='the', label='O'),
#     AnnotatedToken(start=187, end=197, text='retinotomy', label='O'),
#     AnnotatedToken(start=198, end=202, text='site', label='O'),
#     AnnotatedToken(start=202, end=203, text='.', label='O')],
#    [AnnotatedToken(start=204, end=207, text='The', label='O'),
#     AnnotatedToken(start=208, end=215, text='whitish', label='O'),
#     AnnotatedToken(start=216, end=223, text='opacity', label='O'),
#     AnnotatedToken(start=224, end=227, text='was', label='O'),
#     AnnotatedToken(start=228, end=240, text='subsequently', label='O'),
#     AnnotatedToken(start=241, end=245, text='lost', label='O'),
#     AnnotatedToken(start=246, end=248, text='in', label='O'),
#     AnnotatedToken(start=249, end=253, text='both', label='O'),
#     AnnotatedToken(start=254, end=258, text='hRPE', label='O'),
#     AnnotatedToken(start=259, end=266, text='implant', label='O'),
#     AnnotatedToken(start=267, end=272, text='types', label='O'),
#     AnnotatedToken(start=272, end=273, text=',', label='O'),
#     AnnotatedToken(start=274, end=278, text='with', label='O'),
#     AnnotatedToken(start=279, end=282, text='all', label='O'),
#     AnnotatedToken(start=283, end=292, text='remaining', label='O'),
#     AnnotatedToken(start=293, end=299, text='follow', label='B-MeasuredEntity'),
#     AnnotatedToken(start=299, end=300, text='-', label='I-MeasuredEntity'),
#     AnnotatedToken(start=300, end=302, text='up', label='I-MeasuredEntity'),
#     AnnotatedToken(start=303, end=308, text='exams', label='I-MeasuredEntity'),
#     AnnotatedToken(start=309, end=310, text='(', label='O'),
#     AnnotatedToken(start=310, end=316, text='beyond', label='B-Quantity'),
#     AnnotatedToken(start=317, end=318, text='1', label='I-Quantity'),
#     AnnotatedToken(start=319, end=323, text='week', label='I-Quantity'),
#     AnnotatedToken(start=324, end=337, text='postoperation', label='B-Qualifier'),
#     AnnotatedToken(start=338, end=339, text='[', label='O'),
#     AnnotatedToken(start=339, end=343, text='post', label='O'),
#     AnnotatedToken(start=343, end=344, text='-', label='O'),
#     AnnotatedToken(start=344, end=346, text='OP', label='O'),
#     AnnotatedToken(start=346, end=347, text=']', label='O'),
#     AnnotatedToken(start=347, end=348, text=')', label='O'),
#     AnnotatedToken(start=349, end=356, text='showing', label='O'),
#     AnnotatedToken(start=357, end=358, text='a', label='O'),
#     AnnotatedToken(start=359, end=364, text='steep', label='O'),
#     AnnotatedToken(start=365, end=369, text='edge', label='O'),
#     AnnotatedToken(start=370, end=376, text='around', label='O'),
#     AnnotatedToken(start=377, end=380, text='the', label='O'),
#     AnnotatedToken(start=381, end=388, text='implant', label='O'),
#     AnnotatedToken(start=389, end=398, text='periphery', label='O'),
#     AnnotatedToken(start=399, end=400, text='(', label='O'),
#     AnnotatedToken(start=400, end=406, text='Figure', label='O'),
#     AnnotatedToken(start=407, end=409, text='2A', label='O'),
#     AnnotatedToken(start=410, end=413, text='for', label='O'),
#     AnnotatedToken(start=414, end=419, text='fetal', label='O'),
#     AnnotatedToken(start=420, end=423, text='and', label='O'),
#     AnnotatedToken(start=424, end=426, text='2C', label='O'),
#     AnnotatedToken(start=427, end=430, text='for', label='O'),
#     AnnotatedToken(start=431, end=436, text='adult', label='O'),
#     AnnotatedToken(start=436, end=437, text=';', label='O'),
#     AnnotatedToken(start=438, end=444, text='Movies', label='O'),
#     AnnotatedToken(start=445, end=447, text='S3', label='O'),
#     AnnotatedToken(start=448, end=451, text='and', label='O'),
#     AnnotatedToken(start=452, end=454, text='S4', label='O'),
#     AnnotatedToken(start=454, end=455, text=')', label='O'),
#     AnnotatedToken(start=455, end=456, text='.', label='O')]]}]

# %%
# write the annotated NER training data into a file
f = open("test.txt", "w", encoding='UTF-8')

for example in examples:
    annotated_sent = example['sentAnnot']
    for sent in annotated_sent:
        for token in sent:
            f.write(token.text + '\t' + token.label + '\n')
        f.write('\n')

f.close()

# %%
# count the number of sentences
num = 0
for example in examples:
    annotated_sent = example['sentAnnot']
    for sent in annotated_sent:
        num += 1
num
# Out:
# 842

# %%
# split the data into test(2/3) and dev(1/3) set
# dev: 281; test: 561

import random

sample_nums = random.sample(range(842), 281)
sample_nums
# Out:
# [700,
#  214,
#  500,
#  177,
#  350,
#  76,
#  42,
#  711,
#  616,
#  679,
#  651,
#  115,
#  332,
#  492,
#  404,
#  235,
#  483,
#  551,
#  219,
#  317,
#  296,
#  161,
#  192,
#  7,
#  377,
#  423,
#  566,
#  253,
#  175,
#  327,
#  585,
#  442,
#  714,
#  339,
#  228,
#  322,
#  81,
#  320,
#  345,
#  299,
#  557,
#  59,
#  502,
#  370,
#  588,
#  653,
#  131,
#  703,
#  708,
#  140,
#  127,
#  26,
#  550,
#  270,
#  236,
#  134,
#  833,
#  418,
#  337,
#  149,
#  74,
#  568,
#  23,
#  91,
#  60,
#  619,
#  768,
#  390,
#  336,
#  282,
#  314,
#  344,
#  659,
#  522,
#  108,
#  147,
#  733,
#  58,
#  4,
#  279,
#  757,
#  343,
#  284,
#  101,
#  464,
#  295,
#  394,
#  232,
#  738,
#  486,
#  342,
#  265,
#  193,
#  610,
#  530,
#  433,
#  388,
#  169,
#  791,
#  10,
#  732,
#  373,
#  528,
#  841,
#  8,
#  511,
#  541,
#  447,
#  773,
#  400,
#  107,
#  417,
#  799,
#  817,
#  564,
#  17,
#  278,
#  748,
#  378,
#  495,
#  64,
#  549,
#  543,
#  89,
#  387,
#  539,
#  690,
#  729,
#  470,
#  624,
#  69,
#  480,
#  454,
#  251,
#  231,
#  92,
#  721,
#  202,
#  52,
#  123,
#  199,
#  482,
#  467,
#  672,
#  266,
#  620,
#  163,
#  246,
#  716,
#  654,
#  38,
#  521,
#  481,
#  114,
#  277,
#  494,
#  828,
#  201,
#  212,
#  715,
#  226,
#  821,
#  29,
#  837,
#  602,
#  809,
#  466,
#  647,
#  135,
#  674,
#  243,
#  456,
#  503,
#  537,
#  90,
#  411,
#  20,
#  621,
#  565,
#  209,
#  626,
#  288,
#  6,
#  405,
#  70,
#  171,
#  283,
#  835,
#  200,
#  83,
#  498,
#  401,
#  126,
#  25,
#  125,
#  808,
#  553,
#  631,
#  382,
#  509,
#  63,
#  807,
#  85,
#  225,
#  197,
#  766,
#  652,
#  66,
#  504,
#  594,
#  582,
#  826,
#  666,
#  606,
#  782,
#  790,
#  570,
#  72,
#  750,
#  315,
#  376,
#  420,
#  559,
#  399,
#  94,
#  329,
#  506,
#  678,
#  688,
#  341,
#  649,
#  100,
#  532,
#  178,
#  514,
#  611,
#  348,
#  198,
#  556,
#  781,
#  665,
#  811,
#  642,
#  605,
#  592,
#  622,
#  630,
#  794,
#  119,
#  249,
#  597,
#  637,
#  583,
#  788,
#  822,
#  184,
#  271,
#  717,
#  30,
#  263,
#  102,
#  712,
#  174,
#  544,
#  98,
#  673,
#  211,
#  304,
#  578,
#  18,
#  5,
#  696,
#  655,
#  47,
#  412,
#  689,
#  534,
#  453,
#  538,
#  591,
#  21]

# %%
sents = []
for example in examples:
    annotated_sent = example['sentAnnot']
    for sent in annotated_sent:
        sents.append(sent)

dev = []
test = []
for i in range(842):
    if i in sample_nums:
        dev.append(sents[i])
    else:
        test.append(sents[i])

# %%
len(test)
# Out:
# 561

# %%
# write the annotated NER dev data into a file
f = open("dev.txt", "w", encoding='UTF-8')

for sent in dev:
    for token in sent:
        f.write(token.text + '\t' + token.label + '\n')
    f.write('\n')

f.close()

# %%
# write the annotated NER test data into a file
f = open("test.txt", "w", encoding='UTF-8')

for sent in test:
    for token in sent:
        f.write(token.text + '\t' + token.label + '\n')
    f.write('\n')

f.close()

# %% [markdown]
# ## Unit Tagging

# %%
# annotating tokens in each sentence for each doc

# examples = [exmaple]
# annotated_sent = [annotated_tokens[]]
# example = {
#     'docId': doc.docId,
#     'sentAnnot': annotated_sent
# }
import re

Token = namedtuple('Token', ['start', 'end', 'text'])
AnnotatedToken = namedtuple('AnnotatedToken', ['start', 'end', 'text', 'label'])

examples = []
for doc in docs.itertuples():
    doc_annotations = annotations[(annotations.docId == doc.docId) & (annotations.annotType == 'Quantity')]
#     print(doc)
#     print(doc_annotations)
    
    # get rows containing 'unit' in 'other' column
    idx_list = []
    for index, row in doc_annotations.reset_index(drop=True).iterrows():
        if row['other'].get('unit') != None:
            idx_list.append(index)
    doc_annotations = doc_annotations.iloc[idx_list]
#     print(doc_annotations)

#     # add column 'sentIdx' representing the index of a sentence where each quantity of the doc belongs to
#     sent_idx = []
#     for index, row in doc_annotations.iterrows():
#         # check whether the current quantity is within the range of the current sentence span
#         for i in range(len(doc.texts)):
#             sent = doc.texts[i]
#             isInRange = set(range(row.startOffset, row.endOffset)).intersection(set(range(sent.start, sent.end)))
#             if isInRange:
#                 sent_idx.append(i)
#     doc_annotations.loc[:, 'sentIdx'] = sent_idx
    
    # add columns 'unitStart' and 'unitEnd' in doc_annotations to mark the span of units
    unit_start = []
    for index, row in doc_annotations.iterrows():
        if re.compile(row['other'].get('unit')).search(row.text) != None:
            # 'unit' span is within the range of 'quantity' span: append its start offset
            s = re.compile(row['other'].get('unit')).search(row.text).span()[0] + row.startOffset
            unit_start.append(s)
        else:
            # 'unit' span is not within the range of 'quantity' span: ignore it 
            unit_start.append(-1)

            print(row)
            print(doc)
            print(doc_annotations)
    doc_annotations.loc[:, 'unitStart'] = unit_start
    
    unit_end = []
    for index, row in doc_annotations.iterrows():
        if re.compile(row['other'].get('unit')).search(row.text) != None:
            e = re.compile(row['other'].get('unit')).search(row.text).span()[1] + row.startOffset
            unit_end.append(e)
        else:
            unit_end.append(-1)
    doc_annotations.loc[:, 'unitEnd'] = unit_end
    
    # labeling each sentence
    annotated_sent = []
    for sent in doc.texts:
        # get the span of each token within the current sentence
        tokens = [
            Token(sent.start + start, sent.start + end, token)
            for (start, end), token in zip(
                tokenizer.span_tokenize(sent.text),
                tokenizer.tokenize(sent.text)
            )
        ]
        
#         print(sent)
#         for t in tokens:
#             print(t)
            
        # retrieve labels for each sentence
        AnnotatedSpan = namedtuple('AnnotatedSpan', ['start', 'end', 'label'])
        df = doc_annotations[(doc_annotations.unitStart >= sent.start) & (doc_annotations.unitEnd <= sent.end)]
        sent_labels = [AnnotatedSpan(r.unitStart, r.unitEnd, 'unit') for r in df.itertuples()]
#         for l in sent_labels:
#             print("sent_labels", l)
            
        annotated_tokens = []
        for token in tokens:
            # initialise the annotation tag for the current token as 'O'
            tag = 'O'
            for sl in sent_labels:
                # check whether the current token is within the range of the current annotated span
                isInCurrRange = set(range(token.start, token.end)).intersection(set(range(sl.start, sl.end)))
                if isInCurrRange:
                    # choose not to use BIO tag due to some corner examples
                    # unit is within the span of a token (e.g. quantity='5≤2θ/°≤80', unit='°')
                    tag = 'unit'
#                     # check whether it's in the beginning (B) of the span
#                     if token.start == sl.start:
#                         tag = 'B-' + sl.label
#                     # otherwise, it's in the internal (I) of the span
#                     else:
#                         tag = 'I-' + sl.label
            # append the annotated tag for the current token
            annotated_tokens.append(AnnotatedToken(token.start, token.end, token.text, tag))
        
#         for a in annotated_tokens:
#             print('annotated_tokens', a)
        
        if len(annotated_tokens) == len(tokens):
            annotated_sent.append(annotated_tokens)
    
#     for anns in annotated_sent:
#         for annt in anns:
#             print('annotated_tokens', annt)
            
    example = {
        'docId': doc.docId,
        'sentAnnot': annotated_sent
    }
    examples.append(example)
# Out:
# docId          S0019103512003995-1237
# annotSet                            4
# annotType                    Quantity
# startOffset                       607
# endOffset                         613
# annotId                          T1-4
# text                           17,500
# other                   {'unit': 'R'}
# Name: 199, dtype: object
# Pandas(Index=12, docId='S0019103512003995-1237', text='(a) The C II 1334.5 Å line of HD209458 (solid line, Linsky et al., 2010) fitted with a Voigt profile (see Table 1) and adjusted for absorption by the ISM (dotted line). We assumed that the column density of ground state C+ in the ISM is 2.23 × 1019 m−2. The relative velocity of the ISM with respect to Earth is −6.6 km s−1 and the effective thermal velocity along the LOS to the star is 12.3 km s−1 (Wood et al., 2005). (b) The C II 1335.7 Å line of HD209458 fitted with a Voigt profile. Absorption by the ISM was assumed to be negligible. The model profiles were convolved to a spectral resolution of R = 17,500.', texts=[Sentence(start=0, end=168, text='(a) The C II 1334.5 Å line of HD209458 (solid line, Linsky et al., 2010) fitted with a Voigt profile (see Table 1) and adjusted for absorption by the ISM (dotted line).'), Sentence(start=169, end=253, text='We assumed that the column density of ground state C+ in the ISM is 2.23 × 1019 m−2.'), Sentence(start=254, end=420, text='The relative velocity of the ISM with respect to Earth is −6.6 km s−1 and the effective thermal velocity along the LOS to the star is 12.3 km s−1 (Wood et al., 2005).'), Sentence(start=421, end=488, text='(b) The C II 1335.7 Å line of HD209458 fitted with a Voigt profile.'), Sentence(start=489, end=540, text='Absorption by the ISM was assumed to be negligible.'), Sentence(start=541, end=614, text='The model profiles were convolved to a spectral resolution of R = 17,500.')])
#                       docId  annotSet annotType  startOffset  endOffset  \
# 189  S0019103512003995-1237         1  Quantity          237        252
# 192  S0019103512003995-1237         2  Quantity          312        323
# 196  S0019103512003995-1237         3  Quantity          388        399
# 199  S0019103512003995-1237         4  Quantity          607        613
#
#     annotId             text               other
# 189    T1-1  2.23 × 1019 m−2     {'unit': 'm−2'}
# 192    T1-2      −6.6 km s−1  {'unit': 'km s−1'}
# 196    T1-3      12.3 km s−1  {'unit': 'km s−1'}
# 199    T1-4           17,500       {'unit': 'R'}
# docId          S0032063312003054-2458
# annotSet                            4
# annotType                    Quantity
# startOffset                       572
# endOffset                         575
# annotId                          T1-4
# text                              9.8
# other                   {'unit': '%'}
# Name: 350, dtype: object
# Pandas(Index=30, docId='S0032063312003054-2458', text='Table 1 presents the percentage of MEX orbits that we observe the different combinations of energy distribution asymmetries. In total, ASPERA-3 observes electron precipitation signatures on 43.0% of MEX orbits at Mars. The signatures of unaccelerated electron precipitation from electron spikes make up ∼70% of this total, occurring on 29.8% of MEX orbits, and are therefore the most common form of electron precipitation signature at Mars. This compares to signatures of accelerated electron precipitation from peaked electrons and “inverted-V” electrons, which occur on 9.8 and 3.4% of MEX orbits, respectively. This suggests a similarity to the Earth where the diffuse aurora from the precipitation of unaccelerated electrons accounts for a much larger amount of the precipitating flux of particles onto the atmosphere than discrete aurora (Newell et al., 2009).', texts=[Sentence(start=0, end=124, text='Table 1 presents the percentage of MEX orbits that we observe the different combinations of energy distribution asymmetries.'), Sentence(start=125, end=218, text='In total, ASPERA-3 observes electron precipitation signatures on 43.0% of MEX orbits at Mars.'), Sentence(start=219, end=440, text='The signatures of unaccelerated electron precipitation from electron spikes make up ∼70% of this total, occurring on 29.8% of MEX orbits, and are therefore the most common form of electron precipitation signature at Mars.'), Sentence(start=441, end=613, text='This compares to signatures of accelerated electron precipitation from peaked electrons and “inverted-V” electrons, which occur on 9.8 and 3.4% of MEX orbits, respectively.'), Sentence(start=614, end=865, text='This suggests a similarity to the Earth where the diffuse aurora from the precipitation of unaccelerated electrons accounts for a much larger amount of the precipitating flux of particles onto the atmosphere than discrete aurora (Newell et al., 2009).')])
#                       docId  annotSet annotType  startOffset  endOffset  \
# 341  S0032063312003054-2458         1  Quantity          190        195
# 344  S0032063312003054-2458         2  Quantity          303        307
# 347  S0032063312003054-2458         3  Quantity          336        341
# 350  S0032063312003054-2458         4  Quantity          572        575
# 353  S0032063312003054-2458         5  Quantity          580        584
#
#     annotId   text                                     other
# 341    T1-1  43.0%                             {'unit': '%'}
# 344    T1-2   ∼70%  {'mods': ['IsApproximate'], 'unit': '%'}
# 347    T1-3  29.8%                             {'unit': '%'}
# 350    T1-4    9.8                             {'unit': '%'}
# 353    T1-5   3.4%                             {'unit': '%'}
# docId          S0925443913001385-1526
# annotSet                            2
# annotType                    Quantity
# startOffset                       205
# endOffset                         215
# annotId                          T1-2
# text                       1.2% (w/v)
# other             {'unit': '% (w/v)'}
# Name: 955, dtype: object
# Pandas(Index=84, docId='S0925443913001385-1526', text="RNA was isolated from fibroblasts using Trizol following manufacturer's protocol (Invitrogen). Northern blots were performed as described [48]. Briefly, aliquots of RNA (5 μg) were electrophoresed through 1.2% (w/v) agarose under denaturing conditions and transferred to GenescreenPlus membrane (NEN duPont) following the manufacturer's protocol. Radiolabelled probes were generated using random hexamers on PCR-generated templates corresponding to internal regions of the relevant genes.", texts=[Sentence(start=0, end=94, text="RNA was isolated from fibroblasts using Trizol following manufacturer's protocol (Invitrogen)."), Sentence(start=95, end=143, text='Northern blots were performed as described [48].'), Sentence(start=144, end=346, text="Briefly, aliquots of RNA (5 μg) were electrophoresed through 1.2% (w/v) agarose under denaturing conditions and transferred to GenescreenPlus membrane (NEN duPont) following the manufacturer's protocol."), Sentence(start=347, end=488, text='Radiolabelled probes were generated using random hexamers on PCR-generated templates corresponding to internal regions of the relevant genes.')])
#                       docId  annotSet annotType  startOffset  endOffset  \
# 953  S0925443913001385-1526         1  Quantity          170        174
# 955  S0925443913001385-1526         2  Quantity          205        215
#
#     annotId        text                other
# 953    T1-1        5 μg       {'unit': 'μg'}
# 955    T1-2  1.2% (w/v)  {'unit': '% (w/v)'}

# %%
u = '% (w/v)'
q = '1.2% (w/v)'

re.compile(u).search(q).span()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f8ee290fcb0c> in <module>
#       2 q = '1.2% (w/v)'
#       3
# ----> 4 re.compile(u).search(q).span()
#
# AttributeError: 'NoneType' object has no attribute 'span'

# %%
# split the data into test(2/3) and dev(1/3) set
# dev: 281; test: 561

import random

sample_nums = random.sample(range(842), 281)

sents = []
for example in examples:
    annotated_sent = example['sentAnnot']
    for sent in annotated_sent:
        sents.append(sent)

dev = []
test = []
for i in range(842):
    if i in sample_nums:
        dev.append(sents[i])
    else:
        test.append(sents[i])

# %%
# write the annotated NER dev data into a file
f = open("dev.txt", "w", encoding='UTF-8')

for sent in dev:
    for token in sent:
        f.write(token.text + '\t' + token.label + '\n')
    f.write('\n')

f.close()

# write the annotated NER test data into a file
f = open("test.txt", "w", encoding='UTF-8')

for sent in test:
    for token in sent:
        f.write(token.text + '\t' + token.label + '\n')
    f.write('\n')

f.close()
